# %%
import os
from dotenv import load_dotenv

load_dotenv()  # Loads .env file into environment
token = os.getenv("GITHUB_TOKEN")
headers = {"Authorization": f"token {token}"}

# %%
# get base repositories for Java projects on GitHub

import requests
import json

repos = {'layer1': [], 'layer2': [], 'layer3': [], 'layer4': [], 'layer5': [], 'layer6': [], 'layer7': []}

base_url = "https://api.github.com/search/repositories"

# Define different star ranges to get up to 10,000 repositories
star_ranges = [
    "stars:>10000",
    "stars:5000..10000", 
    "stars:2000..4999",
    "stars:1000..1999",
    "stars:500..999",
    "stars:200..499",
    "stars:100..199",
    "stars:50..99",
    "stars:25..49",
    "stars:10..24"
]

for star_range in star_ranges:
    print(f"\nSearching repositories with {star_range}")
    
    params = {
        "q": f"language:Java {star_range} size:<256",
        "sort": "stars",
        "order": "desc",
        "per_page": 100,
        "page": 1
    }
    
    # Get up to x pages per star range
    for page in range(1, 3):
        params["page"] = page
        r = requests.get(base_url, headers=headers, params=params)
        
        if r.status_code == 200:
            page_items = r.json().get("items", [])
            repos["layer1"].extend(page_items)
            print(f"  Page {page}: Found {len(page_items)} repos - Total: {len(repos["layer1"])}")
            
            # If we get less than 100 results, we've reached the end
            if len(page_items) < 100:
                print(f"  Reached end of results for {star_range}")
                break
        else:
            print(f"  Page {page}: Status {r.status_code} - Failed")
            print(f"    Response: {r.text}")
            break
    
    print(f"Total repositories collected so far: {len(repos["layer1"])}")

# Remove duplicates based on full_name
# seen_repos = set()
# unique_repos = []
# for repo in repos["layer1"]:
#     if repo["full_name"] not in seen_repos:
#         seen_repos.add(repo["full_name"])
#         unique_repos.append(repo)

# repos = unique_repos
print(f"\nFinal count after removing duplicates: {len(repos['layer1'])}")

# Save the repositories to a json file
with open("/tmp/java_repos.json", "w") as f:
    json.dump(repos, f, indent=2)

print(f"Saved {len(repos['layer1'])} unique Java repositories to /tmp/java_repos.json")
# Out:
# Searching repositories with stars:>10000
#   Page 1: Found 2 repos - Total: 2
#   Reached end of results for stars:>10000
# Total repositories collected so far: 2
#
# Searching repositories with stars:5000..10000
#   Page 1: Found 2 repos - Total: 2
#   Reached end of results for stars:>10000
# Total repositories collected so far: 2
#
# Searching repositories with stars:5000..10000
#   Page 1: Found 8 repos - Total: 10
#   Reached end of results for stars:5000..10000
# Total repositories collected so far: 10
#
# Searching repositories with stars:2000..4999
#   Page 1: Found 8 repos - Total: 10
#   Reached end of results for stars:5000..10000
# Total repositories collected so far: 10
#
# Searching repositories with stars:2000..4999
#   Page 1: Found 34 repos - Total: 44
#   Reached end of results for stars:2000..4999
# Total repositories collected so far: 44
#
# Searching repositories with stars:1000..1999
#   Page 1: Found 34 repos - Total: 44
#   Reached end of results for stars:2000..4999
# Total repositories collected so far: 44
#
# Searching repositories with stars:1000..1999
#   Page 1: Found 100 repos - Total: 144
#   Page 1: Found 100 repos - Total: 144
#   Page 2: Found 7 repos - Total: 151
#   Reached end of results for stars:1000..1999
# Total repositories collected so far: 151
#
# Searching repositories with stars:500..999
#   Page 2: Found 7 repos - Total: 151
#   Reached end of results for stars:1000..1999
# Total repositories collected so far: 151
#
# Searching repositories with stars:500..999
#   Page 1: Found 100 repos - Total: 251
#   Page 1: Found 100 repos - Total: 251
#   Page 2: Found 100 repos - Total: 351
# Total repositories collected so far: 351
#
# Searching repositories with stars:200..499
#   Page 2: Found 100 repos - Total: 351
# Total repositories collected so far: 351
#
# Searching repositories with stars:200..499
#   Page 1: Found 100 repos - Total: 451
#   Page 1: Found 100 repos - Total: 451
#   Page 2: Found 100 repos - Total: 551
# Total repositories collected so far: 551
#
# Searching repositories with stars:100..199
#   Page 2: Found 100 repos - Total: 551
# Total repositories collected so far: 551
#
# Searching repositories with stars:100..199
#   Page 1: Found 100 repos - Total: 651
#   Page 1: Found 100 repos - Total: 651
#   Page 2: Found 100 repos - Total: 751
# Total repositories collected so far: 751
#
# Searching repositories with stars:50..99
#   Page 2: Found 100 repos - Total: 751
# Total repositories collected so far: 751
#
# Searching repositories with stars:50..99
#   Page 1: Found 100 repos - Total: 851
#   Page 1: Found 100 repos - Total: 851
#   Page 2: Found 100 repos - Total: 951
# Total repositories collected so far: 951
#
# Searching repositories with stars:25..49
#   Page 2: Found 100 repos - Total: 951
# Total repositories collected so far: 951
#
# Searching repositories with stars:25..49
#   Page 1: Found 100 repos - Total: 1051
#   Page 1: Found 100 repos - Total: 1051
#   Page 2: Found 100 repos - Total: 1151
# Total repositories collected so far: 1151
#
# Searching repositories with stars:10..24
#   Page 2: Found 100 repos - Total: 1151
# Total repositories collected so far: 1151
#
# Searching repositories with stars:10..24
#   Page 1: Found 100 repos - Total: 1251
#   Page 1: Found 100 repos - Total: 1251
#   Page 2: Found 100 repos - Total: 1351
# Total repositories collected so far: 1351
#
# Final count after removing duplicates: 1351
# Saved 1351 unique Java repositories to /tmp/java_repos.json
#   Page 2: Found 100 repos - Total: 1351
# Total repositories collected so far: 1351
#
# Final count after removing duplicates: 1351
# Saved 1351 unique Java repositories to /tmp/java_repos.json

# %%
len(repos)  # Output the number of repositories found
# Out:
# 1000

# %%
java_dependencies = {'layer1':{}, 'layer2':{}, 'layer3':{}, 'layer4':{}, 'layer5':{}, 'layer6':{}, 'layer7': {}}
repo_relationships = {'layer1': {}, 'layer2': {}, 'layer3': {}, 'layer4': {}, 'layer5': {}, 'layer6': {}, 'layer7': {}}


def already_exists(repo):
    # check if it is already in repos layers
    for layer in repos:
        if repo in repos[layer]:
            return True
    return False

# %%
import re
import xml.etree.ElementTree as ET
import time

def extract_maven_dependencies(pom_content):
    """Extract dependencies from pom.xml content"""
    dependencies = []
    try:
        root = ET.fromstring(pom_content)
        # Handle namespaces
        ns = {'maven': 'http://maven.apache.org/POM/4.0.0'}
        
        # Find dependencies
        deps = root.findall('.//maven:dependency', ns) or root.findall('.//dependency')
        
        for dep in deps:
            group_id = dep.find('maven:groupId', ns) or dep.find('groupId')
            artifact_id = dep.find('maven:artifactId', ns) or dep.find('artifactId')
            version = dep.find('maven:version', ns) or dep.find('version')
            
            if group_id is not None and artifact_id is not None:
                dependencies.append({
                    'groupId': group_id.text,
                    'artifactId': artifact_id.text,
                    'version': version.text if version is not None else 'unknown'
                })
    except ET.ParseError:
        pass
    return dependencies

def extract_gradle_dependencies(gradle_content):
    """Extract dependencies from build.gradle content"""
    dependencies = []
    # Pattern to match various gradle dependency formats
    patterns = [
        r"implementation\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"compile\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"api\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"testImplementation\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]"
    ]
    
    for pattern in patterns:
        matches = re.findall(pattern, gradle_content)
        for match in matches:
            dependencies.append({
                'groupId': match[0],
                'artifactId': match[1],
                'version': match[2]
            })
    return dependencies

def get_repository_dependencies(repo_full_name):
    """Get dependencies from a repository's build files without searching for GitHub repos"""
    dependencies = []
    
    try:
        # Get repository contents to find build files
        contents_url = f"https://api.github.com/repos/{repo_full_name}/contents"
        response = requests.get(contents_url, headers=headers)
        
        if response.status_code != 200:
            print(f"Failed to get contents for {repo_full_name}: HTTP {response.status_code}")
            return dependencies
        
        contents = response.json()
        
        # Look for pom.xml
        pom_file = next((item for item in contents if item["name"] == "pom.xml"), None)
        if pom_file:
            pom_response = requests.get(pom_file["download_url"])
            if pom_response.status_code == 200:
                dependencies.extend(extract_maven_dependencies(pom_response.text))
            else:
                print(f"Failed to download pom.xml for {repo_full_name}: HTTP {pom_response.status_code}")
        
        # Look for build.gradle
        gradle_file = next((item for item in contents if item["name"] == "build.gradle"), None)
        if gradle_file:
            gradle_response = requests.get(gradle_file["download_url"])
            if gradle_response.status_code == 200:
                dependencies.extend(extract_gradle_dependencies(gradle_response.text))
            else:
                print(f"Failed to download build.gradle for {repo_full_name}: HTTP {gradle_response.status_code}")
                    
    except Exception as e:
        print(f"Error getting dependencies for {repo_full_name}: {e}")
    
    return dependencies

# Simple array to store all dependencies
all_dependencies = []

# Simple dependency extraction for repositories
SRC_LAYER = 'layer1'

print(f"Extracting dependencies from {SRC_LAYER} repositories...")

try:
    for i, repo in enumerate(repos[SRC_LAYER]):
        if SRC_LAYER == 'layer1':
            repo_full_name = repo["full_name"]
        else:
            if isinstance(repo, str):
                repo_full_name = repo
            else:
                repo_full_name = repo[0] if repo else None
                
        if not repo_full_name:
            continue
            
        print(f"[{i+1}/{len(repos[SRC_LAYER])}] Analyzing {repo_full_name}... Total found so far: {len(all_dependencies)}")
        
        try:
            dependencies = get_repository_dependencies(repo_full_name)
            
            # Add each dependency to the simple array
            for dep in dependencies:
                dependency_entry = {
                    'repository': repo_full_name,
                    'groupId': dep['groupId'],
                    'artifactId': dep['artifactId'],
                    'version': dep['version']
                }
                all_dependencies.append(dependency_entry)
            
            print(f"  Found {len(dependencies)} dependencies")
            
            # Rate limiting
            time.sleep(0.1)
            
        except Exception as e:
            print(f"  Error analyzing {repo_full_name}: {e}")
            continue

    print("Dependency extraction complete!")
    print(f"Total dependencies found: {len(all_dependencies)}")
    
except Exception as e:
    print(f"An error occurred: {e}")
    
finally:
    # Save the simple array of dependencies
    with open("/tmp/all_dependencies_simple.json", "w") as f:
        json.dump(all_dependencies, f, indent=2)
    
    print(f"Saved {len(all_dependencies)} dependencies to /tmp/all_dependencies_simple.json")
    
    # Also save a summary of unique dependencies
    unique_deps = set()
    for dep in all_dependencies:
        unique_deps.add(f"{dep['groupId']}:{dep['artifactId']}")
    
    unique_deps_list = sorted(list(unique_deps))
    with open("/tmp/unique_dependencies.json", "w") as f:
        json.dump(unique_deps_list, f, indent=2)
    
    print(f"Saved {len(unique_deps_list)} unique dependencies to /tmp/unique_dependencies.json")
# Out:
# Extracting dependencies from layer1 repositories...
# [1/1351] Analyzing winterbe/java8-tutorial... Total found so far: 0
#   Found 0 dependencies
# [2/1351] Analyzing ashishps1/awesome-leetcode-resources... Total found so far: 0
#   Found 0 dependencies
# [2/1351] Analyzing ashishps1/awesome-leetcode-resources... Total found so far: 0
#   Found 0 dependencies
# [3/1351] Analyzing lihengming/spring-boot-api-project-seed... Total found so far: 0
#   Found 0 dependencies
# [3/1351] Analyzing lihengming/spring-boot-api-project-seed... Total found so far: 0
# /tmp/ipykernel_114059/975964736.py:17: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   group_id = dep.find('maven:groupId', ns) or dep.find('groupId')
# /tmp/ipykernel_114059/975964736.py:18: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   artifact_id = dep.find('maven:artifactId', ns) or dep.find('artifactId')
# /tmp/ipykernel_114059/975964736.py:19: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   version = dep.find('maven:version', ns) or dep.find('version')
#   Found 0 dependencies
# [4/1351] Analyzing Freelander/Android_Data... Total found so far: 0
#   Found 0 dependencies
# [5/1351] Analyzing JakeWharton/hugo... Total found so far: 0
#   Found 0 dependencies
# [5/1351] Analyzing JakeWharton/hugo... Total found so far: 0
#   Found 0 dependencies
# [6/1351] Analyzing Meituan-Dianping/Leaf... Total found so far: 0
#   Found 0 dependencies
# [6/1351] Analyzing Meituan-Dianping/Leaf... Total found so far: 0
#   Found 0 dependencies
# [7/1351] Analyzing ityouknow/spring-cloud-examples... Total found so far: 0
#   Found 0 dependencies
# [7/1351] Analyzing ityouknow/spring-cloud-examples... Total found so far: 0
#   Found 0 dependencies
# [8/1351] Analyzing daimajia/NumberProgressBar... Total found so far: 0
#   Found 0 dependencies
# [8/1351] Analyzing daimajia/NumberProgressBar... Total found so far: 0
#   Found 0 dependencies
# [9/1351] Analyzing LandGrey/SpringBootVulExploit... Total found so far: 0
#   Found 0 dependencies
# [9/1351] Analyzing LandGrey/SpringBootVulExploit... Total found so far: 0
#   Found 0 dependencies
# [10/1351] Analyzing LaurieWired/GhidraMCP... Total found so far: 0
#   Found 0 dependencies
# [10/1351] Analyzing LaurieWired/GhidraMCP... Total found so far: 0
#   Found 0 dependencies
# [11/1351] Analyzing javastacks/spring-boot-best-practice... Total found so far: 0
#   Found 0 dependencies
# [11/1351] Analyzing javastacks/spring-boot-best-practice... Total found so far: 0
#   Found 0 dependencies
# [12/1351] Analyzing rubensousa/ViewPagerCards... Total found so far: 0
# [1339/1351] Analyzing jihor/hiatus-spring-boot... Total found so far: 193
#   Found 0 dependencies
# [1340/1351] Analyzing open-rnd/android-fragment-swapper... Total found so far: 193
#   Found 0 dependencies
# [1340/1351] Analyzing open-rnd/android-fragment-swapper... Total found so far: 193
#   Found 0 dependencies
# [1341/1351] Analyzing chalup/cerberus... Total found so far: 193
#   Found 0 dependencies
# [1341/1351] Analyzing chalup/cerberus... Total found so far: 193
#   Found 0 dependencies
# [1342/1351] Analyzing linux-china/spring-cloud-function-demo... Total found so far: 193
#   Found 0 dependencies
# [1342/1351] Analyzing linux-china/spring-cloud-function-demo... Total found so far: 193
#   Found 0 dependencies
# [1343/1351] Analyzing mohammadima3oud/BlueSignIn... Total found so far: 193
#   Found 0 dependencies
# [1343/1351] Analyzing mohammadima3oud/BlueSignIn... Total found so far: 193
#   Found 0 dependencies
# [1344/1351] Analyzing mikera/cljunit... Total found so far: 193
#   Found 0 dependencies
# [1344/1351] Analyzing mikera/cljunit... Total found so far: 193
#   Found 0 dependencies
# [1345/1351] Analyzing auth10/auth10-java... Total found so far: 193
#   Found 0 dependencies
# [1345/1351] Analyzing auth10/auth10-java... Total found so far: 193
#   Found 0 dependencies
# [1346/1351] Analyzing secoba/HLog... Total found so far: 193
#   Found 0 dependencies
# [1346/1351] Analyzing secoba/HLog... Total found so far: 193
#   Found 0 dependencies
# [1347/1351] Analyzing mtjsoft/UploadMultiImageView... Total found so far: 193
#   Found 0 dependencies
# [1347/1351] Analyzing mtjsoft/UploadMultiImageView... Total found so far: 193
#   Found 0 dependencies
# [1348/1351] Analyzing remobile/react-native-datetime-picker... Total found so far: 193
#   Found 0 dependencies
# [1348/1351] Analyzing remobile/react-native-datetime-picker... Total found so far: 193
#   Found 0 dependencies
# [1349/1351] Analyzing eBay/FeedSDK... Total found so far: 193
#   Found 0 dependencies
# [1349/1351] Analyzing eBay/FeedSDK... Total found so far: 193
#   Found 0 dependencies
# [1350/1351] Analyzing zulffaza/Spring-Cloud-Gateway-Routes-from-Database... Total found so far: 193
#   Found 0 dependencies
# [1350/1351] Analyzing zulffaza/Spring-Cloud-Gateway-Routes-from-Database... Total found so far: 193
#   Found 0 dependencies
# [1351/1351] Analyzing minbox-projects/grace... Total found so far: 193
#   Found 0 dependencies
# [1351/1351] Analyzing minbox-projects/grace... Total found so far: 193
#   Found 0 dependencies
# Dependency extraction complete!
# Total dependencies found: 193
# Saved 193 dependencies to /tmp/all_dependencies_simple.json
# Saved 143 unique dependencies to /tmp/unique_dependencies.json
#   Found 0 dependencies
# Dependency extraction complete!
# Total dependencies found: 193
# Saved 193 dependencies to /tmp/all_dependencies_simple.json
# Saved 143 unique dependencies to /tmp/unique_dependencies.json

# %%
unique_deps
# Out:
# {'${project.inspectGroup}:${project.inspectName}',
#  'androidx.annotation:annotation',
#  'androidx.core:core',
#  'biz.aQute.bnd:biz.aQute.bndlib',
#  'com.afollestad:material-dialogs',
#  'com.alibaba:fastjson',
#  'com.android.support.test.espresso:espresso-idling-resource',
#  'com.android.support:appcompat-v7',
#  'com.android.support:cardview-v7',
#  'com.android.support:design',
#  'com.android.support:gridlayout-v7',
#  'com.android.support:percent',
#  'com.android.support:recyclerview-v7',
#  'com.android.support:support-annotations',
#  'com.android.support:support-v4',
#  'com.badlogicgames.gdx:gdx',
#  'com.balysv:material-ripple',
#  'com.codahale.metrics:metrics-core',
#  'com.daimajia.androidanimations:library',
#  'com.daimajia.swipelayout:library',
#  'com.eventsourcing:eventsourcing-core',
#  'com.extracraftx.minecraft:TemplateMakerFabric',
#  'com.facebook.fresco:fresco',
#  'com.facebook.rebound:rebound',
#  'com.fasterxml.jackson.core:jackson-annotations',
#  'com.fasterxml.jackson.core:jackson-core',
#  'com.fasterxml.jackson.core:jackson-databind',
#  'com.fasterxml.jackson.datatype:jackson-datatype-jdk8',
#  'com.github.bumptech.glide:glide',
#  'com.github.chrisbanes.photoview:library',
#  'com.github.mikaelgrev.miglayout:miglayout-swing',
#  'com.github.rey5137:material',
#  'com.github.tibolte:elasticdownload',
#  'com.google.code.findbugs:annotations',
#  'com.google.code.gson:gson',
#  'com.google.guava:guava',
#  'com.google.truth:truth',
#  'com.graphql-java:graphql-java',
#  'com.graphql-java:graphql-java-annotations',
#  'com.graphql-java:graphql-java-servlet',
#  "com.h2database:h2'\n\n    runtimeOnly 'com.h2database",
#  'com.jakewharton.timber:timber',
#  'com.jakewharton:butterknife',
#  'com.madgag:animated-gif-lib',
#  'com.mcxiaoke.volley:library',
#  'com.ning:async-http-client',
#  'com.nispok:snackbar',
#  'com.nostra13.universalimageloader:universal-image-loader',
#  'com.oasisfeng.nevo:sdk',
#  'com.pnikosis:materialish-progress',
#  'com.readystatesoftware.systembartint:systembartint',
#  'com.squareup.okhttp3:mockwebserver',
#  'com.squareup.okhttp3:okhttp',
#  'com.squareup.okhttp:okhttp',
#  'com.squareup.okio:okio',
#  'com.squareup.picasso:picasso',
#  'com.squareup.retrofit2:retrofit',
#  'com.tngtech.archunit:archunit',
#  'com.unboundid:unboundid-ldapsdk',
#  'commons-codec:commons-codec',
#  'commons-fileupload:commons-fileupload',
#  'commons-io:commons-io',
#  'de.greenrobot:eventbus',
#  'de.greenrobot:greendao',
#  'de.hdodenhof:circleimageview',
#  'eu.chainfire:libsuperuser',
#  'io.github.qupath:qupath-gui-fx',
#  'io.jsonwebtoken:jjwt-api',
#  'io.micrometer:micrometer-registry-prometheus',
#  'io.netty:netty-all',
#  'io.projectreactor:reactor-core',
#  'io.projectreactor:reactor-test',
#  'io.prometheus:simpleclient',
#  'io.reactivex.rxjava3:rxjava',
#  'io.reactivex:rxjava',
#  'io.undertow:undertow-core',
#  'io.undertow:undertow-servlet',
#  'it.unimi.dsi:fastutil',
#  'jakarta.xml.bind:jakarta.xml.bind-api',
#  'javax.servlet:javax.servlet-api',
#  'javax.servlet:servlet-api',
#  'junit:junit',
#  'konifar:fab-transformation',
#  'net.bytebuddy:byte-buddy',
#  'net.imglib2:imglib2-realtransform',
#  'net.portswigger.burp.extender:burp-extender-api',
#  'net.sf.jopt-simple:jopt-simple',
#  'net.sf.trove4j:trove4j',
#  'net.sourceforge.streamsupport:android-retrostreams',
#  'org.apache.cassandra:cassandra-all',
#  'org.apache.commons:commons-lang3',
#  'org.apache.commons:commons-math3',
#  'org.apache.curator:curator-recipes',
#  'org.apache.hadoop:hadoop-client',
#  'org.apache.httpcomponents:httpclient',
#  'org.apache.httpcomponents:httpmime',
#  'org.apache.logging.log4j:log4j-api',
#  'org.apache.logging.log4j:log4j-core',
#  'org.apache.logging.log4j:log4j-slf4j-impl',
#  'org.assertj:assertj-core',
#  'org.codehaus.groovy:groovy-all',
#  'org.codehaus.jackson:jackson-mapper-asl',
#  'org.easytesting:fest-assert-core',
#  'org.eclipse.jetty:jetty-servlet',
#  'org.elasticsearch:elasticsearch',
#  'org.fusesource.jansi:jansi',
#  'org.hamcrest:hamcrest-core',
#  'org.jetbrains:annotations',
#  'org.jline:jline',
#  'org.json:json',
#  'org.junit.jupiter:junit-jupiter-api',
#  'org.junit.jupiter:junit-jupiter-engine',
#  'org.junit.platform:junit-platform-launcher',
#  'org.mockito:mockito-junit-jupiter',
#  'org.objenesis:objenesis',
#  'org.openjdk.jmh:jmh-core',
#  'org.openjdk.jmh:jmh-generator-annprocess',
#  'org.osgi:org.osgi.core',
#  'org.osgi:org.osgi.service.cm',
#  'org.osgi:org.osgi.service.component',
#  'org.ow2.asm:asm',
#  'org.ow2.asm:asm-commons',
#  'org.ow2.asm:asm-debug-all',
#  'org.projectlombok:lombok',
#  'org.reflections:reflections',
#  'org.robolectric:robolectric',
#  'org.slf4j:slf4j-api',
#  'org.slf4j:slf4j-log4j12',
#  'org.slf4j:slf4j-simple',
#  'org.spockframework:spock-core',
#  'org.springdoc:springdoc-openapi-starter-webmvc-ui',
#  "org.springframework.boot:spring-boot-starter-data-jpa'\n    implementation 'org.springframework.boot",
#  "org.springframework.boot:spring-boot-starter-security'\n    implementation 'org.springframework.boot",
#  "org.springframework.boot:spring-boot-starter-test'\n    testImplementation 'org.springframework.security",
#  "org.springframework.boot:spring-boot-starter-validation'\n    implementation 'org.springframework.boot",
#  "org.springframework.boot:spring-boot-starter-web'\n    implementation 'org.springframework.boot",
#  "org.springframework.boot:spring-boot-starter-web'\n    testImplementation('org.springframework.boot",
#  "org.springframework.boot:spring-boot-starter-web'\n  implementation 'org.springframework.boot",
#  'org.springframework.hateoas:spring-hateoas',
#  'org.springframework.shell:spring-shell',
#  'org.testcontainers:localstack',
#  'org.yaml:snakeyaml',
#  'redis.clients:jedis'}

# %%
import re
import xml.etree.ElementTree as ET
from urllib.parse import urlparse
import time

def extract_maven_dependencies(pom_content):
    """Extract dependencies from pom.xml content"""
    dependencies = []
    try:
        root = ET.fromstring(pom_content)
        # Handle namespaces
        ns = {'maven': 'http://maven.apache.org/POM/4.0.0'}
        
        # Find dependencies
        deps = root.findall('.//maven:dependency', ns) or root.findall('.//dependency')
        
        for dep in deps:
            group_id = dep.find('maven:groupId', ns) or dep.find('groupId')
            artifact_id = dep.find('maven:artifactId', ns) or dep.find('artifactId')
            version = dep.find('maven:version', ns) or dep.find('version')
            
            if group_id is not None and artifact_id is not None:
                dependencies.append({
                    'groupId': group_id.text,
                    'artifactId': artifact_id.text,
                    'version': version.text if version is not None else 'unknown'
                })
    except ET.ParseError:
        pass
    return dependencies

def extract_gradle_dependencies(gradle_content):
    """Extract dependencies from build.gradle content"""
    dependencies = []
    # Pattern to match various gradle dependency formats
    patterns = [
        r"implementation\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"compile\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"api\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]",
        r"testImplementation\s+['\"]([^:]+):([^:]+):([^'\"]+)['\"]"
    ]
    
    for pattern in patterns:
        matches = re.findall(pattern, gradle_content)
        for match in matches:
            dependencies.append({
                'groupId': match[0],
                'artifactId': match[1],
                'version': match[2]
            })
    return dependencies

def search_github_for_dependency(group_id, artifact_id):
    """Search GitHub for repositories that might contain this dependency"""
    search_query = f"language:Java {group_id} {artifact_id}"
    search_params = {
        "q": search_query,
        "sort": "stars",
        "order": "desc",
        "per_page": 3
    }
    try:
        response = requests.get(base_url, headers=headers, params=search_params)
        if response.status_code == 200:
            results = response.json().get("items", [])
            return [repo["full_name"] for repo in results]
    except:
        pass
    return []

def find_dependents(repo_full_name):
    """Find repositories that depend on this repository"""
    dependents = []
    # Search for repositories that mention this repo in their dependencies
    search_queries = [
        f"language:Java {repo_full_name.split('/')[1]} in:file filename:pom.xml",
        f"language:Java {repo_full_name.split('/')[1]} in:file filename:build.gradle"
    ]
    
    for query in search_queries:
        search_params = {
            "q": query,
            "sort": "stars",
            "order": "desc",
            "per_page": 10
        }
        try:
            response = requests.get("https://api.github.com/search/code", headers=headers, params=search_params)
            if response.status_code == 200:
                results = response.json().get("items", [])
                for item in results:
                    repo_name = item["repository"]["full_name"]
                    if repo_name != repo_full_name:
                        dependents.append(repo_name)
            time.sleep(0.1)  # Rate limiting
        except:
            pass
    
    return list(set(dependents))  # Remove duplicates

# Analyze dependencies and relationships for each repository


SRC_LAYER = 'layer1'
DST_LAYER = 'layer2'
try:
    for repo in repos[SRC_LAYER][580:]:
        if SRC_LAYER == 'layer1':
            repo_full_name = repo["full_name"]
        else:
            #checl if repo is a string
            if isinstance(repo, str):
                repo_full_name = repo
            else:
                repo_full_name = repo[0] # get just the first element if it's a list

        print(f"Analyzing {repo_full_name}...")
        
        try:
            # Get repository contents to find build files
            contents_url = f"https://api.github.com/repos/{repo_full_name}/contents"
            response = requests.get(contents_url, headers=headers)
            
            dependencies = []
            dependents = []
            
            if response.status_code == 200:
                contents = response.json()
                
                # Look for pom.xml
                pom_file = next((item for item in contents if item["name"] == "pom.xml"), None)
                if pom_file:
                    pom_response = requests.get(pom_file["download_url"])
                    if pom_response.status_code == 200:
                        dependencies.extend(extract_maven_dependencies(pom_response.text))
                
                # Look for build.gradle
                gradle_file = next((item for item in contents if item["name"] == "build.gradle"), None)
                if gradle_file:
                    gradle_response = requests.get(gradle_file["download_url"])
                    if gradle_response.status_code == 200:
                        dependencies.extend(extract_gradle_dependencies(gradle_response.text))
            
            # Find GitHub repositories for dependencies
            # for dep in dependencies:
            #     github_repos = search_github_for_dependency(dep['groupId'], dep['artifactId'])
            #     dep['potential_github_repos'] = github_repos
            #     time.sleep(0.1)  # Rate limiting
            
            # Find repositories that depend on this one
            dependents = find_dependents(repo_full_name)
            
            java_dependencies[DST_LAYER][repo_full_name] = dependencies
            repo_relationships[DST_LAYER][repo_full_name] = {
                'dependencies': dependencies,
                'dependents': dependents,
                'dependency_count': len(dependencies),
                'dependent_count': len(dependents)
            }

            # for dep in dependencies:
            #     if not already_exists(dep['potential_github_repos']):
            #         repos[DST_LAYER].append(dep['potential_github_repos'])
            
            for dep in dependents:
                if not already_exists(dep):
                    repos[DST_LAYER].append(dep)
            
            print(f"  Found {len(dependencies)} dependencies and {len(dependents)} dependents")
            time.sleep(.1)  # Rate limiting between repos
        except Exception as e:
            print(f"  Error analyzing {repo_full_name}: {e}")
            continue

    print("Analysis complete!")
except Exception as e:
    print(f"An error occurred: {e}")
finally:

    # Save the analysis results to a JSON file
    with open("/tmp/java_repo_analysis.json", "w") as f:
        json.dump({
            "java_dependencies": java_dependencies,
            "repo_relationships": repo_relationships
        }, f, indent=2)

    # save also repos
    with open("/tmp/java_repos_with_dependencies.json", "w") as f:
        json.dump(repos, f, indent=2)
# Out:
# Analyzing mimicmobile/okhttp-oauth2-client...
#   Found 0 dependencies and 0 dependents
# Analyzing pbakondy/cordova-plugin-speechrecognition...
#   Found 0 dependencies and 0 dependents
# Analyzing pbakondy/cordova-plugin-speechrecognition...
#   Found 0 dependencies and 0 dependents
# Analyzing LinkedBear/spring-framework-learning-code...
#   Found 0 dependencies and 0 dependents
# Analyzing LinkedBear/spring-framework-learning-code...
#   Found 0 dependencies and 0 dependents
# Analyzing alphamu/android-widget-fanmenu...
#   Found 0 dependencies and 0 dependents
# Analyzing alphamu/android-widget-fanmenu...
#   Found 0 dependencies and 0 dependents
# Analyzing gwenn/sqlite-dialect...
#   Found 0 dependencies and 0 dependents
# Analyzing gwenn/sqlite-dialect...
# /tmp/ipykernel_114059/1344935161.py:18: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   group_id = dep.find('maven:groupId', ns) or dep.find('groupId')
# /tmp/ipykernel_114059/1344935161.py:19: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   artifact_id = dep.find('maven:artifactId', ns) or dep.find('artifactId')
# /tmp/ipykernel_114059/1344935161.py:20: DeprecationWarning: Testing an element's truth value will always return True in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   version = dep.find('maven:version', ns) or dep.find('version')
#   Found 0 dependencies and 0 dependents
# Analyzing jMavarez/MaterialCalendar...
#   Found 0 dependencies and 0 dependents
# Analyzing pyloque/rpckids...
#   Found 0 dependencies and 0 dependents
# Analyzing pyloque/rpckids...
#   Found 0 dependencies and 0 dependents
# Analyzing AnotherJack/AvoidOnResult...
#   Found 0 dependencies and 0 dependents
# Analyzing AnotherJack/AvoidOnResult...
#   Found 0 dependencies and 0 dependents
# Analyzing wangchenyan/html-text...
#   Found 0 dependencies and 0 dependents
# Analyzing wangchenyan/html-text...
#   Found 0 dependencies and 0 dependents
# Analyzing Lovelcp/spring-boot-mybatis-with-redis...
#   Found 0 dependencies and 0 dependents
# Analyzing Lovelcp/spring-boot-mybatis-with-redis...
#   Found 0 dependencies and 0 dependents
# Analyzing itbaima-study/SpringBoot-Vue-Template-Session...
#   Found 0 dependencies and 0 dependents
# Analyzing itbaima-study/SpringBoot-Vue-Template-Session...
#   Found 0 dependencies and 0 dependents
# Analyzing sockeqwe/AnnotatedAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing sockeqwe/AnnotatedAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing it-gorillaz/lnk2pwn...
#   Found 0 dependencies and 0 dependents
# Analyzing it-gorillaz/lnk2pwn...
#   Found 0 dependencies and 0 dependents
# Analyzing anyunzhong/AndroidTimelineView...
#   Found 0 dependencies and 0 dependents
# Analyzing anyunzhong/AndroidTimelineView...
#   Found 0 dependencies and 0 dependents
# Analyzing gzsll/WebViewJavascriptBridge...
#   Found 0 dependencies and 0 dependents
# Analyzing gzsll/WebViewJavascriptBridge...
#   Found 0 dependencies and 0 dependents
# Analyzing fashare2015/HoverView...
#   Found 0 dependencies and 0 dependents
# Analyzing fashare2015/HoverView...
#   Found 0 dependencies and 0 dependents
# Analyzing kiwi-bop/flutter_crashlytics...
#   Found 0 dependencies and 0 dependents
# Analyzing kiwi-bop/flutter_crashlytics...
#   Found 0 dependencies and 0 dependents
# Analyzing vojtechruz/spring-core-cert-notes-4.2...
#   Found 0 dependencies and 0 dependents
# Analyzing vojtechruz/spring-core-cert-notes-4.2...
#   Found 0 dependencies and 0 dependents
# Analyzing canyie/MagiskKiller...
#   Found 0 dependencies and 0 dependents
# Analyzing canyie/MagiskKiller...
#   Found 0 dependencies and 0 dependents
# Analyzing sunnj/story-admin...
#   Found 0 dependencies and 0 dependents
# Analyzing sunnj/story-admin...
#   Found 0 dependencies and 0 dependents
# Analyzing Takhion/renderthread...
#   Found 0 dependencies and 0 dependents
# Analyzing Takhion/renderthread...
#   Error analyzing Takhion/renderthread: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing segunfamisa/bottom-navigation-demo...
#   Error analyzing Takhion/renderthread: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing segunfamisa/bottom-navigation-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing CryptoKass/NoobChain-Tutorial-Part-2...
#   Found 0 dependencies and 0 dependents
# Analyzing CryptoKass/NoobChain-Tutorial-Part-2...
#   Found 0 dependencies and 0 dependents
# Analyzing chiralcode/Android-Color-Picker...
#   Found 0 dependencies and 0 dependents
# Analyzing chiralcode/Android-Color-Picker...
#   Found 0 dependencies and 0 dependents
# Analyzing jsvazic/GAHelloWorld...
#   Found 0 dependencies and 0 dependents
# Analyzing jsvazic/GAHelloWorld...
#   Found 0 dependencies and 0 dependents
# Analyzing chaychan/MultipleItemRvAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing chaychan/MultipleItemRvAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing lenve/vhr2.0...
#   Found 0 dependencies and 0 dependents
# Analyzing lenve/vhr2.0...
#   Found 0 dependencies and 0 dependents
# Analyzing w3blogfr/zebra-zpl...
#   Found 0 dependencies and 0 dependents
# Analyzing w3blogfr/zebra-zpl...
#   Error analyzing w3blogfr/zebra-zpl: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing mthiim/dilithium-java...
#   Error analyzing w3blogfr/zebra-zpl: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing mthiim/dilithium-java...
#   Found 0 dependencies and 0 dependents
# Analyzing jonashackt/tutorial-soap-spring-boot-cxf...
#   Found 0 dependencies and 0 dependents
# Analyzing jonashackt/tutorial-soap-spring-boot-cxf...
#   Found 0 dependencies and 0 dependents
# Analyzing MyBeany/mySpringBoot...
#   Found 0 dependencies and 0 dependents
# Analyzing MyBeany/mySpringBoot...
#   Found 0 dependencies and 0 dependents
# Analyzing saki4510t/ScreenRecordingSample...
#   Found 0 dependencies and 0 dependents
# Analyzing saki4510t/ScreenRecordingSample...
#   Found 0 dependencies and 0 dependents
# Analyzing godot-sdk-integrations/godot-google-play-billing...
#   Found 0 dependencies and 0 dependents
# Analyzing godot-sdk-integrations/godot-google-play-billing...
#   Found 0 dependencies and 0 dependents
# Analyzing amaurycrickx/recognito...
#   Found 0 dependencies and 0 dependents
# Analyzing amaurycrickx/recognito...
#   Found 0 dependencies and 0 dependents
# Analyzing depycode/fastjson-local-echo...
#   Found 0 dependencies and 0 dependents
# Analyzing depycode/fastjson-local-echo...
#   Found 0 dependencies and 0 dependents
# Analyzing bjmashibing/NettyStudy...
#   Found 0 dependencies and 0 dependents
# Analyzing bjmashibing/NettyStudy...
#   Found 0 dependencies and 0 dependents
# Analyzing xujijun/spring-boot-101...
#   Found 0 dependencies and 0 dependents
# Analyzing xujijun/spring-boot-101...
#   Found 0 dependencies and 0 dependents
# Analyzing chrisblakely01/java-spring-microservices...
#   Found 0 dependencies and 0 dependents
# Analyzing chrisblakely01/java-spring-microservices...
#   Found 0 dependencies and 0 dependents
# Analyzing OmniOneID/did-common-sdk-server...
#   Found 0 dependencies and 0 dependents
# Analyzing OmniOneID/did-common-sdk-server...
#   Found 0 dependencies and 0 dependents
# Analyzing Leliana/WhatsThis...
#   Found 0 dependencies and 0 dependents
# Analyzing Leliana/WhatsThis...
#   Found 0 dependencies and 0 dependents
# Analyzing balamaci/rxjava-walkthrough...
#   Found 0 dependencies and 0 dependents
# Analyzing balamaci/rxjava-walkthrough...
#   Found 0 dependencies and 0 dependents
# Analyzing tjake/rbm-dbn-mnist...
#   Found 0 dependencies and 0 dependents
# Analyzing tjake/rbm-dbn-mnist...
#   Found 0 dependencies and 0 dependents
# Analyzing edwardcapriolo/filecrush...
#   Found 0 dependencies and 0 dependents
# Analyzing edwardcapriolo/filecrush...
#   Found 0 dependencies and 0 dependents
# Analyzing RameshMF/registration-login-spring-boot-security-thymeleaf-hibernate...
#   Found 0 dependencies and 0 dependents
# Analyzing RameshMF/registration-login-spring-boot-security-thymeleaf-hibernate...
#   Found 0 dependencies and 0 dependents
# Analyzing leechenxiang/imooc-springboot-wxlogin...
#   Found 0 dependencies and 0 dependents
# Analyzing leechenxiang/imooc-springboot-wxlogin...
#   Found 0 dependencies and 0 dependents
# Analyzing ricvalerio/foregroundappchecker...
#   Found 0 dependencies and 0 dependents
# Analyzing ricvalerio/foregroundappchecker...
#   Found 0 dependencies and 0 dependents
# Analyzing aliyun/aliyun-log-logback-appender...
#   Found 0 dependencies and 0 dependents
# Analyzing aliyun/aliyun-log-logback-appender...
#   Found 0 dependencies and 0 dependents
# Analyzing trunks2008/xxl-job-auto-register...
#   Found 0 dependencies and 0 dependents
# Analyzing trunks2008/xxl-job-auto-register...
#   Found 0 dependencies and 0 dependents
# Analyzing geminiwen/AndroidCubeDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing geminiwen/AndroidCubeDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing forcesunseen/graphquail...
#   Found 0 dependencies and 0 dependents
# Analyzing forcesunseen/graphquail...
#   Found 5 dependencies and 0 dependents
# Analyzing peekler/GDG...
#   Found 5 dependencies and 0 dependents
# Analyzing peekler/GDG...
#   Found 0 dependencies and 0 dependents
# Analyzing Veal98/RPC-FromScratch...
#   Found 0 dependencies and 0 dependents
# Analyzing Veal98/RPC-FromScratch...
#   Found 0 dependencies and 0 dependents
# Analyzing JakeWharton/retrofit1-okhttp3-client...
#   Found 0 dependencies and 0 dependents
# Analyzing JakeWharton/retrofit1-okhttp3-client...
#   Found 0 dependencies and 0 dependents
# Analyzing EdisonTalk/EDT.SpringCloud.Samples...
#   Found 0 dependencies and 0 dependents
# Analyzing EdisonTalk/EDT.SpringCloud.Samples...
#   Found 0 dependencies and 0 dependents
# Analyzing BazingaLyn/netty-study...
#   Found 0 dependencies and 0 dependents
# Analyzing BazingaLyn/netty-study...
#   Found 0 dependencies and 0 dependents
# Analyzing iffa/wrapping-viewpager...
#   Found 0 dependencies and 0 dependents
# Analyzing iffa/wrapping-viewpager...
#   Found 0 dependencies and 0 dependents
# Analyzing simplesteph/ec2-masterclass-sampleapp...
#   Found 0 dependencies and 0 dependents
# Analyzing simplesteph/ec2-masterclass-sampleapp...
#   Found 0 dependencies and 0 dependents
# Analyzing jpbaterabsb/java-avancado...
#   Found 0 dependencies and 0 dependents
# Analyzing jpbaterabsb/java-avancado...
#   Found 0 dependencies and 0 dependents
# Analyzing jhyscode/ssm-BookAppointment...
#   Found 0 dependencies and 0 dependents
# Analyzing jhyscode/ssm-BookAppointment...
#   Found 0 dependencies and 0 dependents
# Analyzing woodpecker-appstore/jexpr-encoder-utils...
#   Found 0 dependencies and 0 dependents
# Analyzing woodpecker-appstore/jexpr-encoder-utils...
#   Found 0 dependencies and 0 dependents
# Analyzing odrotbohm/arch-evident-spring...
#   Found 0 dependencies and 0 dependents
# Analyzing odrotbohm/arch-evident-spring...
#   Found 0 dependencies and 0 dependents
# Analyzing Smith-Cruise/Spring-Boot-Security-JWT-SPA...
#   Found 0 dependencies and 0 dependents
# Analyzing Smith-Cruise/Spring-Boot-Security-JWT-SPA...
#   Found 0 dependencies and 0 dependents
# Analyzing shmilyah/spring-cloud-components...
#   Found 0 dependencies and 0 dependents
# Analyzing shmilyah/spring-cloud-components...
#   Found 0 dependencies and 0 dependents
# Analyzing JessYanCoding/CameraFilters...
#   Found 0 dependencies and 0 dependents
# Analyzing JessYanCoding/CameraFilters...
#   Found 0 dependencies and 0 dependents
# Analyzing ZieIony/NaturalDateFormat...
#   Found 0 dependencies and 0 dependents
# Analyzing ZieIony/NaturalDateFormat...
#   Found 0 dependencies and 0 dependents
# Analyzing simplesteph/kafka-avro-course...
#   Found 0 dependencies and 0 dependents
# Analyzing simplesteph/kafka-avro-course...
#   Found 0 dependencies and 0 dependents
# Analyzing Noisyfox/NoExclamation...
#   Found 0 dependencies and 0 dependents
# Analyzing Noisyfox/NoExclamation...
#   Found 0 dependencies and 0 dependents
# Analyzing mengday/springboot-pay-example...
#   Found 0 dependencies and 0 dependents
# Analyzing mengday/springboot-pay-example...
#   Found 0 dependencies and 0 dependents
# Analyzing luisfcofv/competitive-programming-book...
#   Found 0 dependencies and 0 dependents
# Analyzing luisfcofv/competitive-programming-book...
#   Found 0 dependencies and 0 dependents
# Analyzing beykery/jkcp...
#   Found 0 dependencies and 0 dependents
# Analyzing beykery/jkcp...
#   Found 0 dependencies and 0 dependents
# Analyzing hypirion/inlein...
#   Found 0 dependencies and 0 dependents
# Analyzing hypirion/inlein...
#   Found 0 dependencies and 0 dependents
# Analyzing reljicd/spring-boot-blog...
#   Found 0 dependencies and 0 dependents
# Analyzing reljicd/spring-boot-blog...
#   Found 0 dependencies and 0 dependents
# Analyzing oxylabs/youtube-scraper...
#   Found 0 dependencies and 0 dependents
# Analyzing oxylabs/youtube-scraper...
#   Found 0 dependencies and 0 dependents
# Analyzing pristineio/webrtc-android...
#   Found 0 dependencies and 0 dependents
# Analyzing pristineio/webrtc-android...
#   Found 0 dependencies and 0 dependents
# Analyzing kylelin1998/ChatGPTForTelegram...
#   Found 0 dependencies and 0 dependents
# Analyzing kylelin1998/ChatGPTForTelegram...
#   Error analyzing kylelin1998/ChatGPTForTelegram: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing gybin02/RouterKit...
#   Error analyzing kylelin1998/ChatGPTForTelegram: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing gybin02/RouterKit...
#   Found 0 dependencies and 0 dependents
# Analyzing Blankeer/XAndroidSocket...
#   Found 0 dependencies and 0 dependents
# Analyzing Blankeer/XAndroidSocket...
#   Found 0 dependencies and 0 dependents
# Analyzing gilbutITbook/080337...
#   Found 0 dependencies and 0 dependents
# Analyzing gilbutITbook/080337...
#   Found 0 dependencies and 0 dependents
# Analyzing Purus/launch_review...
#   Found 0 dependencies and 0 dependents
# Analyzing Purus/launch_review...
#   Found 0 dependencies and 0 dependents
# Analyzing achenglike/NightModel...
#   Found 0 dependencies and 0 dependents
# Analyzing achenglike/NightModel...
#   Found 0 dependencies and 0 dependents
# Analyzing litesuits/android-lite-go...
#   Found 0 dependencies and 0 dependents
# Analyzing litesuits/android-lite-go...
#   Found 0 dependencies and 0 dependents
# Analyzing fordes123/ad-filters-subscriber...
#   Found 0 dependencies and 0 dependents
# Analyzing fordes123/ad-filters-subscriber...
#   Found 0 dependencies and 0 dependents
# Analyzing darconeous/gauss-key-card...
#   Found 0 dependencies and 0 dependents
# Analyzing darconeous/gauss-key-card...
#   Found 0 dependencies and 0 dependents
# Analyzing mrprince/sonar-p3c-pmd...
#   Found 0 dependencies and 0 dependents
# Analyzing mrprince/sonar-p3c-pmd...
#   Found 0 dependencies and 0 dependents
# Analyzing ChrisMayfield/ThinkJavaCode2...
#   Found 0 dependencies and 0 dependents
# Analyzing ChrisMayfield/ThinkJavaCode2...
#   Found 0 dependencies and 0 dependents
# Analyzing fooock/phone-tracker...
#   Found 0 dependencies and 0 dependents
# Analyzing fooock/phone-tracker...
#   Found 0 dependencies and 0 dependents
# Analyzing NiaNingXue/SearchAnimation...
#   Found 0 dependencies and 0 dependents
# Analyzing NiaNingXue/SearchAnimation...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/commodore...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/commodore...
#   Found 0 dependencies and 0 dependents
# Analyzing apache/dubbo-rpc-jsonrpc...
#   Found 0 dependencies and 0 dependents
# Analyzing apache/dubbo-rpc-jsonrpc...
#   Found 0 dependencies and 0 dependents
# Analyzing microbun/elasticsearch-thulac-plugin...
#   Found 0 dependencies and 0 dependents
# Analyzing microbun/elasticsearch-thulac-plugin...
#   Found 1 dependencies and 0 dependents
# Analyzing callicoder/java-snowflake...
#   Found 1 dependencies and 0 dependents
# Analyzing callicoder/java-snowflake...
#   Found 0 dependencies and 0 dependents
# Analyzing v5tech/elasticsearch-jest-example...
#   Found 0 dependencies and 0 dependents
# Analyzing v5tech/elasticsearch-jest-example...
#   Found 0 dependencies and 0 dependents
# Analyzing codesofun/web-bee...
#   Found 0 dependencies and 0 dependents
# Analyzing codesofun/web-bee...
#   Found 0 dependencies and 0 dependents
# Analyzing microg/Phonesky...
#   Found 0 dependencies and 0 dependents
# Analyzing microg/Phonesky...
#   Found 0 dependencies and 0 dependents
# Analyzing kantega/notsoserial...
#   Found 0 dependencies and 0 dependents
# Analyzing kantega/notsoserial...
#   Found 0 dependencies and 0 dependents
# Analyzing Gavin-ZYX/asmDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing Gavin-ZYX/asmDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing paypal/resteasy-spring-boot...
#   Found 0 dependencies and 0 dependents
# Analyzing paypal/resteasy-spring-boot...
#   Found 0 dependencies and 0 dependents
# Analyzing zubricky/react-native-android-keyboard-adjust...
#   Found 0 dependencies and 0 dependents
# Analyzing zubricky/react-native-android-keyboard-adjust...
#   Found 0 dependencies and 0 dependents
# Analyzing kelasterbuka/JAVA_dasar_programming...
#   Found 0 dependencies and 0 dependents
# Analyzing kelasterbuka/JAVA_dasar_programming...
#   Found 0 dependencies and 0 dependents
# Analyzing csanuragjain/APKRepatcher...
#   Found 0 dependencies and 0 dependents
# Analyzing csanuragjain/APKRepatcher...
#   Found 0 dependencies and 0 dependents
# Analyzing jantent/springbootRedis...
#   Found 0 dependencies and 0 dependents
# Analyzing jantent/springbootRedis...
#   Error analyzing jantent/springbootRedis: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing frogermcs/RecyclerViewAnimations...
#   Error analyzing jantent/springbootRedis: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Analyzing frogermcs/RecyclerViewAnimations...
#   Found 0 dependencies and 0 dependents
# Analyzing RichardWarburton/slab...
#   Found 0 dependencies and 0 dependents
# Analyzing RichardWarburton/slab...
#   Found 0 dependencies and 0 dependents
# Analyzing NoCodeNoWife/LLRiseTabBar-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing NoCodeNoWife/LLRiseTabBar-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing domi007/silentSMS...
#   Found 0 dependencies and 0 dependents
# Analyzing domi007/silentSMS...
#   Found 0 dependencies and 0 dependents
# Analyzing CrackerCat/FartExt...
#   Found 0 dependencies and 0 dependents
# Analyzing CrackerCat/FartExt...
#   Found 0 dependencies and 0 dependents
# Analyzing lucky-bai/MSolver...
#   Found 0 dependencies and 0 dependents
# Analyzing lucky-bai/MSolver...
#   Found 0 dependencies and 0 dependents
# Analyzing greysonp/permiso...
#   Found 0 dependencies and 0 dependents
# Analyzing greysonp/permiso...
#   Found 0 dependencies and 0 dependents
# Analyzing blondiebytes/30-Days-of-Code...
#   Found 0 dependencies and 0 dependents
# Analyzing blondiebytes/30-Days-of-Code...
#   Found 0 dependencies and 0 dependents
# Analyzing Mojang/slicer...
#   Found 0 dependencies and 0 dependents
# Analyzing Mojang/slicer...
#   Found 0 dependencies and 0 dependents
# Analyzing itsMelo/WcAutoReply...
#   Found 0 dependencies and 0 dependents
# Analyzing itsMelo/WcAutoReply...
#   Found 0 dependencies and 0 dependents
# Analyzing zhangtaii/react-native-google-place-picker...
#   Found 0 dependencies and 0 dependents
# Analyzing zhangtaii/react-native-google-place-picker...
#   Found 0 dependencies and 0 dependents
# Analyzing dlew/android-gridlayout...
#   Found 0 dependencies and 0 dependents
# Analyzing dlew/android-gridlayout...
#   Found 0 dependencies and 0 dependents
# Analyzing arestory/JarvisDownloader...
#   Found 0 dependencies and 0 dependents
# Analyzing arestory/JarvisDownloader...
#   Found 0 dependencies and 0 dependents
# Analyzing leandrosnazareth/pdv-api...
#   Found 0 dependencies and 0 dependents
# Analyzing leandrosnazareth/pdv-api...
#   Found 0 dependencies and 0 dependents
# Analyzing henrymorgen/android-advanced-decode...
#   Found 0 dependencies and 0 dependents
# Analyzing henrymorgen/android-advanced-decode...
#   Found 0 dependencies and 0 dependents
# Analyzing OmniOneID/did-crypto-sdk-server...
#   Found 0 dependencies and 0 dependents
# Analyzing OmniOneID/did-crypto-sdk-server...
#   Found 0 dependencies and 0 dependents
# Analyzing r00t4dm/aLIEz...
#   Found 0 dependencies and 0 dependents
# Analyzing r00t4dm/aLIEz...
#   Found 0 dependencies and 0 dependents
# Analyzing Dreamroute/locker...
#   Found 0 dependencies and 0 dependents
# Analyzing Dreamroute/locker...
#   Found 0 dependencies and 0 dependents
# Analyzing rohfosho/CordovaCallNumberPlugin...
#   Found 0 dependencies and 0 dependents
# Analyzing rohfosho/CordovaCallNumberPlugin...
#   Found 0 dependencies and 0 dependents
# Analyzing sparrow007/BlurImage...
#   Found 0 dependencies and 0 dependents
# Analyzing sparrow007/BlurImage...
#   Found 0 dependencies and 0 dependents
# Analyzing g00glen00b/ng-spring-boot...
#   Found 0 dependencies and 0 dependents
# Analyzing g00glen00b/ng-spring-boot...
#   Found 0 dependencies and 0 dependents
# Analyzing zhonglinlin1305/spring-boot-sample...
#   Found 0 dependencies and 0 dependents
# Analyzing zhonglinlin1305/spring-boot-sample...
#   Found 0 dependencies and 0 dependents
# Analyzing nantaphop/HoverTouchView...
#   Found 0 dependencies and 0 dependents
# Analyzing nantaphop/HoverTouchView...
#   Found 0 dependencies and 0 dependents
# Analyzing GF-Allen/RecordView...
#   Found 0 dependencies and 0 dependents
# Analyzing GF-Allen/RecordView...
#   Found 0 dependencies and 0 dependents
# Analyzing javagl/Obj...
#   Found 0 dependencies and 0 dependents
# Analyzing javagl/Obj...
#   Found 0 dependencies and 0 dependents
# Analyzing AxonFramework/AxonBank...
#   Found 0 dependencies and 0 dependents
# Analyzing AxonFramework/AxonBank...
#   Found 0 dependencies and 0 dependents
# Analyzing brettwooldridge/HikariCP-benchmark...
#   Found 0 dependencies and 0 dependents
# Analyzing brettwooldridge/HikariCP-benchmark...
#   Found 0 dependencies and 0 dependents
# Analyzing UglyTroLL/Douban-Java-SDK-OAuth2...
#   Found 0 dependencies and 0 dependents
# Analyzing UglyTroLL/Douban-Java-SDK-OAuth2...
#   Found 0 dependencies and 0 dependents
# Analyzing InventivetalentDev/AnimatedFrames...
#   Found 0 dependencies and 0 dependents
# Analyzing InventivetalentDev/AnimatedFrames...
#   Found 0 dependencies and 0 dependents
# Analyzing PaXLiCh/FormattEditText...
#   Found 0 dependencies and 0 dependents
# Analyzing PaXLiCh/FormattEditText...
#   Found 0 dependencies and 0 dependents
# Analyzing SweetInk/jrebel-mybatisplus...
#   Found 0 dependencies and 0 dependents
# Analyzing SweetInk/jrebel-mybatisplus...
#   Found 0 dependencies and 0 dependents
# Analyzing tterrag1098/BON2...
#   Found 0 dependencies and 0 dependents
# Analyzing tterrag1098/BON2...
#   Found 3 dependencies and 0 dependents
# Analyzing forcedotcom/EMP-Connector...
#   Found 3 dependencies and 0 dependents
# Analyzing forcedotcom/EMP-Connector...
#   Found 0 dependencies and 0 dependents
# Analyzing yuqirong/FlexibleSearchBar...
#   Found 0 dependencies and 0 dependents
# Analyzing yuqirong/FlexibleSearchBar...
#   Found 0 dependencies and 0 dependents
# Analyzing smallnest/ZKRecipesByExample...
#   Found 0 dependencies and 0 dependents
# Analyzing smallnest/ZKRecipesByExample...
#   Found 0 dependencies and 0 dependents
# Analyzing dpaukov/combinatoricslib3...
#   Found 0 dependencies and 0 dependents
# Analyzing dpaukov/combinatoricslib3...
#   Found 0 dependencies and 0 dependents
# Analyzing mcfunley/juds...
#   Found 0 dependencies and 0 dependents
# Analyzing mcfunley/juds...
#   Found 0 dependencies and 0 dependents
# Analyzing VDavid003/sm64-port-android-base...
#   Found 0 dependencies and 0 dependents
# Analyzing VDavid003/sm64-port-android-base...
#   Found 0 dependencies and 0 dependents
# Analyzing RomanIakovlev/timeshape...
#   Found 0 dependencies and 0 dependents
# Analyzing RomanIakovlev/timeshape...
#   Found 0 dependencies and 0 dependents
# Analyzing jimmysuncpt/AppBadge...
#   Found 0 dependencies and 0 dependents
# Analyzing jimmysuncpt/AppBadge...
#   Found 0 dependencies and 0 dependents
# Analyzing unixzii/android-FancyBehaviorDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing unixzii/android-FancyBehaviorDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing jiangcaijun/ssm...
#   Found 0 dependencies and 0 dependents
# Analyzing jiangcaijun/ssm...
#   Found 0 dependencies and 0 dependents
# Analyzing Ramos-dev/graph4code...
#   Found 0 dependencies and 0 dependents
# Analyzing Ramos-dev/graph4code...
#   Found 0 dependencies and 0 dependents
# Analyzing tuacy/RecyclerPinnedHeader...
#   Found 0 dependencies and 0 dependents
# Analyzing tuacy/RecyclerPinnedHeader...
#   Found 0 dependencies and 0 dependents
# Analyzing ganchaoyang/spring-tutorial...
#   Found 0 dependencies and 0 dependents
# Analyzing ganchaoyang/spring-tutorial...
#   Found 0 dependencies and 0 dependents
# Analyzing robbertvanwaveren/boot-stateless-auth...
#   Found 0 dependencies and 0 dependents
# Analyzing robbertvanwaveren/boot-stateless-auth...
#   Found 0 dependencies and 0 dependents
# Analyzing WuDi-ZhanShen/ScreenOff...
#   Found 0 dependencies and 0 dependents
# Analyzing WuDi-ZhanShen/ScreenOff...
#   Found 0 dependencies and 0 dependents
# Analyzing harryjph/android-bluetooth-serial...
#   Found 0 dependencies and 0 dependents
# Analyzing harryjph/android-bluetooth-serial...
#   Found 0 dependencies and 0 dependents
# Analyzing jonatan-kazmierczak/class-visualizer...
#   Found 0 dependencies and 0 dependents
# Analyzing jonatan-kazmierczak/class-visualizer...
#   Found 0 dependencies and 0 dependents
# Analyzing shehuan/DUtil...
#   Found 0 dependencies and 0 dependents
# Analyzing shehuan/DUtil...
#   Found 0 dependencies and 0 dependents
# Analyzing thymeleaf/thymeleafexamples-stsm...
#   Found 0 dependencies and 0 dependents
# Analyzing thymeleaf/thymeleafexamples-stsm...
#   Found 0 dependencies and 0 dependents
# Analyzing xiaofeng-han/AndroidLibs...
#   Found 0 dependencies and 0 dependents
# Analyzing xiaofeng-han/AndroidLibs...
#   Found 0 dependencies and 0 dependents
# Analyzing JakeWharton/retrofit2-reactor-adapter...
#   Found 0 dependencies and 0 dependents
# Analyzing JakeWharton/retrofit2-reactor-adapter...
#   Found 7 dependencies and 0 dependents
# Analyzing blakey22/shadowsocks-java...
#   Found 7 dependencies and 0 dependents
# Analyzing blakey22/shadowsocks-java...
#   Found 0 dependencies and 0 dependents
# Analyzing Korilakkuma/CanvasView...
#   Found 0 dependencies and 0 dependents
# Analyzing Korilakkuma/CanvasView...
#   Found 0 dependencies and 0 dependents
# Analyzing bojiangzhou/lyyzoo-fastdfs-java...
#   Found 0 dependencies and 0 dependents
# Analyzing bojiangzhou/lyyzoo-fastdfs-java...
#   Found 0 dependencies and 0 dependents
# Analyzing sevenshal/oksharedprefs...
#   Found 0 dependencies and 0 dependents
# Analyzing sevenshal/oksharedprefs...
#   Found 0 dependencies and 0 dependents
# Analyzing gpedro/slack-webhook...
#   Found 0 dependencies and 0 dependents
# Analyzing gpedro/slack-webhook...
#   Found 0 dependencies and 0 dependents
# Analyzing dziadeusz/hexagonal-architecture-by-example...
#   Found 0 dependencies and 0 dependents
# Analyzing dziadeusz/hexagonal-architecture-by-example...
#   Found 1 dependencies and 0 dependents
# Analyzing davecom/ClassicComputerScienceProblemsInJava...
#   Found 1 dependencies and 0 dependents
# Analyzing davecom/ClassicComputerScienceProblemsInJava...
#   Found 0 dependencies and 0 dependents
# Analyzing jeffreyscarpenter/cassandra-guide...
#   Found 0 dependencies and 0 dependents
# Analyzing jeffreyscarpenter/cassandra-guide...
#   Found 0 dependencies and 0 dependents
# Analyzing BlueDriver/questionnaire_online...
#   Found 0 dependencies and 0 dependents
# Analyzing BlueDriver/questionnaire_online...
#   Found 0 dependencies and 0 dependents
# Analyzing wongcain/metronome-android...
#   Found 0 dependencies and 0 dependents
# Analyzing wongcain/metronome-android...
#   Found 0 dependencies and 0 dependents
# Analyzing Lloyd0577/MVPDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing Lloyd0577/MVPDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing ZhuangM/student...
#   Found 0 dependencies and 0 dependents
# Analyzing ZhuangM/student...
#   Found 0 dependencies and 0 dependents
# Analyzing mxdldev/android-mvp-dagger2-flytranslate...
#   Found 0 dependencies and 0 dependents
# Analyzing mxdldev/android-mvp-dagger2-flytranslate...
#   Found 0 dependencies and 0 dependents
# Analyzing rockswang/java-curl...
#   Found 0 dependencies and 0 dependents
# Analyzing rockswang/java-curl...
#   Found 0 dependencies and 0 dependents
# Analyzing zsdlove/fortify-license-crack...
#   Found 0 dependencies and 0 dependents
# Analyzing zsdlove/fortify-license-crack...
#   Found 0 dependencies and 0 dependents
# Analyzing koushikkothagal/spring-security-jpa...
#   Found 0 dependencies and 0 dependents
# Analyzing koushikkothagal/spring-security-jpa...
#   Found 0 dependencies and 0 dependents
# Analyzing 4Q-s-r-o/ota_update...
#   Found 0 dependencies and 0 dependents
# Analyzing 4Q-s-r-o/ota_update...
#   Found 0 dependencies and 0 dependents
# Analyzing proselytear/jwtappdemo...
#   Found 0 dependencies and 0 dependents
# Analyzing proselytear/jwtappdemo...
#   Found 0 dependencies and 0 dependents
# Analyzing eternity-oop/Woowahan-OO-02-domain-service...
#   Found 0 dependencies and 0 dependents
# Analyzing eternity-oop/Woowahan-OO-02-domain-service...
#   Found 0 dependencies and 0 dependents
# Analyzing electronicarts/ea-agent-loader...
#   Found 0 dependencies and 0 dependents
# Analyzing electronicarts/ea-agent-loader...
#   Found 0 dependencies and 0 dependents
# Analyzing romseygeek/samza-luwak...
#   Found 0 dependencies and 0 dependents
# Analyzing romseygeek/samza-luwak...
#   Found 0 dependencies and 0 dependents
# Analyzing frost373/w2j-cli...
#   Found 0 dependencies and 0 dependents
# Analyzing frost373/w2j-cli...
#   Found 0 dependencies and 0 dependents
# Analyzing codelibs/ranklib...
#   Found 0 dependencies and 0 dependents
# Analyzing codelibs/ranklib...
#   Found 0 dependencies and 0 dependents
# Analyzing sushistack/oauth-login-be...
#   Found 0 dependencies and 0 dependents
# Analyzing sushistack/oauth-login-be...
#   Found 6 dependencies and 0 dependents
# Analyzing nanosai/modrun...
#   Found 6 dependencies and 0 dependents
# Analyzing nanosai/modrun...
#   Found 0 dependencies and 0 dependents
# Analyzing Bossyao168/RotateMenu...
#   Found 0 dependencies and 0 dependents
# Analyzing Bossyao168/RotateMenu...
#   Found 0 dependencies and 0 dependents
# Analyzing ilahi123/Taxi-Booking-Android-App...
#   Found 0 dependencies and 0 dependents
# Analyzing ilahi123/Taxi-Booking-Android-App...
#   Found 0 dependencies and 0 dependents
# Analyzing yeyunHZ/YunMap...
#   Found 0 dependencies and 0 dependents
# Analyzing yeyunHZ/YunMap...
#   Found 0 dependencies and 0 dependents
# Analyzing ExtraCrafTX/GeneratorFabricMod...
#   Found 0 dependencies and 0 dependents
# Analyzing ExtraCrafTX/GeneratorFabricMod...
#   Found 4 dependencies and 0 dependents
# Analyzing DTHeaven/AutoLayout-Android...
#   Found 4 dependencies and 0 dependents
# Analyzing DTHeaven/AutoLayout-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing ForgottenArbiter/CommunicationMod...
#   Found 0 dependencies and 0 dependents
# Analyzing ForgottenArbiter/CommunicationMod...
#   Found 0 dependencies and 0 dependents
# Analyzing safeYYY/easyHook...
#   Found 0 dependencies and 0 dependents
# Analyzing safeYYY/easyHook...
#   Found 0 dependencies and 0 dependents
# Analyzing rbailen/Hexagonal-Architecture...
#   Found 0 dependencies and 0 dependents
# Analyzing rbailen/Hexagonal-Architecture...
#   Found 0 dependencies and 0 dependents
# Analyzing carlosCharz/fcmxmppserver...
#   Found 0 dependencies and 0 dependents
# Analyzing carlosCharz/fcmxmppserver...
#   Found 0 dependencies and 0 dependents
# Analyzing nacos-group/grpc-java-registry-nacos...
#   Found 0 dependencies and 0 dependents
# Analyzing nacos-group/grpc-java-registry-nacos...
#   Found 0 dependencies and 0 dependents
# Analyzing x1a0t/Struts2Burp...
#   Found 0 dependencies and 0 dependents
# Analyzing x1a0t/Struts2Burp...
#   Found 0 dependencies and 0 dependents
# Analyzing aureldussauge/AnimatedGradientTextView...
#   Found 0 dependencies and 0 dependents
# Analyzing aureldussauge/AnimatedGradientTextView...
#   Found 0 dependencies and 0 dependents
# Analyzing huangdali/MRichEditorDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing huangdali/MRichEditorDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing travijuu/NumberPicker...
#   Found 0 dependencies and 0 dependents
# Analyzing travijuu/NumberPicker...
#   Found 0 dependencies and 0 dependents
# Analyzing HappyMiao/QrCodeScan...
#   Found 0 dependencies and 0 dependents
# Analyzing HappyMiao/QrCodeScan...
#   Found 0 dependencies and 0 dependents
# Analyzing zhouray/SelectableTextView...
#   Found 0 dependencies and 0 dependents
# Analyzing zhouray/SelectableTextView...
#   Found 0 dependencies and 0 dependents
# Analyzing czhzero/scangon...
#   Found 0 dependencies and 0 dependents
# Analyzing czhzero/scangon...
#   Found 0 dependencies and 0 dependents
# Analyzing allgood/OpenCV-3.1.0-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing allgood/OpenCV-3.1.0-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing aws-samples/amazon-cognito-developer-authentication-sample...
#   Found 0 dependencies and 0 dependents
# Analyzing aws-samples/amazon-cognito-developer-authentication-sample...
#   Found 0 dependencies and 0 dependents
# Analyzing spring-attic/hystrix-dashboard...
#   Found 0 dependencies and 0 dependents
# Analyzing spring-attic/hystrix-dashboard...
#   Found 0 dependencies and 0 dependents
# Analyzing OneSourceCat/XxlJob-Hessian-RCE...
#   Found 0 dependencies and 0 dependents
# Analyzing OneSourceCat/XxlJob-Hessian-RCE...
#   Found 0 dependencies and 0 dependents
# Analyzing bbottema/java-socks-proxy-server...
#   Found 0 dependencies and 0 dependents
# Analyzing bbottema/java-socks-proxy-server...
#   Found 0 dependencies and 0 dependents
# Analyzing meyskens/NokiaRemote...
#   Found 0 dependencies and 0 dependents
# Analyzing meyskens/NokiaRemote...
#   Found 0 dependencies and 0 dependents
# Analyzing anomaly2104/ticket-booking-low-level-system-design...
#   Found 0 dependencies and 0 dependents
# Analyzing anomaly2104/ticket-booking-low-level-system-design...
#   Found 0 dependencies and 0 dependents
# Analyzing brandonlw/magstripereader...
#   Found 0 dependencies and 0 dependents
# Analyzing brandonlw/magstripereader...
#   Found 0 dependencies and 0 dependents
# Analyzing bigpuritz/netty-servlet-bridge...
#   Found 0 dependencies and 0 dependents
# Analyzing bigpuritz/netty-servlet-bridge...
#   Found 0 dependencies and 0 dependents
# Analyzing dsyer/spring-boot-legacy...
#   Found 0 dependencies and 0 dependents
# Analyzing dsyer/spring-boot-legacy...
#   Found 0 dependencies and 0 dependents
# Analyzing pakoito/RxPaper2...
#   Found 0 dependencies and 0 dependents
# Analyzing pakoito/RxPaper2...
#   Found 0 dependencies and 0 dependents
# Analyzing LarsWerkman/LicenseView...
#   Found 0 dependencies and 0 dependents
# Analyzing LarsWerkman/LicenseView...
#   Found 0 dependencies and 0 dependents
# Analyzing googlegenomics/dockerflow...
#   Found 0 dependencies and 0 dependents
# Analyzing googlegenomics/dockerflow...
#   Found 0 dependencies and 0 dependents
# Analyzing stfalcon-studio/SocialAuthHelper...
#   Found 0 dependencies and 0 dependents
# Analyzing stfalcon-studio/SocialAuthHelper...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Junit-ISP-Testing...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Junit-ISP-Testing...
#   Found 0 dependencies and 0 dependents
# Analyzing williambl/blockblockdevice...
#   Found 0 dependencies and 0 dependents
# Analyzing williambl/blockblockdevice...
#   Found 0 dependencies and 0 dependents
# Analyzing MisterChangRay/mybatis-generator-plugins...
#   Found 0 dependencies and 0 dependents
# Analyzing MisterChangRay/mybatis-generator-plugins...
#   Found 0 dependencies and 0 dependents
# Analyzing ausboyue/Okhttp-Multiple-Thread-Download-Demo...
#   Found 0 dependencies and 0 dependents
# Analyzing ausboyue/Okhttp-Multiple-Thread-Download-Demo...
#   Found 0 dependencies and 0 dependents
# Analyzing nbarishok/RxMvpAndroid...
#   Found 0 dependencies and 0 dependents
# Analyzing nbarishok/RxMvpAndroid...
#   Found 0 dependencies and 0 dependents
# Analyzing mikvor/hashmapTest...
#   Found 0 dependencies and 0 dependents
# Analyzing mikvor/hashmapTest...
#   Found 0 dependencies and 0 dependents
# Analyzing alphamu/android-MVVM-DataBinding-RecyclerViewExample...
#   Found 0 dependencies and 0 dependents
# Analyzing alphamu/android-MVVM-DataBinding-RecyclerViewExample...
#   Found 0 dependencies and 0 dependents
# Analyzing sisyphsu/dateparser...
#   Found 0 dependencies and 0 dependents
# Analyzing sisyphsu/dateparser...
#   Found 0 dependencies and 0 dependents
# Analyzing smartcat-labs/cassandra-migration-tool-java...
#   Found 0 dependencies and 0 dependents
# Analyzing smartcat-labs/cassandra-migration-tool-java...
#   Found 0 dependencies and 0 dependents
# Analyzing mewebstudio/java-spring-boot-boilerplate...
#   Found 0 dependencies and 0 dependents
# Analyzing mewebstudio/java-spring-boot-boilerplate...
#   Found 0 dependencies and 0 dependents
# Analyzing bikashthapa01/firebase-authentication-android...
#   Found 0 dependencies and 0 dependents
# Analyzing bikashthapa01/firebase-authentication-android...
#   Found 0 dependencies and 0 dependents
# Analyzing aegis1980/WifiHotSpot...
#   Found 0 dependencies and 0 dependents
# Analyzing aegis1980/WifiHotSpot...
#   Found 0 dependencies and 0 dependents
# Analyzing bingohuang/spring-boot-docker...
#   Found 0 dependencies and 0 dependents
# Analyzing bingohuang/spring-boot-docker...
#   Found 0 dependencies and 0 dependents
# Analyzing anncode1/Curso-POO-Platzi...
#   Found 0 dependencies and 0 dependents
# Analyzing anncode1/Curso-POO-Platzi...
#   Found 0 dependencies and 0 dependents
# Analyzing instaclustr/cassandra-sstable-tools...
#   Found 0 dependencies and 0 dependents
# Analyzing instaclustr/cassandra-sstable-tools...
#   Found 0 dependencies and 0 dependents
# Analyzing yangaijun/multipleselect...
#   Found 0 dependencies and 0 dependents
# Analyzing yangaijun/multipleselect...
#   Found 0 dependencies and 0 dependents
# Analyzing VincentWYJ/CaptureScreen...
#   Found 0 dependencies and 0 dependents
# Analyzing VincentWYJ/CaptureScreen...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/jar-relocator...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/jar-relocator...
#   Found 0 dependencies and 0 dependents
# Analyzing nhn/toast-haste.framework...
#   Found 0 dependencies and 0 dependents
# Analyzing nhn/toast-haste.framework...
#   Found 0 dependencies and 0 dependents
# Analyzing prateek27/design-patterns-java...
#   Found 0 dependencies and 0 dependents
# Analyzing prateek27/design-patterns-java...
#   Found 0 dependencies and 0 dependents
# Analyzing KindedJ/KindedJ...
#   Found 0 dependencies and 0 dependents
# Analyzing KindedJ/KindedJ...
#   Found 0 dependencies and 0 dependents
# Analyzing anthonygauthier/jmeter-elasticsearch-backend-listener...
#   Found 0 dependencies and 0 dependents
# Analyzing anthonygauthier/jmeter-elasticsearch-backend-listener...
#   Found 0 dependencies and 0 dependents
# Analyzing leebyron/mesh...
#   Found 0 dependencies and 0 dependents
# Analyzing leebyron/mesh...
#   Found 0 dependencies and 0 dependents
# Analyzing indeedeng/mph-table...
#   Found 0 dependencies and 0 dependents
# Analyzing indeedeng/mph-table...
#   Found 0 dependencies and 0 dependents
# Analyzing hellokaton/java11-examples...
#   Found 0 dependencies and 0 dependents
# Analyzing hellokaton/java11-examples...
#   Found 0 dependencies and 0 dependents
# Analyzing TechPrimers/spring-boot-graphql-query-example...
#   Found 0 dependencies and 0 dependents
# Analyzing TechPrimers/spring-boot-graphql-query-example...
#   Found 0 dependencies and 0 dependents
# Analyzing jpelgrom/retrofit2-oauthrefresh...
#   Found 0 dependencies and 0 dependents
# Analyzing jpelgrom/retrofit2-oauthrefresh...
#   Found 0 dependencies and 0 dependents
# Analyzing Knight-ZXW/SpWaitKiller...
#   Found 0 dependencies and 0 dependents
# Analyzing Knight-ZXW/SpWaitKiller...
#   Found 0 dependencies and 0 dependents
# Analyzing mathiazhagan01/DrawableColorChange...
#   Found 0 dependencies and 0 dependents
# Analyzing mathiazhagan01/DrawableColorChange...
#   Found 0 dependencies and 0 dependents
# Analyzing pucamafra/RxNotification...
#   Found 0 dependencies and 0 dependents
# Analyzing pucamafra/RxNotification...
#   Found 0 dependencies and 0 dependents
# Analyzing AoEiuV020/VpnProxy...
#   Found 0 dependencies and 0 dependents
# Analyzing AoEiuV020/VpnProxy...
#   Found 0 dependencies and 0 dependents
# Analyzing pires/spring-boot-shiro-orientdb...
#   Found 0 dependencies and 0 dependents
# Analyzing pires/spring-boot-shiro-orientdb...
#   Found 0 dependencies and 0 dependents
# Analyzing DozenWang/DPreference...
#   Found 0 dependencies and 0 dependents
# Analyzing DozenWang/DPreference...
#   Found 0 dependencies and 0 dependents
# Analyzing WendellAdriel/spring-microservices...
#   Found 0 dependencies and 0 dependents
# Analyzing WendellAdriel/spring-microservices...
#   Found 0 dependencies and 0 dependents
# Analyzing Karabosithole/LearnJavaSnakeGame...
#   Found 0 dependencies and 0 dependents
# Analyzing Karabosithole/LearnJavaSnakeGame...
#   Found 0 dependencies and 0 dependents
# Analyzing hitherejoe/Aware...
#   Found 0 dependencies and 0 dependents
# Analyzing hitherejoe/Aware...
#   Found 0 dependencies and 0 dependents
# Analyzing joshlong-attic/service-registration-and-discovery...
#   Found 0 dependencies and 0 dependents
# Analyzing joshlong-attic/service-registration-and-discovery...
#   Found 0 dependencies and 0 dependents
# Analyzing fangjian0423/rocketmq-binder-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing fangjian0423/rocketmq-binder-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing yongjhih/mocker...
#   Found 0 dependencies and 0 dependents
# Analyzing yongjhih/mocker...
#   Found 0 dependencies and 0 dependents
# Analyzing jeff-leo/SpikeSystem...
#   Found 0 dependencies and 0 dependents
# Analyzing jeff-leo/SpikeSystem...
#   Found 0 dependencies and 0 dependents
# Analyzing UnquietCode/JState...
#   Found 0 dependencies and 0 dependents
# Analyzing UnquietCode/JState...
#   Found 0 dependencies and 0 dependents
# Analyzing ullenboom/jrtf...
#   Found 0 dependencies and 0 dependents
# Analyzing ullenboom/jrtf...
#   Found 0 dependencies and 0 dependents
# Analyzing hariprasanths/FloatingToast...
#   Found 0 dependencies and 0 dependents
# Analyzing hariprasanths/FloatingToast...
#   Found 0 dependencies and 0 dependents
# Analyzing xm0625/VideoSniffer...
#   Found 0 dependencies and 0 dependents
# Analyzing xm0625/VideoSniffer...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/JUnit-CACC-RACC...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/JUnit-CACC-RACC...
#   Found 0 dependencies and 0 dependents
# Analyzing PhantomThief/model-view-builder...
#   Found 0 dependencies and 0 dependents
# Analyzing PhantomThief/model-view-builder...
#   Found 0 dependencies and 0 dependents
# Analyzing paulmach/Text-Edit-for-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing paulmach/Text-Edit-for-Android...
#   Found 0 dependencies and 0 dependents
# Analyzing ReactiveX/RxJavaMath...
#   Found 0 dependencies and 0 dependents
# Analyzing ReactiveX/RxJavaMath...
#   Found 1 dependencies and 0 dependents
# Analyzing FJ917/FJNestedHoverTabDemo...
#   Found 1 dependencies and 0 dependents
# Analyzing FJ917/FJNestedHoverTabDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing micedre/keycloak-mail-whitelisting...
#   Found 0 dependencies and 0 dependents
# Analyzing micedre/keycloak-mail-whitelisting...
#   Found 0 dependencies and 0 dependents
# Analyzing gshjd/RainbowCache...
#   Found 0 dependencies and 0 dependents
# Analyzing gshjd/RainbowCache...
#   Found 0 dependencies and 0 dependents
# Analyzing tugcekonuklar/account-service...
#   Found 0 dependencies and 0 dependents
# Analyzing tugcekonuklar/account-service...
#   Found 0 dependencies and 0 dependents
# Analyzing don/cordova-filechooser...
#   Found 0 dependencies and 0 dependents
# Analyzing don/cordova-filechooser...
#   Found 0 dependencies and 0 dependents
# Analyzing tlcdio/MAula03...
#   Found 0 dependencies and 0 dependents
# Analyzing tlcdio/MAula03...
#   Found 0 dependencies and 0 dependents
# Analyzing muyinchen/Java-programming-methodology-Rxjava-articles...
#   Found 0 dependencies and 0 dependents
# Analyzing muyinchen/Java-programming-methodology-Rxjava-articles...
#   Found 0 dependencies and 0 dependents
# Analyzing SmithGao/rxjava_retrofit3.0_okhttp...
#   Found 0 dependencies and 0 dependents
# Analyzing SmithGao/rxjava_retrofit3.0_okhttp...
#   Found 0 dependencies and 0 dependents
# Analyzing cescoffier/my-vertx-first-app...
#   Found 0 dependencies and 0 dependents
# Analyzing cescoffier/my-vertx-first-app...
#   Found 0 dependencies and 0 dependents
# Analyzing ivangrov/Android-Deep-Learning-with-OpenCV...
#   Found 0 dependencies and 0 dependents
# Analyzing ivangrov/Android-Deep-Learning-with-OpenCV...
#   Found 0 dependencies and 0 dependents
# Analyzing chengzipi/Searchbox...
#   Found 0 dependencies and 0 dependents
# Analyzing chengzipi/Searchbox...
#   Found 0 dependencies and 0 dependents
# Analyzing cn/GB2260.java...
#   Found 0 dependencies and 0 dependents
# Analyzing cn/GB2260.java...
#   Found 0 dependencies and 0 dependents
# Analyzing DokiYoloo/CareUEveryDay...
#   Found 0 dependencies and 0 dependents
# Analyzing DokiYoloo/CareUEveryDay...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Advanced-Programming...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Advanced-Programming...
#   Found 0 dependencies and 0 dependents
# Analyzing ckdevrel/IconColorChanger...
#   Found 0 dependencies and 0 dependents
# Analyzing ckdevrel/IconColorChanger...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Algorithms-And-Data-Structures...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/Algorithms-And-Data-Structures...
#   Found 0 dependencies and 0 dependents
# Analyzing federicodotta/ghidra-scripts...
#   Found 0 dependencies and 0 dependents
# Analyzing federicodotta/ghidra-scripts...
#   Found 0 dependencies and 0 dependents
# Analyzing YZHyaa/Framework...
#   Found 0 dependencies and 0 dependents
# Analyzing YZHyaa/Framework...
#   Found 0 dependencies and 0 dependents
# Analyzing patriksletmo/launcherclient...
#   Found 0 dependencies and 0 dependents
# Analyzing patriksletmo/launcherclient...
#   Found 0 dependencies and 0 dependents
# Analyzing androidthings/sample-videoRTC...
#   Found 0 dependencies and 0 dependents
# Analyzing androidthings/sample-videoRTC...
#   Found 0 dependencies and 0 dependents
# Analyzing zjpjohn/ReliableMeageSystem...
#   Found 0 dependencies and 0 dependents
# Analyzing zjpjohn/ReliableMeageSystem...
#   Found 0 dependencies and 0 dependents
# Analyzing yi-ge/desktop-subtitle...
#   Found 0 dependencies and 0 dependents
# Analyzing yi-ge/desktop-subtitle...
#   Found 0 dependencies and 0 dependents
# Analyzing Carson-Ho/TimeAxle_View...
#   Found 0 dependencies and 0 dependents
# Analyzing Carson-Ho/TimeAxle_View...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/OperatingSystems...
#   Found 0 dependencies and 0 dependents
# Analyzing gabrieldim/OperatingSystems...
#   Found 0 dependencies and 0 dependents
# Analyzing xaguzman/pathfinding...
#   Found 0 dependencies and 0 dependents
# Analyzing xaguzman/pathfinding...
#   Found 1 dependencies and 0 dependents
# Analyzing alibaba/druid-ha...
#   Found 1 dependencies and 0 dependents
# Analyzing alibaba/druid-ha...
#   Found 0 dependencies and 0 dependents
# Analyzing darius/expr...
#   Found 0 dependencies and 0 dependents
# Analyzing darius/expr...
#   Found 0 dependencies and 0 dependents
# Analyzing yash786agg/AnimatedLoadingIndicator...
#   Found 0 dependencies and 0 dependents
# Analyzing yash786agg/AnimatedLoadingIndicator...
#   Found 0 dependencies and 0 dependents
# Analyzing idealista/format-preserving-encryption-java...
#   Found 0 dependencies and 0 dependents
# Analyzing idealista/format-preserving-encryption-java...
#   Found 0 dependencies and 0 dependents
# Analyzing MaskCyberSecurityTeam/FinalShellGetPass...
#   Found 0 dependencies and 0 dependents
# Analyzing MaskCyberSecurityTeam/FinalShellGetPass...
#   Found 0 dependencies and 0 dependents
# Analyzing verilylifesciences/genomewarp...
#   Found 0 dependencies and 0 dependents
# Analyzing verilylifesciences/genomewarp...
# ...
#   Found 0 dependencies and 0 dependents
# Analyzing card-io/react-native-card-io...
#   Found 0 dependencies and 0 dependents
# Analyzing dspinellis/effective-debugging...
#   Found 0 dependencies and 0 dependents
# Analyzing dspinellis/effective-debugging...
#   Found 0 dependencies and 0 dependents
# Analyzing AHUCodingBeast/spring-ai-mcp-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing AHUCodingBeast/spring-ai-mcp-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing TranswarpCN/argodb-flink...
#   Found 0 dependencies and 0 dependents
# Analyzing TranswarpCN/argodb-flink...
#   Found 0 dependencies and 0 dependents
# Analyzing bytedeco/procamtracker...
#   Found 0 dependencies and 0 dependents
# Analyzing bytedeco/procamtracker...
#   Found 0 dependencies and 0 dependents
# Analyzing mitchtabian/Bound-Services-with-MVVM...
#   Found 0 dependencies and 0 dependents
# Analyzing mitchtabian/Bound-Services-with-MVVM...
#   Found 0 dependencies and 0 dependents
# Analyzing yanfeng9507/TianYanChaCrawler...
#   Found 0 dependencies and 0 dependents
# Analyzing yanfeng9507/TianYanChaCrawler...
#   Found 0 dependencies and 0 dependents
# Analyzing Rakers1024/AutoJsHook...
#   Found 0 dependencies and 0 dependents
# Analyzing Rakers1024/AutoJsHook...
#   Found 0 dependencies and 0 dependents
# Analyzing MeteorDevelopment/starscript...
#   Found 0 dependencies and 0 dependents
# Analyzing MeteorDevelopment/starscript...
#   Found 2 dependencies and 0 dependents
# Analyzing stuarthalloway/clojure-from-java...
#   Found 2 dependencies and 0 dependents
# Analyzing stuarthalloway/clojure-from-java...
#   Found 0 dependencies and 0 dependents
# Analyzing lokeshgupta1981/Spring-Boot3-Demos...
#   Found 0 dependencies and 0 dependents
# Analyzing lokeshgupta1981/Spring-Boot3-Demos...
#   Found 0 dependencies and 0 dependents
# Analyzing krams915/spring-security-tutorial...
#   Found 0 dependencies and 0 dependents
# Analyzing krams915/spring-security-tutorial...
#   Found 0 dependencies and 0 dependents
# Analyzing nielsutrecht/spring-async...
#   Found 0 dependencies and 0 dependents
# Analyzing nielsutrecht/spring-async...
#   Found 0 dependencies and 0 dependents
# Analyzing howtoprogram/Kafka-MultiThread-Java-Example...
#   Found 0 dependencies and 0 dependents
# Analyzing howtoprogram/Kafka-MultiThread-Java-Example...
#   Found 0 dependencies and 0 dependents
# Analyzing julianodenner/java-sistema-vendas...
#   Found 0 dependencies and 0 dependents
# Analyzing julianodenner/java-sistema-vendas...
#   Found 0 dependencies and 0 dependents
# Analyzing chenyurong/song-parser-spi-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing chenyurong/song-parser-spi-demo...
#   Found 0 dependencies and 0 dependents
# Analyzing JohnnyJayJay/spigot-maps...
#   Found 0 dependencies and 0 dependents
# Analyzing JohnnyJayJay/spigot-maps...
#   Found 1 dependencies and 0 dependents
# Analyzing marcoaparaujo/padroes-projeto...
#   Found 1 dependencies and 0 dependents
# Analyzing marcoaparaujo/padroes-projeto...
#   Found 0 dependencies and 0 dependents
# Analyzing feiniaojin/ddd-example-cms...
#   Found 0 dependencies and 0 dependents
# Analyzing feiniaojin/ddd-example-cms...
#   Found 0 dependencies and 0 dependents
# Analyzing nixuechao/security-jwt...
#   Found 0 dependencies and 0 dependents
# Analyzing nixuechao/security-jwt...
#   Found 0 dependencies and 0 dependents
# Analyzing nbphpcouncil/nb-ci-plugin...
#   Found 0 dependencies and 0 dependents
# Analyzing nbphpcouncil/nb-ci-plugin...
#   Found 0 dependencies and 0 dependents
# Analyzing EalenXie/springboot-batch...
#   Found 0 dependencies and 0 dependents
# Analyzing EalenXie/springboot-batch...
#   Found 0 dependencies and 0 dependents
# Analyzing DarkBlade12/ParticleEffect...
#   Found 0 dependencies and 0 dependents
# Analyzing DarkBlade12/ParticleEffect...
#   Found 0 dependencies and 0 dependents
# Analyzing verhas/License3jRepl...
#   Found 0 dependencies and 0 dependents
# Analyzing verhas/License3jRepl...
#   Found 0 dependencies and 0 dependents
# Analyzing shodgson/uareu...
#   Found 0 dependencies and 0 dependents
# Analyzing shodgson/uareu...
#   Found 0 dependencies and 0 dependents
# Analyzing skjolber/mockito-soap-cxf...
#   Found 0 dependencies and 0 dependents
# Analyzing skjolber/mockito-soap-cxf...
#   Found 0 dependencies and 0 dependents
# Analyzing googlearchive/cloud-pubsub-samples-java...
#   Found 0 dependencies and 0 dependents
# Analyzing googlearchive/cloud-pubsub-samples-java...
#   Found 0 dependencies and 0 dependents
# Analyzing EalenXie/shiro-rbac-system...
#   Found 0 dependencies and 0 dependents
# Analyzing EalenXie/shiro-rbac-system...
#   Found 0 dependencies and 0 dependents
# Analyzing pakoito/RxFunctions...
#   Found 0 dependencies and 0 dependents
# Analyzing pakoito/RxFunctions...
#   Found 0 dependencies and 0 dependents
# Analyzing hyperledger-archives/fabric-api-archive...
#   Found 0 dependencies and 0 dependents
# Analyzing hyperledger-archives/fabric-api-archive...
#   Found 0 dependencies and 0 dependents
# Analyzing kongkongdaren/DrawDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing kongkongdaren/DrawDemo...
#   Found 0 dependencies and 0 dependents
# Analyzing liangchengcheng/ShoppingMall...
#   Found 0 dependencies and 0 dependents
# Analyzing liangchengcheng/ShoppingMall...
#   Found 35 dependencies and 0 dependents
# Analyzing winterbe/java8-explorer...
#   Found 35 dependencies and 0 dependents
# Analyzing winterbe/java8-explorer...
#   Found 0 dependencies and 0 dependents
# Analyzing zhichaosong/easy-coding-example...
#   Found 0 dependencies and 0 dependents
# Analyzing zhichaosong/easy-coding-example...
#   Found 0 dependencies and 0 dependents
# Analyzing taggon/react-native-intl...
#   Found 0 dependencies and 0 dependents
# Analyzing taggon/react-native-intl...
#   Found 0 dependencies and 0 dependents
# Analyzing xaverkapeller/SortedListAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing xaverkapeller/SortedListAdapter...
#   Found 0 dependencies and 0 dependents
# Analyzing davidmoten/predict4java...
#   Found 0 dependencies and 0 dependents
# Analyzing davidmoten/predict4java...
#   Found 0 dependencies and 0 dependents
# Analyzing NandanDesai/SocialInfo4J...
#   Found 0 dependencies and 0 dependents
# Analyzing NandanDesai/SocialInfo4J...
#   Found 0 dependencies and 0 dependents
# Analyzing cursodsousa/minhasfinancas-api...
#   Found 0 dependencies and 0 dependents
# Analyzing cursodsousa/minhasfinancas-api...
#   Found 0 dependencies and 0 dependents
# Analyzing KaiKikuchi/QuickShop...
#   Found 0 dependencies and 0 dependents
# Analyzing KaiKikuchi/QuickShop...
#   Found 0 dependencies and 0 dependents
# Analyzing lightsocks/lightsocks-java...
#   Found 0 dependencies and 0 dependents
# Analyzing lightsocks/lightsocks-java...
#   Found 0 dependencies and 0 dependents
# Analyzing tuyrk/303-java-offter...
#   Found 0 dependencies and 0 dependents
# Analyzing tuyrk/303-java-offter...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/minecraft-command-permissions-fabric...
#   Found 0 dependencies and 0 dependents
# Analyzing lucko/minecraft-command-permissions-fabric...
#   Found 0 dependencies and 0 dependents
# Analyzing willShuhuan/JvmStudy...
#   Found 0 dependencies and 0 dependents
# Analyzing willShuhuan/JvmStudy...
#   Found 0 dependencies and 0 dependents
# Analyzing Elytrium/LimboReconnect...
#   Found 0 dependencies and 0 dependents
# Analyzing Elytrium/LimboReconnect...
#   Found 0 dependencies and 0 dependents
# Analyzing mzule/NineGridLayout...
#   Found 0 dependencies and 0 dependents
# Analyzing mzule/NineGridLayout...
#   Found 0 dependencies and 0 dependents
# Analyzing fstab/http2-examples...
#   Found 0 dependencies and 0 dependents
# Analyzing fstab/http2-examples...
#   Found 0 dependencies and 0 dependents
# Analyzing bjmashibing/TankNettyStudy...
#   Found 0 dependencies and 0 dependents
# Analyzing bjmashibing/TankNettyStudy...
#   Found 4 dependencies and 0 dependents
# Analyzing learning-spring-boot/learning-spring-boot-code...
#   Found 4 dependencies and 0 dependents
# Analyzing learning-spring-boot/learning-spring-boot-code...
#   Found 0 dependencies and 0 dependents
# Analyzing SnappFr/react-native-image-base64...
#   Found 0 dependencies and 0 dependents
# Analyzing SnappFr/react-native-image-base64...
#   Found 0 dependencies and 0 dependents
# Analyzing MrBin99/LaravelEchoAndroid...
#   Found 0 dependencies and 0 dependents
# Analyzing MrBin99/LaravelEchoAndroid...
#   Found 0 dependencies and 0 dependents
# Analyzing uber-archive/kafka-spraynozzle...
#   Found 0 dependencies and 0 dependents
# Analyzing uber-archive/kafka-spraynozzle...
#   Found 0 dependencies and 0 dependents
# Analyzing springframeworkguru/spring5-mvc-rest...
#   Found 0 dependencies and 0 dependents
# Analyzing springframeworkguru/spring5-mvc-rest...
#   Found 0 dependencies and 0 dependents
# Analyzing GuoFeilong/ATLoginButton_New...
#   Found 0 dependencies and 0 dependents
# Analyzing GuoFeilong/ATLoginButton_New...
#   Found 0 dependencies and 0 dependents
# Analyzing lets-mica/mica-example...
#   Found 0 dependencies and 0 dependents
# Analyzing lets-mica/mica-example...
#   Found 0 dependencies and 0 dependents
# Analyzing opersys/opersys-hal-hw...
#   Found 0 dependencies and 0 dependents
# Analyzing opersys/opersys-hal-hw...
#   Found 0 dependencies and 0 dependents
# Analyzing gecgooden/chunkgen...
#   Found 0 dependencies and 0 dependents
# Analyzing gecgooden/chunkgen...
#   Found 0 dependencies and 0 dependents
# Analyzing xiaoxiae/PurePursuitAlgorithm...
#   Found 0 dependencies and 0 dependents
# Analyzing xiaoxiae/PurePursuitAlgorithm...
#   Found 0 dependencies and 0 dependents
# Analyzing tomakehurst/crash-lab...
#   Found 0 dependencies and 0 dependents
# Analyzing tomakehurst/crash-lab...
#   Found 5 dependencies and 0 dependents
# Analyzing nrohmen/FirestoreRecyclerAdapterSample...
#   Found 5 dependencies and 0 dependents
# Analyzing nrohmen/FirestoreRecyclerAdapterSample...
#   Found 0 dependencies and 0 dependents
# Analyzing pofallon/jersey2-akka-java...
#   Found 0 dependencies and 0 dependents
# Analyzing pofallon/jersey2-akka-java...
#   Found 0 dependencies and 0 dependents
# Analyzing folksdev/kitaplik-online...
#   Found 0 dependencies and 0 dependents
# Analyzing folksdev/kitaplik-online...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 122
#     119 try:
#     120     # Get repository contents to find build files
#     121     contents_url = f"https://api.github.com/repos/{repo_full_name}/contents"
# --> 122     response = requests.get(contents_url, headers=headers)
#     124     dependencies = []
#     125     dependents = []
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
repos['layer7'] = []
java_dependencies['layer7'] = {}
repo_relationships['layer7'] = {}

# %%
print(len(repos['layer2']))  # Output the number of repositories found in layer6

i = 0
while repos['layer1'][i]['full_name'] != 'mimicmobile/okhttp-oauth2-client':
    i += 1
print(f"Found 'apache/commons-lang' at index {i} in layer1")
# Out:
# 16
# Found 'apache/commons-lang' at index 580 in layer1

# %%
# Merge all repositories from all layers into one array
final_repos = []

for layer_repos in repos.keys():
    for repo in repos[layer_repos]:
        if layer_repos == 'layer1':
                repo_full_name = repo["full_name"]
        else:
            #checl if repo is a string
            if isinstance(repo, str):
                repo_full_name = repo
            elif len(repo) > 0:
                repo_full_name = repo[0]
            else:
                continue
            
        if repo_full_name not in final_repos:
            # Add only unique repository full names
            final_repos.append(repo_full_name)

# Save to JSON file
with open("/tmp/final_java_repos.json", "w") as f:
    json.dump(final_repos, f, indent=2)

print(f"Saved {len(final_repos)} repositories to /tmp/final_java_repos.json")
# Out:
# Saved 6908 repositories to /tmp/final_java_repos.json

# %%
import os
import subprocess

# Directory to save data
output_dir = "/tmp/java_repo_details"
os.makedirs(output_dir, exist_ok=True)

def get_github_api(url, params=None):
    r = requests.get(url, headers=headers, params=params)
    if r.status_code == 200:
        return r.json()
    else:
        print(f"Failed to fetch {url}: {r.status_code}")
        return None

repo_details = {}

for repo_full_name in final_repos[::-1]:
    print(f"Processing {repo_full_name}...")
    repo_data = {}

    # 1. Download files (list of files in the repo)
    # Also download the content of each file (if it's not a directory)
    # Clone the repository into a subdirectory if not already cloned
    repo_dir = os.path.join(output_dir, repo_full_name.replace('/', '__'))
    if not os.path.exists(repo_dir):
        clone_url = f"https://github.com/{repo_full_name}.git"
        try:
            subprocess.run(
                ["git", "clone", "--depth", "500", clone_url, repo_dir],
                check=True,
                timeout=10
            )
        except Exception as e:
            print(f"  Failed to clone {repo_full_name}: {e}")

    # List the project tree
    project_files = []
    for root, dirs, files in os.walk(repo_dir):
        for file in files:
            rel_path = os.path.relpath(os.path.join(root, file), repo_dir)
            project_files.append(rel_path)

    repo_data['files'] = project_files

    # Add file contents for text-like files
    file_contents = {}
    for rel_path in project_files:
        abs_path = os.path.join(repo_dir, rel_path)
        try:
            # Read only small files (e.g., <1MB) and skip binaries
            if os.path.getsize(abs_path) < 1024 * 1024:
                with open(abs_path, "rb") as f:
                    raw = f.read()
                    try:
                        text = raw.decode("utf-8")
                    except UnicodeDecodeError:
                        try:
                            text = raw.decode("latin1")
                        except Exception:
                            continue  # skip non-text files
                    # Heuristic: skip if too many non-printable characters
                    if sum(c < " " and c not in "\n\r\t" for c in text) < 0.05 * len(text):
                        file_contents[rel_path] = text
        except Exception:
            continue  # skip unreadable files

    repo_data['file_contents'] = file_contents


    print(f"  Found {len(repo_data['files'])} files in {repo_full_name}")

    # 2. Contributors
    contributors_url = f"https://api.github.com/repos/{repo_full_name}/contributors"
    contributors = get_github_api(contributors_url)
    repo_data['contributors'] = contributors if contributors is not None else []

    print(f"  Found {len(repo_data['contributors'])} contributors in {repo_full_name}")

    # 3. Commits with statistics
    # Get commit statistics from the local git repository
    commits = []
    try:
        # Get the list of commit hashes (limit to last 100 for performance)
        result = subprocess.run(
            ["git", "-C", repo_dir, "rev-list", "--max-count=100", "HEAD"],
            stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, check=True
        )
        commit_hashes = result.stdout.strip().split('\n')
        for sha in commit_hashes:
            # Get commit info and stats
            show_cmd = [
                "git", "-C", repo_dir, "show", "--quiet", "--format=%H|%an|%ae|%ad|%s", sha
            ]
            stat_cmd = [
                "git", "-C", repo_dir, "show", "--stat", "--oneline", "--format=", sha
            ]
            show_result = subprocess.run(show_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
            stat_result = subprocess.run(stat_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
            if show_result.returncode == 0:
                parts = show_result.stdout.strip().split('|')
                if len(parts) == 5:
                    commit_info = {
                        "sha": parts[0],
                        "author_name": parts[1],
                        "author_email": parts[2],
                        "date": parts[3],
                        "message": parts[4],
                        "stats": stat_result.stdout.strip()
                    }
                    commits.append(commit_info)
    except Exception as e:
        print(f"  Failed to get commits for {repo_full_name}: {e}")

    repo_data['commits'] = commits

    print(f"  Found {len(repo_data['commits'])} commits in {repo_full_name}")

    # 4. Issues
    issues_url = f"https://api.github.com/repos/{repo_full_name}/issues"
    issues = []
    params = {"state": "all", "per_page": 100, "page": 1}
    while True:
        issues_page = get_github_api(issues_url, params=params)
        if not issues_page:
            break
        issues.extend(issues_page)
        
        break
    repo_data['issues'] = issues

    print(f"  Found {len(repo_data['issues'])} issues in {repo_full_name}")

    # Save per repo
    with open(os.path.join(output_dir, f"{repo_full_name.replace('/', '__')}.json"), "w") as f:
        json.dump(repo_data, f, indent=2)

    repo_details[repo_full_name] = repo_data

    # To avoid hitting rate limits
    time.sleep(0.2)

# Save all details to a single file
with open("/tmp/all_repo_details.json", "w") as f:
    json.dump(repo_details, f, indent=2)

print(f"Saved details for {len(final_repos)} repositories in {output_dir}")
# Out:
# Processing kazakago/compose_multiplatform_with_gradle...
# Cloning into '/tmp/java_repo_details/kazakago__compose_multiplatform_with_gradle'...
#   Found 76 files in kazakago/compose_multiplatform_with_gradle
#   Found 1 contributors in kazakago/compose_multiplatform_with_gradle
#   Found 1 commits in kazakago/compose_multiplatform_with_gradle
#   Found 0 issues in kazakago/compose_multiplatform_with_gradle
# Processing frogobox/frogo-ui...
# Cloning into '/tmp/java_repo_details/frogobox__frogo-ui'...
#   Found 423 files in frogobox/frogo-ui
#   Found 1 contributors in frogobox/frogo-ui
#   Found 95 commits in frogobox/frogo-ui
#   Found 3 issues in frogobox/frogo-ui
# Processing tpakis/codebreak...
# Cloning into '/tmp/java_repo_details/tpakis__codebreak'...
#   Found 142 files in tpakis/codebreak
#   Found 1 contributors in tpakis/codebreak
#   Found 37 commits in tpakis/codebreak
#   Found 0 issues in tpakis/codebreak
# Processing hoc081098/Compose-Multiplatform-KmpViewModel-Unsplash-Sample...
# Cloning into '/tmp/java_repo_details/hoc081098__Compose-Multiplatform-KmpViewModel-Unsplash-Sample'...
#   Found 174 files in hoc081098/Compose-Multiplatform-KmpViewModel-Unsplash-Sample
#   Found 2 contributors in hoc081098/Compose-Multiplatform-KmpViewModel-Unsplash-Sample
#   Found 100 commits in hoc081098/Compose-Multiplatform-KmpViewModel-Unsplash-Sample
#   Found 100 issues in hoc081098/Compose-Multiplatform-KmpViewModel-Unsplash-Sample
# Processing CharLEE-X/neumorph-ui...
# Cloning into '/tmp/java_repo_details/CharLEE-X__neumorph-ui'...
#   Found 294 files in CharLEE-X/neumorph-ui
#   Found 1 contributors in CharLEE-X/neumorph-ui
#   Found 45 commits in CharLEE-X/neumorph-ui
#   Found 24 issues in CharLEE-X/neumorph-ui
# Processing smarttuner/kaffeeverde...
# Cloning into '/tmp/java_repo_details/smarttuner__kaffeeverde'...
#   Found 191 files in smarttuner/kaffeeverde
#   Found 1 contributors in smarttuner/kaffeeverde
#   Found 35 commits in smarttuner/kaffeeverde
#   Found 2 issues in smarttuner/kaffeeverde
# Processing amirisback/nutrition-framework...
# Cloning into '/tmp/java_repo_details/amirisback__nutrition-framework'...
#   Failed to clone amirisback/nutrition-framework: Command '['git', 'clone', '--depth', '500', 'https://github.com/amirisback/nutrition-framework.git', '/tmp/java_repo_details/amirisback__nutrition-framework']' timed out after 9.999979791995429 seconds
#   Found 20 files in amirisback/nutrition-framework
# fatal: early EOF
#   Found 1 contributors in amirisback/nutrition-framework
#   Failed to get commits for amirisback/nutrition-framework: Command '['git', '-C', '/tmp/java_repo_details/amirisback__nutrition-framework', 'rev-list', '--max-count=100', 'HEAD']' returned non-zero exit status 128.
#   Found 0 commits in amirisback/nutrition-framework
#   Found 0 issues in amirisback/nutrition-framework
# Processing AlexBurdu/brazel...
# Cloning into '/tmp/java_repo_details/AlexBurdu__brazel'...
#   Found 973 files in AlexBurdu/brazel
#   Found 1 contributors in AlexBurdu/brazel
#   Found 1 commits in AlexBurdu/brazel
#   Found 0 issues in AlexBurdu/brazel
# Processing BetterAndroid/BetterAndroid...
# Cloning into '/tmp/java_repo_details/BetterAndroid__BetterAndroid'...
#   Found 268 files in BetterAndroid/BetterAndroid
#   Found 1 contributors in BetterAndroid/BetterAndroid
#   Found 100 commits in BetterAndroid/BetterAndroid
#   Found 0 issues in BetterAndroid/BetterAndroid
# Processing actions-marketplace-validations/frogobox_frogo-ui...
# Cloning into '/tmp/java_repo_details/actions-marketplace-validations__frogobox_frogo-ui'...
#   Found 386 files in actions-marketplace-validations/frogobox_frogo-ui
#   Found 1 contributors in actions-marketplace-validations/frogobox_frogo-ui
#   Found 57 commits in actions-marketplace-validations/frogobox_frogo-ui
#   Found 0 issues in actions-marketplace-validations/frogobox_frogo-ui
# Processing Iridium-Development/IridiumSkyblock...
# Cloning into '/tmp/java_repo_details/Iridium-Development__IridiumSkyblock'...
#   Found 177 files in Iridium-Development/IridiumSkyblock
#   Found 28 contributors in Iridium-Development/IridiumSkyblock
#   Found 100 commits in Iridium-Development/IridiumSkyblock
#   Found 100 issues in Iridium-Development/IridiumSkyblock
# Processing romychab/effects-hilt-plugin...
# Cloning into '/tmp/java_repo_details/romychab__effects-hilt-plugin'...
#   Found 847 files in romychab/effects-hilt-plugin
#   Found 1 contributors in romychab/effects-hilt-plugin
#   Found 100 commits in romychab/effects-hilt-plugin
#   Found 11 issues in romychab/effects-hilt-plugin
# Processing EssentialsX/Essentials...
# Cloning into '/tmp/java_repo_details/EssentialsX__Essentials'...
#   Found 751 files in EssentialsX/Essentials
#   Found 30 contributors in EssentialsX/Essentials
#   Found 100 commits in EssentialsX/Essentials
#   Found 100 issues in EssentialsX/Essentials
# Processing md-5/Deadbolt...
# Cloning into '/tmp/java_repo_details/md-5__Deadbolt'...
#   Found 72 files in md-5/Deadbolt
#   Found 8 contributors in md-5/Deadbolt
#   Found 100 commits in md-5/Deadbolt
#   Found 100 issues in md-5/Deadbolt
# Processing LeonMangler/SuperVanish...
# Cloning into '/tmp/java_repo_details/LeonMangler__SuperVanish'...
# fetch-pack: unexpected disconnect while reading sideband packet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 29
#      27 clone_url = f"https://github.com/{repo_full_name}.git"
#      28 try:
# ---> 29     subprocess.run(
#      30         ["git", "clone", "--depth", "500", clone_url, repo_dir],
#      31         check=True,
#      32         timeout=10
#      33     )
#      34 except Exception as e:
#      35     print(f"  Failed to clone {repo_full_name}: {e}")
#
# File /usr/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File /usr/lib/python3.13/subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1219     endtime = None
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#    1226     if timeout is not None:
#
# File /usr/lib/python3.13/subprocess.py:2151, in Popen._communicate(self, input, endtime, orig_timeout)
#    2148                     key.fileobj.close()
#    2149                 self._fileobj2output[key.fileobj].append(data)
# -> 2151 self.wait(timeout=self._remaining_time(endtime))
#    2153 # All data exchanged.  Translate lists into strings.
#    2154 if stdout is not None:
#
# File /usr/lib/python3.13/subprocess.py:1277, in Popen.wait(self, timeout)
#    1275     endtime = _time() + timeout
#    1276 try:
# -> 1277     return self._wait(timeout=timeout)
#    1278 except KeyboardInterrupt:
#    1279     # https://bugs.python.org/issue25942
#    1280     # The first keyboard interrupt waits briefly for the child to
#    1281     # exit under the common assumption that it also received the ^C
#    1282     # generated SIGINT and will exit rapidly.
#    1283     if timeout is not None:
#
# File /usr/lib/python3.13/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051     finally:
#    2052         self._waitpid_lock.release()
# -> 2053 remaining = self._remaining_time(endtime)
#    2054 if remaining <= 0:
#    2055     raise TimeoutExpired(self.args, timeout)
#
# File /usr/lib/python3.13/subprocess.py:1257, in Popen._remaining_time(self, endtime)
#    1255     return None
#    1256 else:
# -> 1257     return endtime - _time()
#
# KeyboardInterrupt:

# %%
# Nuovo approccio: sfruttare la dependency graph API di GitHub

import requests
import json
import time
from collections import defaultdict

def get_dependency_graph(repo_full_name):
    """
    Ottiene le dipendenze usando l'API dependency graph di GitHub
    """
    # L'API dependency graph richiede un token con scope 'repo' o 'public_repo'
    url = f"https://api.github.com/repos/{repo_full_name}/dependency-graph/manifests"
    
    try:
        response = requests.get(url, headers=headers)
        print(response.status_code, response.text)
        
        if response.status_code == 200:
            manifests = response.json()
            dependencies = []
            
            for manifest in manifests:
                # Ogni manifest può avere dipendenze
                if 'dependencies' in manifest:
                    for dep_type, deps in manifest['dependencies'].items():
                        for dep in deps:
                            dependency_info = {
                                'package_url': dep.get('package_url', ''),
                                'metadata': dep.get('metadata', {}),
                                'relationship': dep.get('relationship', dep_type),
                                'scope': dep.get('scope', 'runtime'),
                                'requirements': dep.get('requirements', '')
                            }
                            dependencies.append(dependency_info)
            
            return dependencies
            
        elif response.status_code == 404:
            print(f"  Dependency graph not available for {repo_full_name}")
            return []
        elif response.status_code == 403:
            print(f"  Access forbidden for {repo_full_name} - might need different token permissions")
            return []
        else:
            print(f"  Error {response.status_code} for {repo_full_name}: {response.text}")
            return []
            
    except Exception as e:
        print(f"  Exception getting dependencies for {repo_full_name}: {e}")
        return []

def parse_package_url(package_url):
    """
    Estrae informazioni dal package URL (purl format)
    """
    if not package_url:
        return None
    
    # Format: pkg:maven/group.id/artifact.id@version
    try:
        parts = package_url.split('/')
        if len(parts) >= 3 and parts[0] == 'pkg:maven':
            group_id = parts[1]
            artifact_version = parts[2]
            
            if '@' in artifact_version:
                artifact_id, version = artifact_version.split('@', 1)
            else:
                artifact_id = artifact_version
                version = 'unknown'
                
            return {
                'groupId': group_id,
                'artifactId': artifact_id,
                'version': version,
                'ecosystem': 'maven'
            }
    except:
        pass
    
    return None

# Struttura per raccogliere tutte le dipendenze
all_dependencies_graph = []
dependency_stats = defaultdict(int)

print("Scraping dependencies usando GitHub Dependency Graph API...")
print(f"Processando {len(repos['layer1'])} repositories...")

processed_count = 0
failed_count = 0

for i, repo in enumerate(repos['layer1']):
    repo_full_name = repo["full_name"]
    
    print(f"[{i+1}/{len(repos['layer1'])}] Analyzing {repo_full_name}...")
    
    try:
        dependencies = get_dependency_graph(repo_full_name)
        
        # Processa ogni dipendenza
        for dep in dependencies:
            parsed = parse_package_url(dep.get('package_url', ''))
            if parsed:
                dependency_entry = {
                    'repository': repo_full_name,
                    'groupId': parsed['groupId'],
                    'artifactId': parsed['artifactId'],
                    'version': parsed['version'],
                    'ecosystem': parsed['ecosystem'],
                    'relationship': dep.get('relationship', 'unknown'),
                    'scope': dep.get('scope', 'runtime'),
                    'requirements': dep.get('requirements', ''),
                    'metadata': dep.get('metadata', {})
                }
                all_dependencies_graph.append(dependency_entry)
                
                # Statistiche
                dep_key = f"{parsed['groupId']}:{parsed['artifactId']}"
                dependency_stats[dep_key] += 1
        
        print(f"  Found {len(dependencies)} dependencies")
        processed_count += 1
        
        # Rate limiting - API ha limiti più stretti
        time.sleep(0.5)
        
    except Exception as e:
        print(f"  Error processing {repo_full_name}: {e}")
        failed_count += 1
        continue

print(f"\nScraping completato!")
print(f"Repositories processati: {processed_count}")
print(f"Repositories falliti: {failed_count}")
print(f"Totale dipendenze trovate: {len(all_dependencies_graph)}")
print(f"Dipendenze uniche: {len(dependency_stats)}")

# Salva i risultati
with open("/tmp/dependencies_graph_api.json", "w") as f:
    json.dump(all_dependencies_graph, f, indent=2)

# Salva le statistiche delle dipendenze più popolari
popular_deps = sorted(dependency_stats.items(), key=lambda x: x[1], reverse=True)
with open("/tmp/popular_dependencies.json", "w") as f:
    json.dump(popular_deps, f, indent=2)

print(f"\nSalvato {len(all_dependencies_graph)} dipendenze in /tmp/dependencies_graph_api.json")
print(f"Salvate statistiche dipendenze in /tmp/popular_dependencies.json")

# Mostra le top 10 dipendenze più usate
print("\nTop 10 dipendenze più utilizzate:")
for dep, count in popular_deps[:10]:
    print(f"  {dep}: {count} repositories")
# Out:
# Scraping dependencies usando GitHub Dependency Graph API...
# Processando 1351 repositories...
# [1/1351] Analyzing winterbe/java8-tutorial...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for winterbe/java8-tutorial
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for winterbe/java8-tutorial
#   Found 0 dependencies
# [2/1351] Analyzing ashishps1/awesome-leetcode-resources...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for ashishps1/awesome-leetcode-resources
#   Found 0 dependencies
# [2/1351] Analyzing ashishps1/awesome-leetcode-resources...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for ashishps1/awesome-leetcode-resources
#   Found 0 dependencies
# [3/1351] Analyzing lihengming/spring-boot-api-project-seed...
# [3/1351] Analyzing lihengming/spring-boot-api-project-seed...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for lihengming/spring-boot-api-project-seed
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for lihengming/spring-boot-api-project-seed
#   Found 0 dependencies
# [4/1351] Analyzing Freelander/Android_Data...
# [4/1351] Analyzing Freelander/Android_Data...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for Freelander/Android_Data
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for Freelander/Android_Data
#   Found 0 dependencies
# [5/1351] Analyzing JakeWharton/hugo...
# [5/1351] Analyzing JakeWharton/hugo...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for JakeWharton/hugo
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for JakeWharton/hugo
#   Found 0 dependencies
# [6/1351] Analyzing Meituan-Dianping/Leaf...
# [6/1351] Analyzing Meituan-Dianping/Leaf...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for Meituan-Dianping/Leaf
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for Meituan-Dianping/Leaf
#   Found 0 dependencies
# [7/1351] Analyzing ityouknow/spring-cloud-examples...
# [7/1351] Analyzing ityouknow/spring-cloud-examples...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for ityouknow/spring-cloud-examples
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for ityouknow/spring-cloud-examples
#   Found 0 dependencies
# [8/1351] Analyzing daimajia/NumberProgressBar...
# [8/1351] Analyzing daimajia/NumberProgressBar...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for daimajia/NumberProgressBar
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for daimajia/NumberProgressBar
#   Found 0 dependencies
# [9/1351] Analyzing LandGrey/SpringBootVulExploit...
# [9/1351] Analyzing LandGrey/SpringBootVulExploit...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for LandGrey/SpringBootVulExploit
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for LandGrey/SpringBootVulExploit
#   Found 0 dependencies
# [10/1351] Analyzing LaurieWired/GhidraMCP...
# [10/1351] Analyzing LaurieWired/GhidraMCP...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for LaurieWired/GhidraMCP
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for LaurieWired/GhidraMCP
#   Found 0 dependencies
# [11/1351] Analyzing javastacks/spring-boot-best-practice...
# [11/1351] Analyzing javastacks/spring-boot-best-practice...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for javastacks/spring-boot-best-practice
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for javastacks/spring-boot-best-practice
#   Found 0 dependencies
# [12/1351] Analyzing rubensousa/ViewPagerCards...
# [12/1351] Analyzing rubensousa/ViewPagerCards...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for rubensousa/ViewPagerCards
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for rubensousa/ViewPagerCards
#   Found 0 dependencies
# [13/1351] Analyzing jbloch/effective-java-3e-source-code...
# [13/1351] Analyzing jbloch/effective-java-3e-source-code...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for jbloch/effective-java-3e-source-code
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for jbloch/effective-java-3e-source-code
#   Found 0 dependencies
# [14/1351] Analyzing rom1v/sndcpy...
# [14/1351] Analyzing rom1v/sndcpy...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for rom1v/sndcpy
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for rom1v/sndcpy
#   Found 0 dependencies
# [15/1351] Analyzing abel533/MyBatis-Spring-Boot...
# [15/1351] Analyzing abel533/MyBatis-Spring-Boot...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for abel533/MyBatis-Spring-Boot
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for abel533/MyBatis-Spring-Boot
#   Found 0 dependencies
# [16/1351] Analyzing bethrobson/Head-First-Design-Patterns...
# [16/1351] Analyzing bethrobson/Head-First-Design-Patterns...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for bethrobson/Head-First-Design-Patterns
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for bethrobson/Head-First-Design-Patterns
#   Found 0 dependencies
# [17/1351] Analyzing java8/Java8InAction...
# [17/1351] Analyzing java8/Java8InAction...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for java8/Java8InAction
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for java8/Java8InAction
#   Found 0 dependencies
# [18/1351] Analyzing facebookarchive/network-connection-class...
# [18/1351] Analyzing facebookarchive/network-connection-class...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for facebookarchive/network-connection-class
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for facebookarchive/network-connection-class
#   Found 0 dependencies
# [19/1351] Analyzing yusugomori/DeepLearning...
# [19/1351] Analyzing yusugomori/DeepLearning...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for yusugomori/DeepLearning
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for yusugomori/DeepLearning
#   Found 0 dependencies
# [20/1351] Analyzing bmelnychuk/AndroidTreeView...
# [20/1351] Analyzing bmelnychuk/AndroidTreeView...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for bmelnychuk/AndroidTreeView
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for bmelnychuk/AndroidTreeView
#   Found 0 dependencies
# [21/1351] Analyzing jasonross/Nuwa...
# [21/1351] Analyzing jasonross/Nuwa...
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for jasonross/Nuwa
#   Found 0 dependencies
# 404 {"message":"Not Found","documentation_url":"https://docs.github.com/rest","status":"404"}
#   Dependency graph not available for jasonross/Nuwa
#   Found 0 dependencies
# [22/1351] Analyzing brianway/webporter...
# [22/1351] Analyzing brianway/webporter...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 100
#      97 print(f"[{i+1}/{len(repos['layer1'])}] Analyzing {repo_full_name}...")
#      99 try:
# --> 100     dependencies = get_dependency_graph(repo_full_name)
#     102     # Processa ogni dipendenza
#     103     for dep in dependencies:
#
# Cell In[69], line 16, in get_dependency_graph(repo_full_name)
#      13 url = f"https://api.github.com/repos/{repo_full_name}/dependency-graph/manifests"
#      15 try:
# ---> 16     response = requests.get(url, headers=headers)
#      17     print(response.status_code, response.text)
#      19     if response.status_code == 200:
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/large-scale-database/venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /usr/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /usr/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(all_dependencies_graph)
# Out:
# []
