# %%
import random
from bson.objectid import ObjectId
import json

#set the random seed for reproducibility
random.seed(42)

def generate_random_object_id():
    """Generate a random ObjectId."""
    return str(ObjectId())

# %%
from datetime import datetime
import bcrypt

def generate_random_version():
    """Generate a random version string."""
    major = random.randint(0, 9)
    minor = random.randint(0, 9)
    patch = random.randint(0, 9)
    return f"{major}.{minor}.{patch}"

def generate_random_description (file_content):
    # search for README.md in file_content
    if "README.md" in file_content:
        return file_content["README.md"][:100]  # Return first 100 characters of README.md content

    if "readme.md" in file_content:
        return file_content["readme.md"][:100]

    for key in file_content:
        if key.lower().endswith('readme.md'):
            return file_content[key][:100]
    
    for key in file_content:
        if key.lower().endswith('.md'):
            return file_content[key][:100]

    return "This is a randomly generated description."

def convert_date(date_str):
    # convert from git date() Tue Jun 27 13:10:39 2023 +0800) to mongodb date format
    
    # Convert to MongoDB Extended JSON date format
    dt = datetime.strptime(date_str, "%a %b %d %H:%M:%S %Y %z")
    return dt.isoformat()

def convert_date_issue(date_str):
    # convert from date (2025-05-26T11:15:46Z) to mongodb date format
    dt = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%SZ")
    return dt.isoformat()

def get_stats(stats):

    file_changed = len(stats.split("\n")) - 1
    stats = stats.split("\n")[-1].strip()
    try:
        insertions = int(stats.split(' insertion')[0].split(' ')[-1])
    except Exception as e:
        insertions = 0
    try:
        deletions = int(stats.split(' deletion')[0].split(' ')[-1])
    except Exception as e:
        deletions = 0
    return file_changed, insertions, deletions

def get_size_kb(obj):
    return len(json.dumps(obj)) / 1024

def return_bycript_password(password):
    """Return a bcrypt hashed password."""
    salt = bcrypt.gensalt()
    hashed = bcrypt.hashpw(password.encode('utf-8'), salt)
    return hashed.decode('utf-8')

# %%
get_stats(".../src/wrapper-validation/wrapper-checksums.json  | 28 ++++++++++++++++++++++\n 1 file changed, 28 insertions(+)")
# Out:
# (1, 28, 0)

# %%
import json
import os
import time
import sys


'''
private String username; (_id)
private String password;
private String email;
private String name;
private String surname;
private String nationality;
private Integer followerNumber;
private Integer followingNumber;
private List<String> comments;
private List<String> projects;
private Boolean isAdmin;
private Instant registrationDate;
'''
users = set()

'''
private String id;
private String name;
private String description;
private String owner;
private String version;
private Instant creationDate;
private List<String> administrators;
private Set<String> fileIds;
'''
project = []

'''
private String id;

// redundant fields to support index, not join operations
private String owner;
private String projectName;

private String path;
private String type;
private Integer size;
private Integer lines;
private Instant lastModified;
private String lastModifiedBy;
private String content;
'''
file = []

'''
private String id;

    @Indexed(name = "idx_commits_author")
    private String author;

    private Integer linesAdded;
    private Integer linesDeleted;
    private Integer filesModified;
    private Instant timestamp;
'''
commit = []

'''
    @JsonProperty("_id")
    private String id;

    private String username;
    private Integer stars;
    private String text;
    private Instant timestamp;
'''
comment = []

# print("Loading repository details from all_repo_details.json...")
# with open('all_repo_details.json', 'r') as f:
#    all_repo_details = json.load(f)

# print("Repository details loaded successfully.")

json_files = [f for f in os.listdir('downloaded_repos') if f.endswith('.json')]

all_repo_details = []
for file_name in json_files:
    all_repo_details.append(file_name[:-5].replace('__', '/'))

j = 0
user_ids_linking = {}
for repo_full_name in all_repo_details:

    print(f"Processing repository {j+1}/{len(all_repo_details)}: {repo_full_name}")
    
    if j % 100 == 0 and j > 0:
        print(f"files: {get_size_kb(file):.1f} KB, commits: {get_size_kb(commit):.1f} KB, comments: {get_size_kb(comment):.1f} KB, projects: {get_size_kb(project):.1f} KB")

    with open(f'downloaded_repos/{json_files[j]}', 'r') as f:
        repo_details = json.load(f)

    j += 1

    if len(repo_details['file_contents']) == 0 or len(repo_details['commits']) == 0 or len(repo_details['contributors']) == 0:
        print(f"Skipping repository {repo_full_name} due to no file contents.")
        continue


    contributors = [c['login'] for c in repo_details['contributors']]
    for c in contributors:
        users.add(c)

    file_ids = []

    repo_id = generate_random_object_id()
    repo_owner = repo_full_name.split('/')[0]
    project_name = repo_full_name.split('/')[-1]

    #analyze commits
    commit_ids = []
    for i in range(len(repo_details['commits'])):
        if len(contributors) == 0:
            repo_details['commits'][i]['author'] = repo_owner
        else:
            repo_details['commits'][i]['author'] = random.choice(contributors)
        repo_details['commits'][i]['id'] = generate_random_object_id()
        file_modified, lines_added, lines_deleted = get_stats(repo_details['commits'][i]['stats'])
        repo_details['commits'][i]['linesAdded'] = lines_added
        repo_details['commits'][i]['linesDeleted'] = lines_deleted
        repo_details['commits'][i]['filesModified'] = file_modified
        repo_details['commits'][i]['timestamp'] = convert_date(repo_details['commits'][i]['date'])
        
        commit.append({
            '_id': repo_details['commits'][i]['id'],
            'author': repo_details['commits'][i]['author'],
            'linesAdded': repo_details['commits'][i]['linesAdded'],
            'linesDeleted': repo_details['commits'][i]['linesDeleted'],
            'filesModified': repo_details['commits'][i]['filesModified'],
            'timestamp': repo_details['commits'][i]['timestamp']
        })

        if repo_details['commits'][i]['author'] not in user_ids_linking:
            user_ids_linking[repo_details['commits'][i]['author']] = {'commitIds': [], 'projectIds': [], 'commentIds': []}
        user_ids_linking[repo_details['commits'][i]['author']]['commitIds'].append(repo_details['commits'][i]['id'])


        commit_ids.append(repo_details['commits'][i]['id'])


    repo_size_attuale = 0
    already_added_files = set()
    for file_name in repo_details['file_contents']:
        # search if it is pom or build.gradle
        if file_name.endswith('pom.xml') or file_name.endswith('build.gradle'):
            # add the file to the project
            file_id = generate_random_object_id()
            file_ids.append(file_id)
            extension = file_name.split('.')[-1]
            content = repo_details['file_contents'][file_name]
            
            
            repo_size_attuale += len(content)

            file.append({
                '_id': file_id,
                'owner': repo_owner,
                'projectName': project_name,
                'path': file_name,
                'type': extension,
                'size': len(content),
                'lines': len(content.split('\n')),
                'lastModified': convert_date(repo_details['commits'][0]['date']),
                'lastModifiedBy': repo_details['commits'][0]['author'], # todo
                'content': content
            })

            already_added_files.add(file_name)

    n_files = 0
    for file_name in repo_details['file_contents']:
        if file_name.startswith('.'):
            continue

        if not '.' in file_name:
            continue

        for subpath in file_name.split('/'):
            if subpath.startswith('.'):
                continue

        if not file_name.split('.')[-1] in ['java', 'xml', 'gradle', 'yml']:
            continue

        if file_name in already_added_files:
            continue

        file_id = generate_random_object_id()
        file_ids.append(file_id)
        extension = file_name.split('.')[-1]
        content = repo_details['file_contents'][file_name]
        
        if len(content) > 10000:
            #print(f"Skipping file {file_name} due to excessive size.")
            continue
    
        repo_size_attuale += len(content)

        file.append({
            '_id': file_id,
            'owner': repo_owner,
            'projectName': project_name,
            'path': file_name,
            'type': extension,
            'size': len(content),
            'lines': len(content.split('\n')),
            'lastModified': convert_date(repo_details['commits'][0]['date']),
            'lastModifiedBy': repo_details['commits'][0]['author'], # todo
            'content': content
        })
        n_files += 1

        if repo_size_attuale > 50000 or n_files > 500:  # 20 KB threshold
            print(f"Skipping repository {repo_full_name} due to excessive size: {repo_size_attuale} bytes, {n_files} files / {len(repo_details['file_contents'])} total files.")
            break


    

    comments = []
    issues_size = 0
    for issue in repo_details['issues'][:100]:
        if not issue['body']:
            continue

        users.add(issue['user']['login'])
        comment = {
            '_id': generate_random_object_id(),
            'username': issue['user']['login'],
            'text': issue['body'][:1000],  # Limit to 1000 characters
            'timestamp': convert_date_issue(issue['created_at']),
            'stars': random.randint(1, 10)  # Randomly generated stars for the comment
        }
        comments.append(comment)
        issues_size += len(issue['body'][:1000])

        if issue['user']['login'] not in user_ids_linking:
            user_ids_linking[issue['user']['login']] = {'commitIds': [], 'projectIds': [], 'commentIds': []}
        user_ids_linking[issue['user']['login']]['commentIds'].append(comment['_id'])


        if issues_size > 20000:
    #        print(f"Skipping repository {repo_full_name} due to excessive issues size: {issues_size} bytes.")
            break

    project.append({
        '_id': repo_id,
        'name': project_name,
        'description': generate_random_description(repo_details['file_contents']),
        'owner': repo_owner,
        'version': generate_random_version(),
        'creationDate': convert_date(repo_details['commits'][-1]['date']),
        'administrators': [u for u in contributors],
        'fileIds': file_ids,
        'comments': comments,
        'commitIds': commit_ids
    })


    if repo_owner not in user_ids_linking:
        user_ids_linking[repo_owner] = {'commitIds': [], 'projectIds': [], 'commentIds': []}
    user_ids_linking[repo_owner]['commentIds'].append(repo_id)


    #time.sleep(0.1)  # To avoid overwhelming the system with too many requests at once
# Out:
# Processing repository 1/1911: jwtk/jjwt
# Skipping repository jwtk/jjwt due to excessive size: 56379 bytes, 1 files / 770 total files.
# Processing repository 2/1911: spring-attic/hystrix-dashboard
# Processing repository 3/1911: IBM/spring-cloud-kubernetes-with-istio
# Processing repository 4/1911: tozny/java-aes-crypto
# Processing repository 5/1911: pucamafra/RxNotification
# Processing repository 6/1911: spartajet/javafx-boot-demo
# Skipping repository spartajet/javafx-boot-demo due to no file contents.
# Processing repository 7/1911: meyskens/NokiaRemote
# Processing repository 8/1911: ViRb3/TrustMeAlready
# Processing repository 9/1911: PetarMarijanovic/RxActivityResult
# Processing repository 10/1911: soranico/tomcat-learn
# Skipping repository soranico/tomcat-learn due to excessive size: 50609 bytes, 6 files / 4019 total files.
# Processing repository 11/1911: su18/JDBC-Attack
# Processing repository 12/1911: commonsguy/cwac-merge
# Processing repository 13/1911: ddalcu/spring-starter
# Processing repository 14/1911: mthiim/dilithium-java
# Processing repository 15/1911: machi12/MyDatabase
# Processing repository 16/1911: microsoft/mssql-jdbc
# Skipping repository microsoft/mssql-jdbc due to excessive size: 51181 bytes, 1 files / 479 total files.
# Processing repository 17/1911: shinyke/Time-NLP
# Processing repository 18/1911: aws-cloudformation/cloudformation-resource-schema
# Processing repository 19/1911: JodaOrg/joda-time
# Skipping repository JodaOrg/joda-time due to excessive size: 51380 bytes, 2 files / 541 total files.
# Processing repository 20/1911: actions/setup-node
# Processing repository 21/1911: Carson-Ho/Search_Layout
# Processing repository 22/1911: FasterXML/jackson-dataformat-xml
# Skipping repository FasterXML/jackson-dataformat-xml due to excessive size: 50360 bytes, 18 files / 386 total files.
# Processing repository 23/1911: linyiqun/hadoop-yarn
# Skipping repository linyiqun/hadoop-yarn due to excessive size: 52749 bytes, 13 files / 58 total files.
# Processing repository 24/1911: Kamilahsantos/Java-week-LinuxTips
# Processing repository 25/1911: alexruiz/fest-util
# Skipping repository alexruiz/fest-util due to excessive size: 51701 bytes, 30 files / 112 total files.
# Processing repository 26/1911: csanuragjain/APKRepatcher
# Processing repository 27/1911: CN-GuoZiyang/MYDB
# Skipping repository CN-GuoZiyang/MYDB due to excessive size: 50667 bytes, 28 files / 110 total files.
# Processing repository 28/1911: mitre/device-admin-sample
# Processing repository 29/1911: jimweirich/builder
# Processing repository 30/1911: AlexLiuSheng/BadgeView
# Processing repository 31/1911: robbertvanwaveren/boot-stateless-auth
# Processing repository 32/1911: datafaker-net/datafaker
# Skipping repository datafaker-net/datafaker due to excessive size: 58173 bytes, 15 files / 9958 total files.
# Processing repository 33/1911: nadam/userinfobot
# Processing repository 34/1911: alexlauerman/UpdateToken
# Skipping repository alexlauerman/UpdateToken due to excessive size: 50760 bytes, 21 files / 76 total files.
# Processing repository 35/1911: Arronlong/httpclientutil
# Skipping repository Arronlong/httpclientutil due to excessive size: 55105 bytes, 12 files / 58 total files.
# Processing repository 36/1911: mybatis/spring-boot-starter
# Skipping repository mybatis/spring-boot-starter due to excessive size: 57061 bytes, 1 files / 324 total files.
# Processing repository 37/1911: akka/akka-http
# Skipping repository akka/akka-http due to excessive size: 51766 bytes, 18 files / 1722 total files.
# Processing repository 38/1911: GF-Allen/RecordView
# Processing repository 39/1911: daniel-cottone/Cerberus
# Skipping repository daniel-cottone/Cerberus due to excessive size: 52601 bytes, 26 files / 67 total files.
# Processing repository 40/1911: ruby/bigdecimal
# Processing repository 41/1911: android10/frodo
# Skipping repository android10/frodo due to excessive size: 50205 bytes, 25 files / 118 total files.
# Processing repository 42/1911: pires/spring-boot-shiro-orientdb
# Processing repository 43/1911: yeyunHZ/YunMap
# Processing repository 44/1911: longjiazuo/spring4.x-project
# Processing repository 45/1911: Ebryx/AES-Killer
# Processing repository 46/1911: danylovolokh/HashTagHelper
# Processing repository 47/1911: baihui212/tsharding
# Skipping repository baihui212/tsharding due to excessive size: 51944 bytes, 38 files / 88 total files.
# Processing repository 48/1911: bingoogolapple/BGAUpdate-Android
# Processing repository 49/1911: QPC-WORLDWIDE/robolectric
# Skipping repository QPC-WORLDWIDE/robolectric due to no file contents.
# Processing repository 50/1911: eclipse-ee4j/expressly
# Skipping repository eclipse-ee4j/expressly due to excessive size: 51259 bytes, 12 files / 128 total files.
# Processing repository 51/1911: apache/maven-plugin-testing
# Skipping repository apache/maven-plugin-testing due to excessive size: 53319 bytes, 17 files / 89 total files.
# Processing repository 52/1911: cachix/install-nix-action
# Processing repository 53/1911: mikeknep/SOLID
# Processing repository 54/1911: anncode1/Curso-POO-Platzi
# Processing repository 55/1911: winteryoung/yanwte2
# Skipping repository winteryoung/yanwte2 due to excessive size: 50275 bytes, 52 files / 188 total files.
# Processing repository 56/1911: tokudu/AndroidPushNotificationsDemo
# Processing repository 57/1911: smartcat-labs/cassandra-migration-tool-java
# Skipping repository smartcat-labs/cassandra-migration-tool-java due to excessive size: 54131 bytes, 21 files / 64 total files.
# Processing repository 58/1911: card-io/react-native-card-io
# Processing repository 59/1911: salesforce/gorp
# Skipping repository salesforce/gorp due to excessive size: 50473 bytes, 12 files / 90 total files.
# Processing repository 60/1911: welk1n/ReverseShell-Java
# Processing repository 61/1911: litesuits/android-lite-async
# Processing repository 62/1911: imotov/elasticsearch-facet-script
# Processing repository 63/1911: baomidou/dynamic-datasource
# Skipping repository baomidou/dynamic-datasource due to excessive size: 50642 bytes, 6 files / 221 total files.
# Processing repository 64/1911: mrkmg/node-external-editor
# Processing repository 65/1911: tomdz/storm-esper
# Processing repository 66/1911: LinkedInAttic/play-testng-plugin
# Processing repository 67/1911: sevntu-checkstyle/sevntu.checkstyle
# Skipping repository sevntu-checkstyle/sevntu.checkstyle due to excessive size: 65360 bytes, 1 files / 519 total files.
# Processing repository 68/1911: StriveYee/CustomMybatisGenerator
# Skipping repository StriveYee/CustomMybatisGenerator due to excessive size: 54132 bytes, 6 files / 536 total files.
# Processing repository 69/1911: Ardesco/Selenium-Maven-Template
# Processing repository 70/1911: spring-attic/rest-shell
# Processing repository 71/1911: dingguotao/kafka-src-0.10.1.0
# Skipping repository dingguotao/kafka-src-0.10.1.0 due to excessive size: 56667 bytes, 1 files / 1634 total files.
# Processing repository 72/1911: zxing/zxing
# Skipping repository zxing/zxing due to excessive size: 50007 bytes, 3 files / 2470 total files.
# Processing repository 73/1911: howtoprogram/Kafka-MultiThread-Java-Example
# Processing repository 74/1911: ScaCap/action-surefire-report
# Processing repository 75/1911: nekdenis/Camera2MediaCodec
# Skipping repository nekdenis/Camera2MediaCodec due to excessive size: 51550 bytes, 13 files / 72 total files.
# Processing repository 76/1911: jython/frozen-mirror
# Skipping repository jython/frozen-mirror due to excessive size: 54976 bytes, 29 files / 4100 total files.
# Processing repository 77/1911: Devlight/ArcProgressStackView
# Processing repository 78/1911: hsongxian/SmileRefresh
# Processing repository 79/1911: redesperado/SpringBoot
# Skipping repository redesperado/SpringBoot due to no file contents.
# Processing repository 80/1911: FasterXML/jackson-datatypes-collections
# Skipping repository FasterXML/jackson-datatypes-collections due to excessive size: 52411 bytes, 15 files / 3346 total files.
# Processing repository 81/1911: javaee/javax.annotation
# Skipping repository javaee/javax.annotation due to excessive size: 51716 bytes, 11 files / 51 total files.
# Processing repository 82/1911: oikomi/FishChatServerJava
# Processing repository 83/1911: paypal/resteasy-spring-boot
# Skipping repository paypal/resteasy-spring-boot due to excessive size: 51259 bytes, 23 files / 93 total files.
# Processing repository 84/1911: skyrising/skyblock
# Processing repository 85/1911: ladingwu/ApplicationDemo
# Skipping repository ladingwu/ApplicationDemo due to excessive size: 50388 bytes, 25 files / 69 total files.
# Processing repository 86/1911: venmo/tooltip-view
# Processing repository 87/1911: skeeto/sample-java-project
# Processing repository 88/1911: lokeshgupta1981/Spring-Boot3-Demos
# Skipping repository lokeshgupta1981/Spring-Boot3-Demos due to excessive size: 50524 bytes, 17 files / 286 total files.
# Processing repository 89/1911: LFDT-web3j/web3j
# Skipping repository LFDT-web3j/web3j due to excessive size: 55739 bytes, 10 files / 1143 total files.
# Processing repository 90/1911: TechPrimers/spring-boot-graphql-query-example
# Processing repository 91/1911: AnotherJack/AvoidOnResult
# Processing repository 92/1911: BlackFan/BFScan
# Skipping repository BlackFan/BFScan due to excessive size: 54790 bytes, 14 files / 73 total files.
# Processing repository 93/1911: ForbesLindesay/acorn-globals
# Processing repository 94/1911: ChrisZou/android-unit-testing-tutorial
# Processing repository 95/1911: floatingmuseum/DeviceAdminSample
# Processing repository 96/1911: apache/maven-wagon
# Skipping repository apache/maven-wagon due to excessive size: 65940 bytes, 1 files / 404 total files.
# Processing repository 97/1911: sarvex/JavaPoet
# Skipping repository sarvex/JavaPoet due to excessive size: 51426 bytes, 10 files / 78 total files.
# Processing repository 98/1911: jonschlinkert/arr-flatten
# Processing repository 99/1911: willyancaetano/junit5-exemplos
# Processing repository 100/1911: mimicmobile/okhttp-oauth2-client
# Processing repository 101/1911: mybatis/spring
# files: 3865.3 KB, commits: 1939.0 KB, comments: 0.9 KB, projects: 1434.3 KB
# Skipping repository mybatis/spring due to excessive size: 50638 bytes, 12 files / 334 total files.
# Processing repository 102/1911: jekyll/jekyll-gist
# Processing repository 103/1911: square/seismic
# Processing repository 104/1911: ChrisMayfield/ThinkJavaCode2
# Skipping repository ChrisMayfield/ThinkJavaCode2 due to excessive size: 50366 bytes, 33 files / 200 total files.
# Processing repository 105/1911: Blankeer/XAndroidSocket
# Skipping repository Blankeer/XAndroidSocket due to excessive size: 53310 bytes, 40 files / 101 total files.
# Processing repository 106/1911: rails/coffee-rails
# Processing repository 107/1911: AzimoLabs/AndroidKeyboardWatcher
# Processing repository 108/1911: ZFChen/DBC2XML
# Processing repository 109/1911: blakey22/shadowsocks-java
# Skipping repository blakey22/shadowsocks-java due to excessive size: 50514 bytes, 14 files / 68 total files.
# Processing repository 110/1911: FasterXML/jackson-jaxrs-providers
# Skipping repository FasterXML/jackson-jaxrs-providers due to excessive size: 50338 bytes, 7 files / 2184 total files.
# Processing repository 111/1911: sindresorhus/figures
# Processing repository 112/1911: ethjava/web3j-sample
# Skipping repository ethjava/web3j-sample due to excessive size: 54535 bytes, 16 files / 47 total files.
# Processing repository 113/1911: apache/maven-compiler-plugin
# Skipping repository apache/maven-compiler-plugin due to excessive size: 272417 bytes, 1 files / 632 total files.
# Processing repository 114/1911: apache/commons-configuration
# Skipping repository apache/commons-configuration due to excessive size: 54982 bytes, 5 files / 714 total files.
# Processing repository 115/1911: mybatis/thymeleaf-scripting
# Skipping repository mybatis/thymeleaf-scripting due to excessive size: 56876 bytes, 16 files / 167 total files.
# Processing repository 116/1911: spring-projects/spring-data-commons
# Skipping repository spring-projects/spring-data-commons due to excessive size: 54213 bytes, 18 files / 1215 total files.
# Processing repository 117/1911: shack2/javaserializetools
# Processing repository 118/1911: mcfunley/juds
# Processing repository 119/1911: tunefish/xposed-okhttp-logger
# Processing repository 120/1911: JakeWharton/picasso2-okhttp3-downloader
# Processing repository 121/1911: alephsecurity/general-research-tools
# Processing repository 122/1911: twitter/hpack
# Skipping repository twitter/hpack due to excessive size: 55102 bytes, 12 files / 80 total files.
# Processing repository 123/1911: iceleaf916/ToyVPN
# Processing repository 124/1911: BIOP/qupath-extension-warpy
# Processing repository 125/1911: rohfosho/CordovaCallNumberPlugin
# Processing repository 126/1911: actions/download-artifact
# Processing repository 127/1911: azkevin/swing-drawing-app
# Processing repository 128/1911: Leliana/WhatsThis
# Processing repository 129/1911: NetSPI/xssValidator
# Skipping repository NetSPI/xssValidator due to excessive size: 50815 bytes, 23 files / 145 total files.
# Processing repository 130/1911: gupaoedu-tom/spring5-samples
# Skipping repository gupaoedu-tom/spring5-samples due to excessive size: 50172 bytes, 43 files / 344 total files.
# Processing repository 131/1911: javaee/servlet-spec
# Skipping repository javaee/servlet-spec due to excessive size: 50513 bytes, 7 files / 131 total files.
# Processing repository 132/1911: neoascetic/rawgithack
# Processing repository 133/1911: gwenn/sqlite-dialect
# Processing repository 134/1911: UFOnaut/SimpleTabBar
# Processing repository 135/1911: FreeeBird/hotel
# Skipping repository FreeeBird/hotel due to excessive size: 52401 bytes, 17 files / 106 total files.
# Processing repository 136/1911: openzipkin/brave
# Skipping repository openzipkin/brave due to excessive size: 227734 bytes, 1 files / 1042 total files.
# Processing repository 137/1911: xuwujing/Netty-study
# Skipping repository xuwujing/Netty-study due to excessive size: 50189 bytes, 34 files / 111 total files.
# Processing repository 138/1911: zhouray/SelectableTextView
# Skipping repository zhouray/SelectableTextView due to no file contents.
# Processing repository 139/1911: gabrieldim/ChatSystem-Java
# Processing repository 140/1911: islomar/seven-concurrency-models-in-seven-weeks
# Skipping repository islomar/seven-concurrency-models-in-seven-weeks due to excessive size: 50526 bytes, 11 files / 324 total files.
# Processing repository 141/1911: webjars/js-cookie
# Processing repository 142/1911: junit-team/junit4
# Skipping repository junit-team/junit4 due to excessive size: 54137 bytes, 16 files / 606 total files.
# Processing repository 143/1911: lucky-bai/MSolver
# Processing repository 144/1911: easymock/objenesis
# Skipping repository easymock/objenesis due to excessive size: 50032 bytes, 2 files / 213 total files.
# Processing repository 145/1911: gwenshap/kafka-examples
# Skipping repository gwenshap/kafka-examples due to excessive size: 51179 bytes, 15 files / 75 total files.
# Processing repository 146/1911: YoKeyword/ItemTouchHelperDemo
# Processing repository 147/1911: lets-mica/mica-auto
# Skipping repository lets-mica/mica-auto due to excessive size: 52311 bytes, 27 files / 102 total files.
# Processing repository 148/1911: Takhion/renderthread
# Processing repository 149/1911: turbolinks/turbolinks-rails
# Processing repository 150/1911: yuzh233/redis-learning
# Skipping repository yuzh233/redis-learning due to excessive size: 52121 bytes, 27 files / 150 total files.
# Processing repository 151/1911: AoEiuV020/VpnProxy
# Skipping repository AoEiuV020/VpnProxy due to excessive size: 52877 bytes, 19 files / 80 total files.
# Processing repository 152/1911: PortSwigger/collaborator-everywhere
# Processing repository 153/1911: mojohaus/wagon-maven-plugin
# Skipping repository mojohaus/wagon-maven-plugin due to excessive size: 50338 bytes, 9 files / 119 total files.
# Processing repository 154/1911: undera/cmdrunner
# Processing repository 155/1911: peekler/GDG
# Skipping repository peekler/GDG due to excessive size: 51591 bytes, 26 files / 71 total files.
# Processing repository 156/1911: oblac/jodd-util
# Skipping repository oblac/jodd-util due to excessive size: 50398 bytes, 18 files / 350 total files.
# Processing repository 157/1911: apolloconfig/apollo-use-cases
# Skipping repository apolloconfig/apollo-use-cases due to excessive size: 50057 bytes, 17 files / 122 total files.
# Processing repository 158/1911: assertj/assertj
# Skipping repository assertj/assertj due to excessive size: 75829 bytes, 1 files / 5212 total files.
# Processing repository 159/1911: tinmegali/simple-mvp
# Skipping repository tinmegali/simple-mvp due to excessive size: 51794 bytes, 13 files / 68 total files.
# Processing repository 160/1911: Bossyao168/RotateMenu
# Processing repository 161/1911: kiwi-bop/flutter_crashlytics
# Processing repository 162/1911: oliverlockwood/jenkinsfile-idea-plugin
# Processing repository 163/1911: marcoaparaujo/padroes-projeto
# Skipping repository marcoaparaujo/padroes-projeto due to excessive size: 50008 bytes, 46 files / 192 total files.
# Processing repository 164/1911: danielwegener/logback-kafka-appender
# Skipping repository danielwegener/logback-kafka-appender due to excessive size: 50181 bytes, 14 files / 73 total files.
# Processing repository 165/1911: actions/cache
# Processing repository 166/1911: jqwik-team/jqwik-spring
# Processing repository 167/1911: gshjd/RainbowCache
# Processing repository 168/1911: square/retrofit
# Skipping repository square/retrofit due to excessive size: 53792 bytes, 10 files / 1143 total files.
# Processing repository 169/1911: darconeous/gauss-key-card
# Processing repository 170/1911: ShihooWang/DaemonLibrary
# Skipping repository ShihooWang/DaemonLibrary due to excessive size: 50608 bytes, 23 files / 77 total files.
# Processing repository 171/1911: kai-morich/SimpleUsbTerminal
# Processing repository 172/1911: YClimb/wxpay-sdk
# Skipping repository YClimb/wxpay-sdk due to excessive size: 54273 bytes, 16 files / 53 total files.
# Processing repository 173/1911: mojohaus/versions
# Skipping repository mojohaus/versions due to excessive size: 480566 bytes, 1 files / 1356 total files.
# Processing repository 174/1911: gradle/actions
# Processing repository 175/1911: zzak/sdoc
# Processing repository 176/1911: JessYanCoding/CameraFilters
# Skipping repository JessYanCoding/CameraFilters due to excessive size: 52288 bytes, 30 files / 97 total files.
# Processing repository 177/1911: Learn2Crack/android-nfc-tag-read-write
# Processing repository 178/1911: openairplay/AirPlayAuth
# Processing repository 179/1911: PebbleTemplates/pebble
# Skipping repository PebbleTemplates/pebble due to excessive size: 53359 bytes, 21 files / 847 total files.
# Processing repository 180/1911: YuriMB/WinSCP-Password-Recovery
# Processing repository 181/1911: raonigabriel/spring-qrcode-example
# Processing repository 182/1911: sebthom/oval
# Skipping repository sebthom/oval due to excessive size: 51803 bytes, 11 files / 472 total files.
# Processing repository 183/1911: lucko/jar-relocator
# Processing repository 184/1911: dmilicic/Android-Clean-Boilerplate
# Processing repository 185/1911: rspec/rspec-mocks
# Processing repository 186/1911: NikoYuwono/ToolbarPanel
# Processing repository 187/1911: Jaouan/ViewsFrom
# Processing repository 188/1911: GcsSloop/encrypt
# Skipping repository GcsSloop/encrypt due to excessive size: 50364 bytes, 17 files / 62 total files.
# Processing repository 189/1911: stfalcon-studio/SmsVerifyCatcher
# Processing repository 190/1911: ModeShape/modeshape
# Skipping repository ModeShape/modeshape due to excessive size: 406943 bytes, 1 files / 2999 total files.
# Processing repository 191/1911: hypery2k/cordova-certificate-plugin
# Processing repository 192/1911: yongjhih/mocker
# Processing repository 193/1911: robinfjb/Android_SDK_Hotfix
# Skipping repository robinfjb/Android_SDK_Hotfix due to excessive size: 50342 bytes, 36 files / 114 total files.
# Processing repository 194/1911: codeurjc/Curso-Kubernetes
# Processing repository 195/1911: team-supercharge/rxsnappy
# Processing repository 196/1911: leftso/demo-spring-boot-security-oauth2
# Skipping repository leftso/demo-spring-boot-security-oauth2 due to excessive size: 53028 bytes, 21 files / 57 total files.
# Processing repository 197/1911: DeekshithSN/sample-web-application
# Processing repository 198/1911: sushistack/oauth-login-be
# Skipping repository sushistack/oauth-login-be due to excessive size: 50357 bytes, 32 files / 72 total files.
# Processing repository 199/1911: andydevacc/MentionEditText
# Processing repository 200/1911: Conan924/NacosExploit
# Processing repository 201/1911: rails/spring
# files: 8980.9 KB, commits: 4160.0 KB, comments: 0.3 KB, projects: 3055.5 KB
# Processing repository 202/1911: moditect/moditect
# Skipping repository moditect/moditect due to excessive size: 60340 bytes, 1 files / 104 total files.
# Processing repository 203/1911: rails/arel
# Processing repository 204/1911: spring-attic/spring-cloud-security
# Skipping repository spring-attic/spring-cloud-security due to excessive size: 51211 bytes, 12 files / 116 total files.
# Processing repository 205/1911: gaoyuyue/MyUploader-Backend
# Processing repository 206/1911: saki4510t/ScreenRecordingSample
# Processing repository 207/1911: JakeWharton/hugo
# Processing repository 208/1911: Noisyfox/NoExclamation
# Processing repository 209/1911: chrisoei/JCIP
# Skipping repository chrisoei/JCIP due to no file contents.
# Processing repository 210/1911: heroku/devcenter-gradle
# Processing repository 211/1911: aliyun/aliyun-odps-java-sdk
# Skipping repository aliyun/aliyun-odps-java-sdk due to excessive size: 66091 bytes, 1 files / 2197 total files.
# Processing repository 212/1911: AReallyGoodName/OfflineReverseGeocode
# Processing repository 213/1911: sonatype/jarjar-maven-plugin
# Skipping repository sonatype/jarjar-maven-plugin due to excessive size: 51466 bytes, 25 files / 89 total files.
# Processing repository 214/1911: v5tech/elasticsearch-jest-example
# Processing repository 215/1911: flow/flow-bin
# Processing repository 216/1911: jvm-build-service-code/glassfish-jaf
# Skipping repository jvm-build-service-code/glassfish-jaf due to excessive size: 53404 bytes, 7 files / 57 total files.
# Processing repository 217/1911: mechero/spring-boot-testing-strategies
# Processing repository 218/1911: VitZhou/java-test-demo
# Skipping repository VitZhou/java-test-demo due to no file contents.
# Processing repository 219/1911: NickstaDB/SerializationDumper
# Processing repository 220/1911: Lotus6/ThinkphpGUI
# Processing repository 221/1911: apache/commons-lang
# Skipping repository apache/commons-lang due to excessive size: 55106 bytes, 5 files / 618 total files.
# Processing repository 222/1911: Bohemiana/godzilla_erkai
# Skipping repository Bohemiana/godzilla_erkai due to excessive size: 52667 bytes, 12 files / 54 total files.
# Processing repository 223/1911: dpa99c/cordova-plugin-request-location-accuracy
# Processing repository 224/1911: payatu/diva-android
# Skipping repository payatu/diva-android due to no file contents.
# Processing repository 225/1911: xuningjack/RequestPermission
# Processing repository 226/1911: Bakumon/NumberAnimTextView
# Processing repository 227/1911: mojohaus/buildnumber-maven-plugin
# Skipping repository mojohaus/buildnumber-maven-plugin due to excessive size: 53523 bytes, 1 files / 156 total files.
# Processing repository 228/1911: xm0625/VideoSniffer
# Processing repository 229/1911: iTXTech/mirai-console-loader
# Skipping repository iTXTech/mirai-console-loader due to excessive size: 55026 bytes, 16 files / 82 total files.
# Processing repository 230/1911: bacen/pix-dict-quickstart
# Processing repository 231/1911: navinreddy20/Javacode
# Skipping repository navinreddy20/Javacode due to excessive size: 50967 bytes, 88 files / 165 total files.
# Processing repository 232/1911: hongxialiu/DateChooseWheelViewDemo
# Skipping repository hongxialiu/DateChooseWheelViewDemo due to excessive size: 51196 bytes, 24 files / 72 total files.
# Processing repository 233/1911: alibaba/easyexcel
# Skipping repository alibaba/easyexcel due to excessive size: 53038 bytes, 21 files / 652 total files.
# Processing repository 234/1911: mxdldev/android-mvp-dagger2-flytranslate
# Skipping repository mxdldev/android-mvp-dagger2-flytranslate due to excessive size: 50966 bytes, 44 files / 86 total files.
# Processing repository 235/1911: shalskar/PeekAndPop
# Processing repository 236/1911: xuningjack/ServiceKeep
# Processing repository 237/1911: bert82503/commons-pool2-sr
# Skipping repository bert82503/commons-pool2-sr due to excessive size: 50734 bytes, 8 files / 52 total files.
# Processing repository 238/1911: TheCherno/EventSystem
# Skipping repository TheCherno/EventSystem due to no file contents.
# Processing repository 239/1911: bmob/bmob-java-sdk
# Processing repository 240/1911: SpringCloud/spring-cloud-dubbo
# Processing repository 241/1911: Haoshenqi0123/holiday
# Processing repository 242/1911: cucumber/cucumber-jvm
# Skipping repository cucumber/cucumber-jvm due to excessive size: 172125 bytes, 1 files / 1233 total files.
# Processing repository 243/1911: blondiebytes/30-Days-of-Code
# Skipping repository blondiebytes/30-Days-of-Code due to excessive size: 51614 bytes, 42 files / 379 total files.
# Processing repository 244/1911: sevenshal/oksharedprefs
# Processing repository 245/1911: jeff-leo/SpikeSystem
# Processing repository 246/1911: mewebstudio/java-spring-boot-boilerplate
# Skipping repository mewebstudio/java-spring-boot-boilerplate due to excessive size: 51781 bytes, 17 files / 182 total files.
# Processing repository 247/1911: EdisonTalk/EDT.SpringCloud.Samples
# Skipping repository EdisonTalk/EDT.SpringCloud.Samples due to no file contents.
# Processing repository 248/1911: fchenxi/easykafka
# Skipping repository fchenxi/easykafka due to excessive size: 50369 bytes, 7 files / 221 total files.
# Processing repository 249/1911: rockswang/java-curl
# Processing repository 250/1911: apangin/nalim
# Processing repository 251/1911: spring-projects/spring-session
# Skipping repository spring-projects/spring-session due to excessive size: 57222 bytes, 12 files / 875 total files.
# Processing repository 252/1911: LMAX-Exchange/disruptor
# Skipping repository LMAX-Exchange/disruptor due to excessive size: 54489 bytes, 26 files / 340 total files.
# Processing repository 253/1911: Maximvdw/SpigotSite-API
# Processing repository 254/1911: teaey/apns4j
# Skipping repository teaey/apns4j due to excessive size: 53529 bytes, 27 files / 66 total files.
# Processing repository 255/1911: mojohaus/animal-sniffer
# Skipping repository mojohaus/animal-sniffer due to excessive size: 168075 bytes, 1 files / 256 total files.
# Processing repository 256/1911: webjars/jquery
# Processing repository 257/1911: 4ZM/slurp
# Processing repository 258/1911: j-easy/easy-flows
# Skipping repository j-easy/easy-flows due to excessive size: 53430 bytes, 16 files / 57 total files.
# Processing repository 259/1911: springfox/springfox
# Skipping repository springfox/springfox due to excessive size: 50363 bytes, 11 files / 1488 total files.
# Processing repository 260/1911: MachineryEnchantress/SpeakingCaliperApp
# Processing repository 261/1911: samdjstevens/java-totp
# Skipping repository samdjstevens/java-totp due to excessive size: 50412 bytes, 32 files / 78 total files.
# Processing repository 262/1911: amazon-archives/cloudwatch-logs-subscription-consumer
# Skipping repository amazon-archives/cloudwatch-logs-subscription-consumer due to excessive size: 50176 bytes, 15 files / 73 total files.
# Processing repository 263/1911: Y4Sec-Team/CVE-2023-21939
# Processing repository 264/1911: mfaisalkhatri/selenium4poc
# Skipping repository mfaisalkhatri/selenium4poc due to excessive size: 50362 bytes, 16 files / 141 total files.
# Processing repository 265/1911: ysrc/Liudao
# Processing repository 266/1911: Geekholt/TvFocus
# Skipping repository Geekholt/TvFocus due to excessive size: 52738 bytes, 34 files / 93 total files.
# Processing repository 267/1911: gf-huanchupk/SpringBootLearning
# Skipping repository gf-huanchupk/SpringBootLearning due to excessive size: 62787 bytes, 1 files / 359 total files.
# Processing repository 268/1911: pristineio/webrtc-android
# Skipping repository pristineio/webrtc-android due to no file contents.
# Processing repository 269/1911: atomikos/transactions-essentials
# Skipping repository atomikos/transactions-essentials due to excessive size: 60491 bytes, 1 files / 486 total files.
# Processing repository 270/1911: google/samba-documents-provider
# Skipping repository google/samba-documents-provider due to excessive size: 54142 bytes, 17 files / 132 total files.
# Processing repository 271/1911: smallrye/jandex
# Skipping repository smallrye/jandex due to excessive size: 58531 bytes, 1 files / 389 total files.
# Processing repository 272/1911: gs666/RulerDemo
# Processing repository 273/1911: VazkiiModsArchive/Ambience
# Skipping repository VazkiiModsArchive/Ambience due to excessive size: 54126 bytes, 15 files / 89 total files.
# Processing repository 274/1911: zhuguohui/HorizontalPage
# Skipping repository zhuguohui/HorizontalPage due to excessive size: 52362 bytes, 21 files / 67 total files.
# Processing repository 275/1911: ganchaoyang/spring-tutorial
# Skipping repository ganchaoyang/spring-tutorial due to excessive size: 51213 bytes, 7 files / 222 total files.
# Processing repository 276/1911: wangzheng0822/ratelimiter4j
# Skipping repository wangzheng0822/ratelimiter4j due to excessive size: 58574 bytes, 22 files / 137 total files.
# Processing repository 277/1911: lucko/commodore
# Processing repository 278/1911: dolyw/ShiroJwt
# Skipping repository dolyw/ShiroJwt due to excessive size: 50930 bytes, 33 files / 94 total files.
# Processing repository 279/1911: panpf/spider-web-score-view
# Processing repository 280/1911: bndtools/bnd
# Skipping repository bndtools/bnd due to no file contents.
# Processing repository 281/1911: Luosunce/material-design-data
# Processing repository 282/1911: apache/lucene-solr
# Processing repository 283/1911: bjmashibing/NettyStudy
# Processing repository 284/1911: nbarishok/RxMvpAndroid
# Skipping repository nbarishok/RxMvpAndroid due to excessive size: 52040 bytes, 50 files / 140 total files.
# Processing repository 285/1911: daimajia/NumberProgressBar
# Processing repository 286/1911: jamesisaac/react-native-background-task
# Processing repository 287/1911: sofastack/sofa-bolt
# Skipping repository sofastack/sofa-bolt due to excessive size: 52363 bytes, 8 files / 360 total files.
# Processing repository 288/1911: antwankakki/FabricView
# Processing repository 289/1911: networknt/json-schema-validator
# Skipping repository networknt/json-schema-validator due to excessive size: 50370 bytes, 9 files / 1329 total files.
# Processing repository 290/1911: testcontainers/testcontainers-java
# Skipping repository testcontainers/testcontainers-java due to excessive size: 53002 bytes, 2 files / 1386 total files.
# Processing repository 291/1911: caarmen/SunriseSunset
# Processing repository 292/1911: thomasjungblut/glove
# Processing repository 293/1911: ithedan/CustomViewBgUi
# Processing repository 294/1911: ReactiveCircus/android-emulator-runner
# Processing repository 295/1911: MdFarhanRaja/SearchableSpinner
# Processing repository 296/1911: babel/babel
# Processing repository 297/1911: aress31/burpgpt
# Processing repository 298/1911: jenkinsci/windows-slaves-plugin
# Processing repository 299/1911: chenerzhu/proxy-pool
# Skipping repository chenerzhu/proxy-pool due to excessive size: 52622 bytes, 20 files / 79 total files.
# Processing repository 300/1911: swtestacademy/TestNGParallel
# Processing repository 301/1911: matthewrkula/SecretTextView
# files: 13242.0 KB, commits: 6040.5 KB, comments: 0.2 KB, projects: 4615.6 KB
# Processing repository 302/1911: arquillian/arquillian-cube
# Skipping repository arquillian/arquillian-cube due to excessive size: 217666 bytes, 1 files / 1076 total files.
# Processing repository 303/1911: aserg-ufmg/demo-ci
# Processing repository 304/1911: UglyTroLL/Douban-Java-SDK-OAuth2
# Skipping repository UglyTroLL/Douban-Java-SDK-OAuth2 due to excessive size: 51367 bytes, 8 files / 96 total files.
# Processing repository 305/1911: vvsuperman/coolmq
# Processing repository 306/1911: codelibs/ranklib
# Skipping repository codelibs/ranklib due to excessive size: 58474 bytes, 18 files / 101 total files.
# Processing repository 307/1911: RealTia/CS-GOClickGUI
# Processing repository 308/1911: thlorenz/ansicolors
# Processing repository 309/1911: TestingResearchIllinois/NonDex
# Skipping repository TestingResearchIllinois/NonDex due to excessive size: 50209 bytes, 3 files / 232 total files.
# Processing repository 310/1911: xmikos/SnooperStopper
# Processing repository 311/1911: gzsll/WebViewJavascriptBridge
# Processing repository 312/1911: OmniOneID/did-crypto-sdk-server
# Skipping repository OmniOneID/did-crypto-sdk-server due to excessive size: 51685 bytes, 23 files / 85 total files.
# Processing repository 313/1911: jpelgrom/retrofit2-oauthrefresh
# Processing repository 314/1911: holmofy/debezium-datetime-converter
# Processing repository 315/1911: actions/create-release
# Processing repository 316/1911: xstevens/syslog-kafka
# Processing repository 317/1911: lplping/tensorflow-for-java
# Processing repository 318/1911: mojohaus/build-helper-maven-plugin
# Skipping repository mojohaus/build-helper-maven-plugin due to excessive size: 118864 bytes, 1 files / 271 total files.
# Processing repository 319/1911: svn2github/protostuff
# Skipping repository svn2github/protostuff due to no file contents.
# Processing repository 320/1911: google/caliper
# Skipping repository google/caliper due to excessive size: 50218 bytes, 3 files / 337 total files.
# Processing repository 321/1911: opersys/opersys-hal-hw
# Processing repository 322/1911: yizhuoyan/game-bull-fighting-java-console
# Processing repository 323/1911: jpbaterabsb/java-avancado
# Processing repository 324/1911: jakartaee/servlet
# Skipping repository jakartaee/servlet due to excessive size: 60579 bytes, 1 files / 1388 total files.
# Processing repository 325/1911: paul-hammant/paranamer
# Skipping repository paul-hammant/paranamer due to excessive size: 50405 bytes, 8 files / 108 total files.
# Processing repository 326/1911: Svti/Axis2Shell
# Processing repository 327/1911: projectlombok/lombok
# Skipping repository projectlombok/lombok due to excessive size: 54574 bytes, 83 files / 2362 total files.
# Processing repository 328/1911: toddlipcon/jetty-hadoop-fix
# Skipping repository toddlipcon/jetty-hadoop-fix due to excessive size: 142673 bytes, 1 files / 792 total files.
# Processing repository 329/1911: apache/commons-exec
# Skipping repository apache/commons-exec due to excessive size: 53326 bytes, 18 files / 175 total files.
# Processing repository 330/1911: forcesunseen/graphquail
# Processing repository 331/1911: jiahongfei/ViewGroupDemo
# Processing repository 332/1911: pbakondy/cordova-plugin-speechrecognition
# Processing repository 333/1911: MWHunter/KohiKB
# Processing repository 334/1911: bfwg/springboot-jwt-starter
# Skipping repository bfwg/springboot-jwt-starter due to excessive size: 50723 bytes, 28 files / 75 total files.
# Processing repository 335/1911: onlylemi/MapView
# Skipping repository onlylemi/MapView due to excessive size: 52732 bytes, 19 files / 83 total files.
# Processing repository 336/1911: chenyurong/song-parser-spi-demo
# Processing repository 337/1911: googlearchive/cloud-pubsub-samples-java
# Skipping repository googlearchive/cloud-pubsub-samples-java due to excessive size: 52005 bytes, 4 files / 73 total files.
# Processing repository 338/1911: beckchr/juel
# Skipping repository beckchr/juel due to excessive size: 56690 bytes, 16 files / 229 total files.
# Processing repository 339/1911: draftcode/ijaas
# Processing repository 340/1911: alexruiz/fest-assert-2.x
# Skipping repository alexruiz/fest-assert-2.x due to excessive size: 50761 bytes, 34 files / 1050 total files.
# Processing repository 341/1911: Lihuanghe/SMSGate
# Skipping repository Lihuanghe/SMSGate due to excessive size: 52225 bytes, 12 files / 488 total files.
# Processing repository 342/1911: balsikandar/Best-Coding-practices-in-android
# Processing repository 343/1911: nkcoder/quartz-explained
# Skipping repository nkcoder/quartz-explained due to excessive size: 51124 bytes, 4 files / 423 total files.
# Processing repository 344/1911: fangyidong/json-simple
# Processing repository 345/1911: facebookarchive/network-connection-class
# Processing repository 346/1911: cami-la/loops-e-arrays
# Skipping repository cami-la/loops-e-arrays due to excessive size: 50779 bytes, 45 files / 90 total files.
# Processing repository 347/1911: rohitdate/Crime-Analysis-Prediction-System
# Processing repository 348/1911: eclipse-tycho/tycho
# Skipping repository eclipse-tycho/tycho due to excessive size: 1227193 bytes, 1 files / 5986 total files.
# Processing repository 349/1911: apache/velocity-tools
# Skipping repository apache/velocity-tools due to excessive size: 58684 bytes, 7 files / 273 total files.
# Processing repository 350/1911: johnbhurst/dbunit
# Skipping repository johnbhurst/dbunit due to excessive size: 52207 bytes, 1 files / 696 total files.
# Processing repository 351/1911: a-voyager/BluetoothHelper
# Processing repository 352/1911: in28minutes/functional-programming-with-java
# Processing repository 353/1911: lovedise/PermissionGen
# Processing repository 354/1911: pyloque/rpckids
# Skipping repository pyloque/rpckids due to no file contents.
# Processing repository 355/1911: vaadin/framework
# Skipping repository vaadin/framework due to no file contents.
# Processing repository 356/1911: gshevtsov/TroikaDumper
# Processing repository 357/1911: mrprince/sonar-p3c-pmd
# Skipping repository mrprince/sonar-p3c-pmd due to excessive size: 50715 bytes, 20 files / 438 total files.
# Processing repository 358/1911: gjtorikian/commonmarker
# Processing repository 359/1911: proselytear/jwtappdemo
# Processing repository 360/1911: normanmaurer/netty-in-action
# Skipping repository normanmaurer/netty-in-action due to excessive size: 50302 bytes, 27 files / 143 total files.
# Processing repository 361/1911: spring-attic/platform
# Skipping repository spring-attic/platform due to excessive size: 55831 bytes, 1 files / 106 total files.
# Processing repository 362/1911: oyhk/redis-sentinel-java
# Processing repository 363/1911: tumblr/Graywater
# Processing repository 364/1911: lizhangqu/CoreLink
# Processing repository 365/1911: JakeWharton/salvage
# Processing repository 366/1911: romannurik/Android-SwipeToDismiss
# Processing repository 367/1911: asciidoctor/asciidoctorj-pdf
# Processing repository 368/1911: GoogleChromeLabs/cronet-sample
# Processing repository 369/1911: angelicaweiler/transacao-api
# Processing repository 370/1911: apache/velocity-engine
# Skipping repository apache/velocity-engine due to excessive size: 54120 bytes, 3 files / 782 total files.
# Processing repository 371/1911: 0x727/SpringBootExploit
# Skipping repository 0x727/SpringBootExploit due to excessive size: 50498 bytes, 17 files / 106 total files.
# Processing repository 372/1911: sxdtzhaoxinguo/micaicms-ssmb
# Processing repository 373/1911: apg-mobile/android-round-textview
# Processing repository 374/1911: jakartaee/jaf-api
# Skipping repository jakartaee/jaf-api due to excessive size: 50709 bytes, 7 files / 95 total files.
# Processing repository 375/1911: binaryfork/Spanny
# Processing repository 376/1911: federicodotta/ghidra-scripts
# Processing repository 377/1911: umermansoor/TrafficDistributor
# Processing repository 378/1911: V-I-C-T-O-R/DataM
# Skipping repository V-I-C-T-O-R/DataM due to excessive size: 51927 bytes, 26 files / 103 total files.
# Processing repository 379/1911: ktoso/git-commit-id-debugging
# Skipping repository ktoso/git-commit-id-debugging due to excessive size: 56009 bytes, 13 files / 376 total files.
# Processing repository 380/1911: ndori/RxLoading
# Skipping repository ndori/RxLoading due to excessive size: 50546 bytes, 32 files / 127 total files.
# Processing repository 381/1911: SweetInk/jrebel-mybatisplus
# Processing repository 382/1911: mathiazhagan01/DrawableColorChange
# Processing repository 383/1911: rails/jbuilder
# Processing repository 384/1911: zhangchuangiie/SimpleMybatis
# Processing repository 385/1911: sindresorhus/array-differ
# Processing repository 386/1911: wikibook/spring-security
# Skipping repository wikibook/spring-security due to excessive size: 177433 bytes, 1 files / 956 total files.
# Processing repository 387/1911: apache/logging-log4j1
# Skipping repository apache/logging-log4j1 due to excessive size: 51891 bytes, 8 files / 690 total files.
# Processing repository 388/1911: bimalkaf/Android_Offline_NotesApp
# Processing repository 389/1911: shekhargulati/strman-java
# Processing repository 390/1911: ityouknow/spring-cloud-examples
# Skipping repository ityouknow/spring-cloud-examples due to excessive size: 90830 bytes, 1 files / 277 total files.
# Processing repository 391/1911: JackOfMostTrades/gadgetinspector
# Skipping repository JackOfMostTrades/gadgetinspector due to excessive size: 53976 bytes, 21 files / 64 total files.
# Processing repository 392/1911: licheedev/Custom-Glide-ModelLoader-Demo
# Processing repository 393/1911: zhangyaoshu/c3p0
# Skipping repository zhangyaoshu/c3p0 due to no file contents.
# Processing repository 394/1911: FasterXML/jackson-dataformats-text
# Skipping repository FasterXML/jackson-dataformats-text due to excessive size: 51033 bytes, 16 files / 1867 total files.
# Processing repository 395/1911: istanbuljs/append-transform
# Processing repository 396/1911: tuyulers5/jav88
# Skipping repository tuyulers5/jav88 due to excessive size: 56628 bytes, 10 files / 130 total files.
# Processing repository 397/1911: amplab/graphx
# Skipping repository amplab/graphx due to excessive size: 140374 bytes, 1 files / 7993 total files.
# Processing repository 398/1911: octopress/colorator
# Processing repository 399/1911: apache/dubbo-rpc-jsonrpc
# Processing repository 400/1911: tomj74/chunk-springmvc
# Processing repository 401/1911: lihengming/spring-boot-api-project-seed
# files: 19218.1 KB, commits: 8058.6 KB, comments: 0.1 KB, projects: 6086.9 KB
# Processing repository 402/1911: cprcrack/VideoEnabledWebView
# Processing repository 403/1911: charles-sudo/Android-Studio-Plugins-cn
# Processing repository 404/1911: gouwuwo/database-ddl-transfer
# Skipping repository gouwuwo/database-ddl-transfer due to excessive size: 51217 bytes, 16 files / 67 total files.
# Processing repository 405/1911: Meituan-Dianping/Leaf
# Skipping repository Meituan-Dianping/Leaf due to excessive size: 50583 bytes, 32 files / 74 total files.
# Processing repository 406/1911: TNG/ArchUnit
# Skipping repository TNG/ArchUnit due to excessive size: 54401 bytes, 12 files / 1702 total files.
# Processing repository 407/1911: unclebob/fitnesse
# Skipping repository unclebob/fitnesse due to excessive size: 52088 bytes, 16 files / 2927 total files.
# Processing repository 408/1911: michaelcgood/spring-data-redis-example
# Processing repository 409/1911: binarywang/WxJava
# Skipping repository binarywang/WxJava due to excessive size: 101155 bytes, 1 files / 3752 total files.
# Processing repository 410/1911: yinjihuan/elastic-job-spring-boot-starter
# Processing repository 411/1911: githubofrico/DataStructure
# Skipping repository githubofrico/DataStructure due to excessive size: 56258 bytes, 31 files / 66 total files.
# Processing repository 412/1911: xiaoxiae/PurePursuitAlgorithm
# Processing repository 413/1911: EsotericSoftware/kryo
# Skipping repository EsotericSoftware/kryo due to excessive size: 50978 bytes, 7 files / 256 total files.
# Processing repository 414/1911: cn/GB2260.java
# Processing repository 415/1911: beautifulSoup/RtmpRecoder
# Processing repository 416/1911: akhilbattula/android-camerax-java
# Processing repository 417/1911: asciidoctor/asciidoctor
# Processing repository 418/1911: javaee/jaxb-spec
# Skipping repository javaee/jaxb-spec due to excessive size: 56729 bytes, 5 files / 176 total files.
# Processing repository 419/1911: shmilyah/spring-cloud-components
# Processing repository 420/1911: zhangtaii/react-native-google-place-picker
# Processing repository 421/1911: ebanx/swipe-button
# Processing repository 422/1911: bkiers/retrofit-oauth
# Processing repository 423/1911: ypresto/android-transcoder
# Skipping repository ypresto/android-transcoder due to excessive size: 51753 bytes, 18 files / 97 total files.
# Processing repository 424/1911: Microservice-API-Patterns/DDD-Library
# Processing repository 425/1911: jonashackt/tutorial-soap-spring-boot-cxf
# Skipping repository jonashackt/tutorial-soap-spring-boot-cxf due to excessive size: 56560 bytes, 11 files / 272 total files.
# Processing repository 426/1911: tuyrk/303-java-offter
# Processing repository 427/1911: DefinitelyTyped/DefinitelyTyped
# Processing repository 428/1911: Mojang/slicer
# Processing repository 429/1911: openjdk/jmh
# Skipping repository openjdk/jmh due to excessive size: 133070 bytes, 1 files / 1171 total files.
# Processing repository 430/1911: buptdavid/datastructure
# Skipping repository buptdavid/datastructure due to excessive size: 51315 bytes, 43 files / 123 total files.
# Processing repository 431/1911: laobie/NineGridImageView
# Processing repository 432/1911: dk-lockdown/seata-demo
# Skipping repository dk-lockdown/seata-demo due to excessive size: 55840 bytes, 19 files / 122 total files.
# Processing repository 433/1911: Java-Techie-jt/spring-cloud-gatway-hystrix
# Processing repository 434/1911: mperham/connection_pool
# Processing repository 435/1911: nantaphop/HoverTouchView
# Processing repository 436/1911: daCapricorn/ArcMenu
# Processing repository 437/1911: ilahi123/Taxi-Booking-Android-App
# Skipping repository ilahi123/Taxi-Booking-Android-App due to excessive size: 53506 bytes, 37 files / 95 total files.
# Processing repository 438/1911: googlesamples/android-play-publisher-api
# Processing repository 439/1911: 1nikolas/play-integrity-checker-app
# Processing repository 440/1911: bonifaido/dexmaker
# Skipping repository bonifaido/dexmaker due to excessive size: 50990 bytes, 14 files / 351 total files.
# Processing repository 441/1911: mojohaus/javacc-maven-plugin
# Skipping repository mojohaus/javacc-maven-plugin due to excessive size: 65814 bytes, 1 files / 230 total files.
# Processing repository 442/1911: ladingwu/ImageLoaderFramework
# Skipping repository ladingwu/ImageLoaderFramework due to excessive size: 52509 bytes, 31 files / 98 total files.
# Processing repository 443/1911: lianggzone/springboot-action
# Skipping repository lianggzone/springboot-action due to excessive size: 50451 bytes, 28 files / 241 total files.
# Processing repository 444/1911: alibaba/fastjson2
# Skipping repository alibaba/fastjson2 due to excessive size: 162358 bytes, 1 files / 4787 total files.
# Processing repository 445/1911: hufrea/keysh
# Skipping repository hufrea/keysh due to excessive size: 52175 bytes, 15 files / 88 total files.
# Processing repository 446/1911: chenssy89/jutils
# Skipping repository chenssy89/jutils due to excessive size: 52199 bytes, 16 files / 57 total files.
# Processing repository 447/1911: f111fei/react-native-unity-view
# Processing repository 448/1911: jyqq163/keycloak-services-social-weixin
# Processing repository 449/1911: duanyikang/Develop-SDK
# Processing repository 450/1911: indeedeng/mph-table
# Skipping repository indeedeng/mph-table due to excessive size: 50217 bytes, 34 files / 122 total files.
# Processing repository 451/1911: ce-automne/TomcatMemShell
# Skipping repository ce-automne/TomcatMemShell due to excessive size: 51191 bytes, 10 files / 49 total files.
# Processing repository 452/1911: sdaschner/scalable-coffee-shop
# Skipping repository sdaschner/scalable-coffee-shop due to excessive size: 50226 bytes, 36 files / 151 total files.
# Processing repository 453/1911: jjenkov/java-nio-server
# Processing repository 454/1911: lewky/seckill
# Processing repository 455/1911: yexuan910812/NativeImageView
# Processing repository 456/1911: gordonad/spring-data-demos
# Skipping repository gordonad/spring-data-demos due to excessive size: 86091 bytes, 1 files / 162 total files.
# Processing repository 457/1911: callicoder/spring-boot-websocket-chat-demo
# Processing repository 458/1911: jasonross/Nuwa
# Processing repository 459/1911: linux-china/dubbo3
# Skipping repository linux-china/dubbo3 due to excessive size: 94151 bytes, 1 files / 1350 total files.
# Processing repository 460/1911: jonschlinkert/align-text
# Processing repository 461/1911: aleksandr-m/gitflow-maven-plugin
# ...
# Processing repository 1776/1911: rafadelnero/design-patterns-saga
# Skipping repository rafadelnero/design-patterns-saga due to excessive size: 50058 bytes, 80 files / 165 total files.
# Processing repository 1777/1911: apache/commons-text
# Skipping repository apache/commons-text due to excessive size: 58113 bytes, 6 files / 286 total files.
# Processing repository 1778/1911: go-cqhttp/for-java
# Skipping repository go-cqhttp/for-java due to excessive size: 51471 bytes, 45 files / 124 total files.
# Processing repository 1779/1911: ReactiveX/RxJavaMath
# Processing repository 1780/1911: adonixis/android-submit-credit-card-flow
# Processing repository 1781/1911: hawx/guard-shell
# Processing repository 1782/1911: apolloconfig/apollo-java
# Skipping repository apolloconfig/apollo-java due to excessive size: 50988 bytes, 7 files / 549 total files.
# Processing repository 1783/1911: Karabosithole/LearnJavaSnakeGame
# Processing repository 1784/1911: SeleniumHQ/selenium
# Skipping repository SeleniumHQ/selenium due to excessive size: 53326 bytes, 8 files / 5353 total files.
# Processing repository 1785/1911: spotify/dockerfile-maven
# Skipping repository spotify/dockerfile-maven due to excessive size: 51447 bytes, 1 files / 139 total files.
# Processing repository 1786/1911: micrometer-metrics/tracing
# Skipping repository micrometer-metrics/tracing due to excessive size: 53230 bytes, 8 files / 400 total files.
# Processing repository 1787/1911: rails/jquery-rails
# Processing repository 1788/1911: reljicd/spring-boot-blog
# Processing repository 1789/1911: chalk/chalk
# Processing repository 1790/1911: mattprecious/swirl
# Skipping repository mattprecious/swirl due to excessive size: 51041 bytes, 44 files / 124 total files.
# Processing repository 1791/1911: niorgai/Android-Resource-Usage-Count
# Processing repository 1792/1911: runk/node-chardet
# Processing repository 1793/1911: researchgate/azkaban-ldap-usermanager
# Processing repository 1794/1911: google/firing-range
# Skipping repository google/firing-range due to excessive size: 50201 bytes, 16 files / 305 total files.
# Processing repository 1795/1911: remkop/picocli
# Skipping repository remkop/picocli due to excessive size: 51999 bytes, 2 files / 1467 total files.
# Processing repository 1796/1911: jerickson314/sdscanner
# Processing repository 1797/1911: w3blogfr/zebra-zpl
# Skipping repository w3blogfr/zebra-zpl due to excessive size: 50538 bytes, 22 files / 67 total files.
# Processing repository 1798/1911: godot-sdk-integrations/godot-google-play-billing
# Processing repository 1799/1911: mittorn/virglrenderer-android
# Processing repository 1800/1911: edvin/fxlauncher
# Processing repository 1801/1911: luxiaoxun/NettyRpc
# files: 105254.2 KB, commits: 35642.6 KB, comments: 0.7 KB, projects: 27124.7 KB
# Skipping repository luxiaoxun/NettyRpc due to excessive size: 50231 bytes, 14 files / 100 total files.
# Processing repository 1802/1911: lets-mica/mica-example
# Processing repository 1803/1911: subchen/jetbrick-template-2x
# Skipping repository subchen/jetbrick-template-2x due to excessive size: 50825 bytes, 16 files / 265 total files.
# Processing repository 1804/1911: amigoscode/login-registration-backend
# Processing repository 1805/1911: whyalwaysmea/Spring-Security
# Skipping repository whyalwaysmea/Spring-Security due to excessive size: 50796 bytes, 38 files / 107 total files.
# Processing repository 1806/1911: CrazyBunQnQ/MybatisPluginKeygen
# Processing repository 1807/1911: safeYYY/easyHook
# Processing repository 1808/1911: mojohaus/exec-maven-plugin
# Skipping repository mojohaus/exec-maven-plugin due to excessive size: 115557 bytes, 1 files / 297 total files.
# Processing repository 1809/1911: AxonFramework/AxonBank
# Skipping repository AxonFramework/AxonBank due to excessive size: 52677 bytes, 33 files / 95 total files.
# Processing repository 1810/1911: aowubulao/auto-cpdaily
# Processing repository 1811/1911: RobotTeam/JavaPhash
# Processing repository 1812/1911: undera/jmeter-plugins
# Skipping repository undera/jmeter-plugins due to excessive size: 101799 bytes, 1 files / 763 total files.
# Processing repository 1813/1911: hengyunabc/redis-id-generator
# Processing repository 1814/1911: wikibook/clean-architecture
# Skipping repository wikibook/clean-architecture due to excessive size: 51447 bytes, 36 files / 77 total files.
# Processing repository 1815/1911: alphamu/android-widget-fanmenu
# Processing repository 1816/1911: deepin-community/el-api
# Skipping repository deepin-community/el-api due to excessive size: 52249 bytes, 8 files / 82 total files.
# Processing repository 1817/1911: frost373/w2j-cli
# Skipping repository frost373/w2j-cli due to excessive size: 50167 bytes, 26 files / 88 total files.
# Processing repository 1818/1911: dev-share/database-transform-tool
# Skipping repository dev-share/database-transform-tool due to excessive size: 54441 bytes, 9 files / 73 total files.
# Processing repository 1819/1911: shazam/shazamcrest
# Skipping repository shazam/shazamcrest due to excessive size: 52553 bytes, 15 files / 83 total files.
# Processing repository 1820/1911: linux-china/toolchains-maven-plugin
# Processing repository 1821/1911: belerweb/pinyin4j
# Skipping repository belerweb/pinyin4j due to excessive size: 53358 bytes, 13 files / 104 total files.
# Processing repository 1822/1911: satya164/react-native-in-app-purchase
# Processing repository 1823/1911: LeadroyaL/fastjson-blacklist
# Processing repository 1824/1911: xuyisheng/AccessibilityUtil
# Skipping repository xuyisheng/AccessibilityUtil due to no file contents.
# Processing repository 1825/1911: gilbutITbook/080337
# Skipping repository gilbutITbook/080337 due to excessive size: 51451 bytes, 45 files / 116 total files.
# Processing repository 1826/1911: SargerasWang/ExcelUtil
# Processing repository 1827/1911: mrme2014/TableRowTextView
# Processing repository 1828/1911: secoba/HLog
# Skipping repository secoba/HLog due to no file contents.
# Processing repository 1829/1911: kylelin1998/ChatGPTForTelegram
# Skipping repository kylelin1998/ChatGPTForTelegram due to excessive size: 50847 bytes, 16 files / 119 total files.
# Processing repository 1830/1911: alibaba/druid
# Skipping repository alibaba/druid due to excessive size: 58591 bytes, 1 files / 6251 total files.
# Processing repository 1831/1911: mikkipastel/VideoPlanet
# Processing repository 1832/1911: jboss-remoting/jboss-marshalling
# Skipping repository jboss-remoting/jboss-marshalling due to excessive size: 52306 bytes, 16 files / 258 total files.
# Processing repository 1833/1911: fstab/http2-examples
# Skipping repository fstab/http2-examples due to excessive size: 50902 bytes, 13 files / 64 total files.
# Processing repository 1834/1911: JorringHsiao/custom-sse
# Processing repository 1835/1911: phith0n/JavaThings
# Skipping repository phith0n/JavaThings due to excessive size: 52322 bytes, 26 files / 81 total files.
# Processing repository 1836/1911: zhangyanbo2007/youkefu
# Skipping repository zhangyanbo2007/youkefu due to excessive size: 51729 bytes, 8 files / 1823 total files.
# Processing repository 1837/1911: Jay-Goo/M3U8Downloader
# Skipping repository Jay-Goo/M3U8Downloader due to excessive size: 51578 bytes, 26 files / 82 total files.
# Processing repository 1838/1911: actions/checkout
# Processing repository 1839/1911: lianghuan-xatu/Jd-Pruchase-Kill-dev
# Skipping repository lianghuan-xatu/Jd-Pruchase-Kill-dev due to no file contents.
# Processing repository 1840/1911: forcedotcom/EMP-Connector
# Processing repository 1841/1911: toohandsome/xiaomi2meidi
# Skipping repository toohandsome/xiaomi2meidi due to excessive size: 50683 bytes, 36 files / 101 total files.
# Processing repository 1842/1911: aws/aws-sdk-java
# Skipping repository aws/aws-sdk-java due to no file contents.
# Processing repository 1843/1911: fourbrother/AXMLEditor
# Processing repository 1844/1911: smxiazi/NEW_xp_CAPTCHA
# Processing repository 1845/1911: EalenXie/spring-microservice-ddd
# Skipping repository EalenXie/spring-microservice-ddd due to excessive size: 50709 bytes, 36 files / 79 total files.
# Processing repository 1846/1911: TechPrimers/grpc-spring-boot-example
# Skipping repository TechPrimers/grpc-spring-boot-example due to no file contents.
# Processing repository 1847/1911: huyuanxin/CMeKGCrawler
# Skipping repository huyuanxin/CMeKGCrawler due to excessive size: 50493 bytes, 39 files / 87 total files.
# Processing repository 1848/1911: spring-cloud/spring-cloud-config
# Skipping repository spring-cloud/spring-cloud-config due to excessive size: 51838 bytes, 6 files / 899 total files.
# Processing repository 1849/1911: gybin02/jet-aop
# Processing repository 1850/1911: gogamoga/velocity-engine-1.6.4
# Skipping repository gogamoga/velocity-engine-1.6.4 due to excessive size: 53156 bytes, 22 files / 806 total files.
# Processing repository 1851/1911: spring-projects/spring-security
# Skipping repository spring-projects/spring-security due to excessive size: 50462 bytes, 13 files / 4960 total files.
# Processing repository 1852/1911: microbun/elasticsearch-thulac-plugin
# Skipping repository microbun/elasticsearch-thulac-plugin due to excessive size: 50857 bytes, 28 files / 93 total files.
# Processing repository 1853/1911: bytedeco/procamtracker
# Processing repository 1854/1911: Ahmed-Adel-Ismail/CommandsMap
# Processing repository 1855/1911: escline/InstallCert
# Processing repository 1856/1911: LXYan2333/Fabric-Bedrock-Miner
# Processing repository 1857/1911: vlonjat-gashi/progress-activity
# Processing repository 1858/1911: nixuechao/security-jwt
# Processing repository 1859/1911: xuwujing/java-study
# Skipping repository xuwujing/java-study due to excessive size: 50077 bytes, 31 files / 318 total files.
# Processing repository 1860/1911: all-contributors/cli
# Processing repository 1861/1911: dathoangse/java-cqrs-commandbus
# Skipping repository dathoangse/java-cqrs-commandbus due to excessive size: 51065 bytes, 29 files / 84 total files.
# Processing repository 1862/1911: bonnyfone/vectalign
# Skipping repository bonnyfone/vectalign due to excessive size: 54933 bytes, 13 files / 51 total files.
# Processing repository 1863/1911: Ardesco/Query
# Processing repository 1864/1911: netgloo/spring-boot-samples
# Skipping repository netgloo/spring-boot-samples due to excessive size: 50319 bytes, 26 files / 131 total files.
# Processing repository 1865/1911: paulmach/Text-Edit-for-Android
# Skipping repository paulmach/Text-Edit-for-Android due to excessive size: 50008 bytes, 29 files / 60 total files.
# Processing repository 1866/1911: liudongdong0909/mybatis-generator-core-fix
# Skipping repository liudongdong0909/mybatis-generator-core-fix due to excessive size: 55538 bytes, 14 files / 341 total files.
# Processing repository 1867/1911: yargs/cliui
# Processing repository 1868/1911: amaurycrickx/recognito
# Skipping repository amaurycrickx/recognito due to excessive size: 50171 bytes, 14 files / 58 total files.
# Processing repository 1869/1911: UnquietCode/JState
# Skipping repository UnquietCode/JState due to excessive size: 52286 bytes, 14 files / 62 total files.
# Processing repository 1870/1911: yumengbdw/DividerItemDecoration
# Skipping repository yumengbdw/DividerItemDecoration due to no file contents.
# Processing repository 1871/1911: hibernate/hibernate-validator
# Skipping repository hibernate/hibernate-validator due to excessive size: 280706 bytes, 1 files / 2244 total files.
# Processing repository 1872/1911: balamaci/rxjava-walkthrough
# Skipping repository balamaci/rxjava-walkthrough due to excessive size: 53987 bytes, 9 files / 41 total files.
# Processing repository 1873/1911: OneSourceCat/XxlJob-Hessian-RCE
# Processing repository 1874/1911: As-Zach/GeoServer-SpringBoot
# Skipping repository As-Zach/GeoServer-SpringBoot due to excessive size: 50600 bytes, 13 files / 158 total files.
# Processing repository 1875/1911: simplesteph/kafka-connect-github-source
# Skipping repository simplesteph/kafka-connect-github-source due to excessive size: 53796 bytes, 17 files / 63 total files.
# Processing repository 1876/1911: hyperledger-archives/fabric-api-archive
# Skipping repository hyperledger-archives/fabric-api-archive due to excessive size: 51691 bytes, 10 files / 98 total files.
# Processing repository 1877/1911: mukel/llama3.java
# Processing repository 1878/1911: gamerforEA/Minecraft-ClientFixer
# Processing repository 1879/1911: winterbe/java8-explorer
# Processing repository 1880/1911: jneat/minibus
# Processing repository 1881/1911: nbphpcouncil/nb-ci-plugin
# Skipping repository nbphpcouncil/nb-ci-plugin due to excessive size: 52032 bytes, 14 files / 97 total files.
# Processing repository 1882/1911: leandrosnazareth/pdv-api
# Skipping repository leandrosnazareth/pdv-api due to excessive size: 53507 bytes, 27 files / 83 total files.
# Processing repository 1883/1911: IzZzI/BackUpDemo
# Processing repository 1884/1911: gousiosg/java-callgraph
# Processing repository 1885/1911: bjmashibing/JUC
# Skipping repository bjmashibing/JUC due to excessive size: 50453 bytes, 47 files / 181 total files.
# Processing repository 1886/1911: hitherejoe/Aware
# Skipping repository hitherejoe/Aware due to excessive size: 53078 bytes, 11 files / 63 total files.
# Processing repository 1887/1911: pumadong/cl-member
# Skipping repository pumadong/cl-member due to excessive size: 54554 bytes, 21 files / 101 total files.
# Processing repository 1888/1911: gumyns/Progress-for-Retrofit-2
# Processing repository 1889/1911: mojohaus/appassembler
# Skipping repository mojohaus/appassembler due to excessive size: 221321 bytes, 1 files / 522 total files.
# Processing repository 1890/1911: mojohaus/flatten-maven-plugin
# Skipping repository mojohaus/flatten-maven-plugin due to excessive size: 188669 bytes, 1 files / 350 total files.
# Processing repository 1891/1911: FasterXML/jackson-databind
# Skipping repository FasterXML/jackson-databind due to excessive size: 55175 bytes, 7 files / 1506 total files.
# Processing repository 1892/1911: KISLAYA-SRI/THE-METRO-APP
# Processing repository 1893/1911: jshttp/accepts
# Processing repository 1894/1911: kaxi4it/EditTextInRecyclerViewDemo
# Processing repository 1895/1911: actions/setup-java
# Processing repository 1896/1911: eclipse-ee4j/yasson
# Skipping repository eclipse-ee4j/yasson due to excessive size: 50531 bytes, 6 files / 624 total files.
# Processing repository 1897/1911: HubSpot/jackson-datatype-protobuf
# Skipping repository HubSpot/jackson-datatype-protobuf due to excessive size: 53385 bytes, 17 files / 133 total files.
# Processing repository 1898/1911: sidiqpermana/mvp-repositorypattern
# Processing repository 1899/1911: illuzor/Android-Sharing-Extension-ANE
# Processing repository 1900/1911: tomakehurst/crash-lab
# Skipping repository tomakehurst/crash-lab due to excessive size: 52492 bytes, 28 files / 76 total files.
# Processing repository 1901/1911: benjiman/statemachine
# files: 110150.8 KB, commits: 37181.5 KB, comments: 0.5 KB, projects: 28355.5 KB
# Skipping repository benjiman/statemachine due to no file contents.
# Processing repository 1902/1911: annabergite/abg-rpc
# Skipping repository annabergite/abg-rpc due to excessive size: 53586 bytes, 4 files / 289 total files.
# Processing repository 1903/1911: yusugomori/DeepLearning
# Processing repository 1904/1911: sourcey/materiallogindemo
# Processing repository 1905/1911: JustCoding-Hai/subtlechat
# Skipping repository JustCoding-Hai/subtlechat due to excessive size: 51345 bytes, 29 files / 106 total files.
# Processing repository 1906/1911: majidgolshadi/Android-Download-Manager-Pro
# Skipping repository majidgolshadi/Android-Download-Manager-Pro due to excessive size: 54085 bytes, 25 files / 55 total files.
# Processing repository 1907/1911: Cybereason/Logout4Shell
# Processing repository 1908/1911: AnliaLee/BookPage
# Processing repository 1909/1911: khmarbaise/maven-training
# Skipping repository khmarbaise/maven-training due to excessive size: 100679 bytes, 1 files / 280 total files.
# Processing repository 1910/1911: microg/GoogleServicesFrameworkIncludes
# Processing repository 1911/1911: allgood/OpenCV-3.1.0-Android
# Skipping repository allgood/OpenCV-3.1.0-Android due to excessive size: 50677 bytes, 11 files / 147 total files.

# %%
# save documents in json files
with open('mongo_projects.json', 'w') as f:
    json.dump(project, f, indent=2)
with open('mongo_files.json', 'w') as f:
    json.dump(file, f, indent=2)
with open('mongo_commits.json', 'w') as f:
    json.dump(commit, f, indent=2)


with open('temp_users.json', 'w') as f:
    json.dump(list(users), f, indent=2)
with open('temp_user_ids_lining.json', 'w') as f:
    json.dump(user_ids_linking, f, indent=2)

#with open('mongo_comments.json', 'w') as f:
#    json.dump(comment, f, indent=2)

# %%
import requests
import time
from datetime import datetime
import os

from dotenv import load_dotenv

load_dotenv()  # Loads .env file into environment
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN")

# GitHub API configuration
GITHUB_API_URL = "https://api.github.com/users/"

headers = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

def fetch_user_info(username):
    """Fetch user information from GitHub API."""
    try:
        response = requests.get(f"{GITHUB_API_URL}{username}", headers=headers)
        
        if response.status_code == 200:
            user_data = response.json()
            print(user_data)
            # {'login': 'wec246810',
            #  'id': 20639489, 
            #  'node_id': 'MDQ6VXNlcjIwNjM5NDg5', 
            #  'avatar_url': 'https://avatars.githubusercontent.com/u/20639489?v=4', 
            #  'gravatar_id': '', 
            #  'url': 'https://api.github.com/users/wec246810', 
            #  'html_url': 'https://github.com/wec246810', 
            #  'followers_url': 'https://api.github.com/users/wec246810/followers', 
            #  'following_url': 'https://api.github.com/users/wec246810/following{/other_user}', 
            #  'gists_url': 'https://api.github.com/users/wec246810/gists{/gist_id}', 
            #  'starred_url': 'https://api.github.com/users/wec246810/starred{/owner}{/repo}', 
            #  'subscriptions_url': 'https://api.github.com/users/wec246810/subscriptions', 
            #  'organizations_url': 'https://api.github.com/users/wec246810/orgs', 
            #  'repos_url': 'https://api.github.com/users/wec246810/repos', 
            #  'events_url': 'https://api.github.com/users/wec246810/events{/privacy}', 
            #  'received_events_url': 'https://api.github.com/users/wec246810/received_events', 
            #  'type': 'User', 
            #  'user_view_type': 'public', 
            #  'site_admin': False, 
            #  'name': None, 
            #  'company': None, 
            #  'blog': '', 
            #  'location': None, 
            #  'email': None, 
            #  'hireable': None, 
            #  'bio': None, 
            #  'twitter_username': None, 
            #  'public_repos': 19, 
            #  'public_gists': 0, 
            #  'followers': 7, 
            #  'following': 0, 
            #  'created_at': '2016-07-25T09:46:41Z', 
            #  'updated_at': '2025-04-13T05:38:35Z'}

            name_surname = user_data.get("name", "").split() if user_data.get("name") else None
            name = name_surname[0] if name_surname else None
            surname = " ".join(name_surname[1:]) if (name_surname and len(name_surname) > 1) else None

            

            if user_data.get("site_admin", False):
                # Append the raw response to a log file for debugging/auditing
                with open("github_user_api_responses.log", "a", encoding="utf-8") as logf:
                    logf.write(f"site_admin {username}: {response.text}\n")
            
            if user_data.get("type", "User") != "User":
                # Append the raw response to a log file for debugging/auditing
                with open("github_user_api_responses.log", "a", encoding="utf-8") as logf:
                    logf.write(f"{username}: {response.text}\n")

            res = {
                "_id": username,
                "password": return_bycript_password(username),  # Use username as password for testing simplicity
                "email": user_data.get("email", None),
                "name": name,
                "surname": surname,
                "nationality": user_data.get("location", None),
                "followerNumber": user_data.get("followers", 0),
                "followingNumber": user_data.get("following", 0),
                "commentIds": user_ids_linking[username]['commentIds'] if (username in user_ids_linking and len(user_ids_linking[username]['commentIds'])) else None,
                "projectIds": user_ids_linking[username]['projectIds'] if (username in user_ids_linking and len(user_ids_linking[username]['projectIds'])) else None,
                "commitIds": user_ids_linking[username]['commitIds'] if (username in user_ids_linking and len(user_ids_linking[username]['commitIds'])) else None,
                "isAdmin": user_data.get("site_admin", False),
                "registrationDate": user_data.get("created_at", datetime.now().isoformat())
            }

            # return only non None values of res
            return {k: v for k, v in res.items() if v is not None}

        elif response.status_code == 404:
            print(f"User {username} not found")
            return None
        elif response.status_code == 403:
            print(f"Rate limit exceeded for user {username}. Skipping...")
            return None
        else:
            print(f"Error fetching user {username}: {response.status_code}")
            return None
            
    except Exception as e:
        print(f"Exception fetching user {username}: {e}")
        return None

# %%
# Convert users set to list for processing
#users_list = list(users) # uncomment first time
print(f"Total users to fetch: {len(users_list)}")

# Fetch all users
#all_users = []  # uncomment first time
#for i, username in enumerate(users_list[5813:]):
for i in range(5813, len(users_list)):
    username = users_list[i]
    print(f"Fetching user {i+1}/{len(users_list)}: {username}")
    
    user_info = fetch_user_info(username)
    if user_info:
        all_users.append(user_info)
    
    # Add small delay between requests to be respectful
    time.sleep(0.8) # api limit is 5k per hour

# Save final users data
with open('mongo_users.json', 'w') as f:
    json.dump(all_users, f, indent=2)

print(f"\nCompleted! Fetched {len(all_users)} users out of {len(users_list)} total users.")
print(f"Data saved to mongo_users.json")

# %%
len(all_users)
with open('mongo_users_corretto.json', 'w') as f:
    json.dump(all_users, f, indent=2)

# %%
all_users
# Out:
# [{'_id': 'wec246810',
#   'password': '$2b$12$us2mBD923jOqc9OIaZp6uetbRDZHSRFP78jF0DexX3aErsO6bjlOO',
#   'followerNumber': 7,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2016-07-25T09:46:41Z',
#   'commentIds': ['68543ace8e6211d047bfaac4']},
#  {'_id': 'mohitsatr',
#   'password': '$2b$12$O1kgrXjatzuq3/A88iw4Pu2gqvP0yM88GNAbkj6Mdo2Kp5GoPAloC',
#   'email': 'atrrmohit@gmail.com',
#   'name': 'Mohit-Attry',
#   'nationality': 'Punjab, India',
#   'followerNumber': 3,
#   'registrationDate': '2008-05-16T16:49:47Z'},
#  {'_id': 'hogimn',
#   'password': '$2b$12$bNby.Z2eZ0xLUL01k0NhPuRBq3P9lx70reacbvPZz.IxU2zi82xu.',
#   'email': 'hogimn@gmail.com',
#   'name': 'Hoki',
#   'surname': 'Min',
#   'nationality': 'Republic of Korea',
#   'followerNumber': 17,
#   'followingNumber': 7,
#   'commitIds': ['68543adb8e6211d047c2f665',
#    '68543adb8e6211d047c2f692',
#    '68543adb8e6211d047c2f695',
#    '68543adb8e6211d047c2f6a2',
#    '68543adb8e6211d047c2f6cd',
#    '68543adb8e6211d047c2f6ce',
#    '68543adb8e6211d047c2f6dd',
#    '68543adb8e6211d047c2f6df',
#    '68543adb8e6211d047c2f6e7',
#    '68543adb8e6211d047c2f6ed',
#    '68543adb8e6211d047c2f70d',
#    '68543adb8e6211d047c2f721',
#    '68543adb8e6211d047c2f741',
#    '68543adb8e6211d047c2f75a',
#    '68543adb8e6211d047c2f772',
#    '68543adb8e6211d047c2f794',
#    '68543adb8e6211d047c2f7a4',
#    '68543adb8e6211d047c2f7d0',
#    '68543adb8e6211d047c2f7d9',
#    '68543adb8e6211d047c2f7e8'],
#   'isAdmin': False,
#   'registrationDate': '2022-08-05T12:15:58Z'},
#  {'_id': 'camerondavison',
#   'password': '$2b$12$.nu.hSWIdDUZwDDfTQrDEuzjdiP4JEy/2.BQNzf/3RLSbAqXFFHKq',
#   'email': 'cameron.davison@gmail.com',
#   'name': 'Cameron',
#   'surname': 'Davison',
#   'nationality': 'Austin, TX',
#   'followerNumber': 26,
#   'followingNumber': 82,
#   'isAdmin': False,
#   'registrationDate': '2009-12-10T06:39:39Z',
#   'commentIds': ['68543acf8e6211d047c01115']},
#  {'_id': 'liuxiujun',
#   'password': '$2b$12$d9qfFlMNNzQvXLkhStSamOH5TP/4GBeE1WhFmPxD.uS0pA35RLXPy',
#   'followerNumber': 2,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2014-12-17T08:17:47Z',
#   'commentIds': ['68543ae08e6211d047c3aef6']},
#  {'_id': 'wwhelloworld',
#   'password': '$2b$12$sr0JcL/BhbxAvtWsn8nuFOYwhemp4nGwNFw6aypK6izfQtQgw.I/e',
#   'name': 'weiwei',
#   'followerNumber': 0,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2017-02-15T09:08:57Z',
#   'commentIds': ['68543ace8e6211d047bf99bc']},
#  {'_id': 'lianetm',
#   'password': '$2b$12$5lSSK8YCuKw48lsMoQ4Q4.2/WxFgJggeC6R32JBlezSf4/KwZC00q',
#   'name': 'Lianet',
#   'surname': 'Magrans',
#   'nationality': 'Montreal, Canada',
#   'followerNumber': 5,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2022-01-25T16:56:51Z',
#   'commentIds': ['68543ad58e6211d047c189fa']},
#  {'_id': 'InfoSec812',
#   'password': '$2b$12$rW4h.GlEdkDnas.sHG5cMeCuXLhmoSidWuSMtPxraAQjJadWLj2ZW',
#   'name': 'Deven',
#    '68543ae08e6211d047c3c02b'],
#   'isAdmin': False,
#   'registrationDate': '2017-11-10T14:20:12Z'},
#  {'_id': 'latyika94',
#   'password': '$2b$12$a0TX4PwtZdz8KINBEUsGXObJvrEIF4MZlS6Fw61HDz.5NI9QuSg2.',
#   'email': 'latyika94@gmail.com',
#   'nationality': 'Hungary',
#   'followerNumber': 1,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2016-04-29T15:49:33Z',
#   'commentIds': ['68543acd8e6211d047bf6221']},
#  {'_id': 'lealceldeiro',
#   'password': '$2b$12$CUnJ./jc9znjSakBWwihAegFtBqdBOSHE25bVm.f9AW1UmHDpFXHS',
#   'name': 'Asiel',
#   'surname': 'Leal Celdeiro',
#   'nationality': 'Europe (UTC+2)',
#   'followerNumber': 12,
#   'followingNumber': 9,
#   'isAdmin': False,
#   'registrationDate': '2015-11-24T00:40:24Z',
#   'commentIds': ['68543ace8e6211d047bfdc2c']},
#  {'_id': 'kidomine',
#   'password': '$2b$12$zdPmhx9JWSbd54FJtyEfReCfz7brj6BI1IdiZt8.Kq0qci5rpAtQy',
#   'name': 'Ian',
#   'surname': 'Diaz',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2013-03-30T08:50:41Z',
#   'commentIds': ['68543ada8e6211d047c2c5f0']},
#  {'_id': 'Payaml',
#   'password': '$2b$12$tebL2IZAT5RJgmx/KmdkOegT3L/u9qciqrrGNkXPtt06TkwZ5WqYy',
#   'email': '472726299@qq.com',
#   'name': '薄荷er',
#   'followerNumber': 0,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2017-02-15T01:08:58Z',
#   'commentIds': ['68543acf8e6211d047c00743']},
#  {'_id': 'YoYo-YY-YoYo',
#   'password': '$2b$12$wg6Orntb48sNQeVmUs5abuG2LqFpkii96DeeczBw69Y.PEYtbPmoi',
#   'name': 'Yang',
#   'nationality': 'China',
#   'followerNumber': 2,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2014-12-23T13:25:38Z',
#   'commentIds': ['68543adc8e6211d047c2fcc2']},
#  {'_id': 'slootzky',
#   'password': '$2b$12$4rC4N3GH/D51hR/MLcu7AOTgur3emJyj6KQrcN87uG7IoC5wBz3Dq',
#   'email': 'rot253@gmail.com',
#   'name': 'Rotem',
#   'surname': 'Slootzky',
#   'followerNumber': 0,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2015-02-12T09:39:04Z',
#   'commentIds': ['68543ad48e6211d047c138b3']},
#  {'_id': 'micheljung',
#   'password': '$2b$12$.Z2k4JHHhrbxo7d7N0BMru1EGR.Z26wqF2Z31Me4ZB/dgHGc.x9im',
#   'email': 'michel.jung89@gmail.com',
#   'name': 'Michel',
#   'surname': 'Jung',
#   'nationality': 'Switzerland',
#   'followerNumber': 28,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2012-06-18T19:02:18Z',
#   'commentIds': ['68543acd8e6211d047bf8723']},
#  {'_id': 'luckypoem',
#    '68543acf8e6211d047c00d76',
#    '68543acf8e6211d047c00d7d',
#    '68543acf8e6211d047c00daa',
#    '68543acf8e6211d047c00dec',
#    '68543acf8e6211d047c00e12',
#    '68543acf8e6211d047c00e8f',
#    '68543acf8e6211d047c00eb3',
#    '68543acf8e6211d047c00ebf',
#    '68543acf8e6211d047c00eca',
#    '68543acf8e6211d047c00ef3',
#    '68543acf8e6211d047c00f15',
#    '68543acf8e6211d047c00f17',
#    '68543acf8e6211d047c00f33',
#    '68543acf8e6211d047c00f3d',
#    '68543acf8e6211d047c00f4a'],
#   'isAdmin': False,
#   'registrationDate': '2016-04-13T04:34:46Z'},
#  {'_id': 'phaer',
#   'password': '$2b$12$nsBeScgQuBgYwaTmiA2HGOew4Rw3DjMR7K7B88lUh19qn9xnLqma6',
#   'email': 'hello@phaer.org',
#   'name': 'Paul',
#   'surname': 'Haerle',
#   'nationality': 'Vienna, Austria',
#   'followerNumber': 123,
#   'followingNumber': 133,
#   'commitIds': ['68543acc8e6211d047bf07b4',
#    '68543acc8e6211d047bf07b7',
#    '68543acc8e6211d047bf07c2',
#    '68543acc8e6211d047bf0816',
#    '68543acc8e6211d047bf0840',
#    '68543acc8e6211d047bf089f',
#    '68543acc8e6211d047bf08ba'],
#   'isAdmin': False,
#   'registrationDate': '2009-07-05T00:49:18Z',
#   'commentIds': ['68543acc8e6211d047bf08f4']},
#  {'_id': 'JeethJJ',
#   'password': '$2b$12$yxUlTvVVSB2aRM7nNmZPe.etDKIV70i0FCdHszyJbYkMbCm8wAY3G',
#   'name': 'Jihan',
#   'surname': 'Jeeth',
#   'nationality': 'Colombo , Sri Lanka',
#   'followerNumber': 11,
#   'followingNumber': 15,
#   'isAdmin': False,
#   'registrationDate': '2019-05-22T08:04:18Z',
#   'commentIds': ['68543ad48e6211d047c125d5']},
#  {'_id': 'skumaravelayutham',
#   'password': '$2b$12$CKQ.pvl9q9g2Bhu0CluPt.1POvN8ea1GoDnyQOgLbDQwXNtI68AbK',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543ad68e6211d047c1b880',
#    '68543ad68e6211d047c1b883',
#    '68543ad68e6211d047c1b885'],
#   'isAdmin': False,
#   'registrationDate': '2018-10-02T19:19:24Z'},
#  {'_id': 'ChristopheCVBWDG',
#   'password': '$2b$12$AXVh8qvbaEsDPfevjtCUgewF2.nvADJ8NvmirQepmZ/9xRSMhveSG',
#   'email': 'ccarvalho@wedigital.garden',
#   'name': 'Christophe',
#   'surname': 'Carvalho Vilas-Boas',
#   'nationality': 'Paris, France',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2017-02-06T16:09:53Z',
#   'commentIds': ['68543ada8e6211d047c29796']},
#  {'_id': 'hbweb',
#   'password': '$2b$12$KQ4PbD3dckxJ2hytj08Qa.GUX571TyKvpFujF/9KAjGvH/am6zwhC',
#   'email': 'hung@quaycreative.com',
#   'name': 'Hung',
#   'surname': 'Bui',
#   'nationality': 'United Kingdom',
#   'followerNumber': 19,
#    '68543ad98e6211d047c25db9',
#    '68543ad98e6211d047c25dbb',
#    '68543ad98e6211d047c25dc0',
#    '68543ad98e6211d047c25dc1'],
#   'isAdmin': False,
#   'registrationDate': '2012-04-23T03:08:06Z',
#   'commentIds': ['68543ad98e6211d047c25dda']},
#  {'_id': 'HashEngineering',
#   'password': '$2b$12$6E9/q61WnFeBD6ZRHuTJt.74S3OGIRBoGiOoFuC5VC4Brzjx1QVCC',
#   'email': 'hashengineeringsolutions@gmail.com',
#   'name': 'HashEngineering',
#   'nationality': 'Southern California',
#   'followerNumber': 86,
#   'followingNumber': 5,
#   'commitIds': ['68543ad38e6211d047c1124d',
#    '68543ad38e6211d047c1127a',
#    '68543ad38e6211d047c11283',
#    '68543ad38e6211d047c112a4',
#    '68543ad38e6211d047c112d7',
#    '68543ad38e6211d047c112d9',
#    '68543ad38e6211d047c112ff',
#    '68543ad38e6211d047c1130e',
#    '68543ad38e6211d047c1137d',
#    '68543ad38e6211d047c1137f',
#    '68543ad38e6211d047c113a1',
#    '68543ad38e6211d047c113b5',
#    '68543ad38e6211d047c113f9',
#    '68543ad38e6211d047c113fc',
#    '68543ad38e6211d047c11413',
#    '68543ad38e6211d047c11417'],
#   'isAdmin': False,
#   'registrationDate': '2013-11-16T16:26:12Z'},
#  {'_id': 'kongyang80',
#   'password': '$2b$12$sdDH2L.AoGsEFdAxLH5Zh.ECJ0bieUl3StUS0WPAXMvv8Ao6HomXC',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543add8e6211d047c30ecf',
#    '68543add8e6211d047c30ed6',
#    '68543add8e6211d047c30ed7',
#    '68543add8e6211d047c30edf'],
#   'isAdmin': False,
#   'registrationDate': '2011-06-08T14:55:21Z',
#   'commentIds': ['68543add8e6211d047c30f0b']},
#  {'_id': 'onyas',
#   'password': '$2b$12$kD.5ouWQJdEoD0PHAfzeTex2pFzMgVlMoDIonudJ0N2qcjSiHcnDC',
#   'name': 'Edward',
#   'nationality': 'Xiamen China',
#   'followerNumber': 42,
#   'followingNumber': 295,
#   'isAdmin': False,
#   'registrationDate': '2012-03-31T06:50:02Z',
#   'commentIds': ['68543adc8e6211d047c301d3']},
#  {'_id': 'ScottConway',
#   'password': '$2b$12$hY9.zjrzD8fcEeunwMbr/.GMNbkyquJpfrSgnhFaP8mnPDSzr1jqG',
#   'email': 'scott.conway@gmail.com',
#   'name': 'Scott',
#   'surname': 'Conway',
#   'nationality': 'Fort Worth, Texas',
#   'followerNumber': 1,
#   'followingNumber': 2,
#   'commitIds': ['68543ad18e6211d047c067bd',
#    '68543ad18e6211d047c067be',
#    '68543ad18e6211d047c067bf',
#    '68543ad18e6211d047c067c5',
#    '68543ad18e6211d047c067cb',
#    '68543ad18e6211d047c067cf',
#    '68543ad18e6211d047c067d1',
#    '68543ad18e6211d047c067d4',
#    '68543ad18e6211d047c067d5',
#    '68543ad18e6211d047c067de',
#    '68543ad18e6211d047c067e2',
#    '68543ad18e6211d047c067e6',
#    '68543ad18e6211d047c067eb',
#    '68543ad18e6211d047c067ed',
#    '68543ad18e6211d047c067ef',
#    '68543ad18e6211d047c067f7',
#    '68543ad18e6211d047c067f8',
#    '68543ad18e6211d047c06803',
#    '68543ad18e6211d047c0680e',
#    '68543ad18e6211d047c0680f',
#    '68543ad18e6211d047c06811',
#    '68543ad18e6211d047c06820',
#    '68543ad18e6211d047c06823',
#    '68543ad18e6211d047c06826',
#    '68543ad18e6211d047c0682d',
#    '68543ad18e6211d047c0682e',
#    '68543ad18e6211d047c06830',
#    '68543ad18e6211d047c06838',
#    '68543ad18e6211d047c06839',
#    '68543ad18e6211d047c06845',
#    '68543ad18e6211d047c06849',
#    '68543ad18e6211d047c06851',
#    '68543ad18e6211d047c0685c',
#    '68543ad18e6211d047c06862',
#    '68543ad18e6211d047c06863',
#    '68543ad18e6211d047c06864',
#    '68543ad18e6211d047c0686a',
#    '68543ad18e6211d047c0686b',
#    '68543ad18e6211d047c0686f',
#    '68543ad18e6211d047c06882',
#    '68543ad18e6211d047c06886',
#    '68543ad18e6211d047c0688c',
#    '68543ad18e6211d047c0688f'],
#   'isAdmin': False,
#   'registrationDate': '2012-08-10T11:53:06Z'},
#  {'_id': 'mikegirard',
#   'password': '$2b$12$cb7pkjaQX2EKcAamMRw10OuikmiCGPRSyrG8fL20vlhaUpIehCnPu',
#   'name': 'Mike',
#   'surname': 'G',
#   'nationality': 'Denver Metro',
#   'followerNumber': 3,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2012-11-12T16:45:54Z',
#   'commentIds': ['68543acc8e6211d047bf11de']},
#  {'_id': 'Yury-Fridlyand',
#   'password': '$2b$12$DmecV99jIeX874j.CepnjOxzP9eQic4oEEBnil9Jd4dkvPyctOt8i',
#   'followerNumber': 13,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2021-08-09T17:32:21Z',
#   'commentIds': ['68543acd8e6211d047bf53d6']},
#  {'_id': '908875137',
#   'password': '$2b$12$7Oa7uC0rwNLbAT1LMRZl3ez1Tb6zZm1l.TQW1hywKAGrbNyCj8GvO',
#   'name': 'Leamon',
#   'surname': 'Tree',
#   'nationality': 'China',
#   'followerNumber': 0,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2017-12-15T05:22:10Z',
#   'commentIds': ['68543adf8e6211d047c39bee']},
#  {'_id': 'cargocultprogramming',
#   'password': '$2b$12$pkkMa1sPFp7K4imhvNqKNed1IoBRHomVAnzRe4EplHP67PjSbtLT.',
#   'name': 'mluisser',
#   'nationality': 'Austria',
#   'followerNumber': 0,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2015-01-02T16:20:55Z',
#   'commentIds': ['68543ad48e6211d047c15fe4']},
#  {'_id': 'andrewhavens',
#   'password': '$2b$12$8tFhCE32oUbVZYU9HmyGUuVXjT6QQlmD2o1YyXltw6LjTLmeDyqU6',
#   'name': 'Andrew',
#   'surname': 'Havens',
#   'nationality': 'Portland, Oregon, USA',
#   'followerNumber': 87,
#   'followingNumber': 9,
#   'isAdmin': False,
#   'registrationDate': '2010-10-20T04:24:32Z',
#   'commentIds': ['68543acd8e6211d047bf4a21']},
#  {'_id': 'mathieuales',
#   'password': '$2b$12$z5x1Yh9ofcdwfMhrenNXOu0UpdNUnjhNJPSVnBgcEx4kws0zO6Y2K',
#   'name': 'Mathieu',
#   'surname': 'Alès',
#   'nationality': 'Rennes, France',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543acd8e6211d047bf91af',
#    '68543acd8e6211d047bf91da',
#    '68543acd8e6211d047bf91dc',
#    '68543acd8e6211d047bf921b',
#    '68543acd8e6211d047bf921c',
#    '68543acd8e6211d047bf9230',
#    '68543acd8e6211d047bf9241',
#    '68543acd8e6211d047bf924c',
#    '68543acd8e6211d047bf9263',
#    '68543acd8e6211d047bf9274',
#    '68543acd8e6211d047bf9290',
#    '68543acd8e6211d047bf929b',
#    '68543acd8e6211d047bf92ad',
#    '68543acd8e6211d047bf92bf',
#    '68543acd8e6211d047bf92c1',
#    '68543acd8e6211d047bf92c5',
#    '68543acd8e6211d047bf92e0',
#    '68543acd8e6211d047bf92f3',
#    '68543acd8e6211d047bf92f9',
#    '68543acd8e6211d047bf9308',
#    '68543acd8e6211d047bf9312',
#    '68543acd8e6211d047bf931d',
#    '68543acd8e6211d047bf9363'],
#   'isAdmin': False,
#   'registrationDate': '2015-06-24T08:27:34Z'},
#  {'_id': 'it-noob',
#   'password': '$2b$12$V6c69UvssEedUrMbWAPtz.QgFN63H7GzR8F61GCWcKJBUWOuQth6q',
#   'email': 'itnoob@qq.com',
#   'name': 'DaShuiNiu',
#   'nationality': ' Dalian Chnia',
#   'followerNumber': 13,
#   'followingNumber': 29,
#   'isAdmin': False,
#   'registrationDate': '2015-04-21T03:07:31Z',
#   'commentIds': ['68543adb8e6211d047c2e975']},
#  {'_id': 'berthelemy',
#   'password': '$2b$12$vtktF1i7GLd3mKRMH5E6e.joMNB6m06jaxA0GwknJfVKWIRV.q/cm',
#   'name': 'Mark',
#   'surname': 'Berthelemy',
#   'nationality': 'Guiscriff, France',
#   'followerNumber': 1,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2012-10-08T13:57:55Z',
#   'commentIds': ['68543ad48e6211d047c15fc7']},
#  {'_id': 'ncavig',
#   'password': '$2b$12$hx6be8i1nDVMkdqDYTboPOJlUdrKa7NR2Qhs7gww1hvD6WzHmjPtu',
#   'email': 'ncavig@gmail.com',
#   'name': 'Nicolas',
#   'surname': 'Cavigliano',
#   'nationality': 'Sunnyvale, CA',
#   'followerNumber': 13,
#   'followingNumber': 11,
#   'commitIds': ['68543acf8e6211d047c007f6',
#    '68543acf8e6211d047c00830',
#    '68543acf8e6211d047c00838',
#    '68543acf8e6211d047c0086d',
#    '68543acf8e6211d047c00884',
#    '68543acf8e6211d047c0089b',
#    '68543acf8e6211d047c008e1',
#    '68543acf8e6211d047c008e8',
#    '68543acf8e6211d047c008fa',
#    '68543acf8e6211d047c008fb'],
#   'isAdmin': False,
#   'registrationDate': '2010-07-05T19:11:29Z'},
#  {'_id': 'Insthyd',
#   'password': '$2b$12$kG/LejTUwmpYXJw1VUhPOO3twrHvCvtPYdG/1dYVm804WCUz0Ah.W',
#   'followerNumber': 2,
#   'followingNumber': 8,
#   'isAdmin': False,
#   'registrationDate': '2015-09-29T02:31:13Z',
#   'commentIds': ['68543acf8e6211d047c01292']},
#  {'_id': 'mmcintosh',
#   'password': '$2b$12$0VvH6wXyWraSwrqdxiJZneenNWJFk7QVcWsDhRFxnzw40PxtMwNgK',
#   'name': 'MarkMac',
#   'nationality': 'Baltimore',
#   'followerNumber': 5,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2011-06-05T14:44:39Z',
#   'commentIds': ['68543acd8e6211d047bf3f97']},
#  {'_id': 'AbelSara',
#   'password': '$2b$12$4Yhpk/2J9itOedt7fqn2EeEKUk7oQSdLysUZyn7NNVCC3DoSdW4ia',
#   'email': 'nenbaying@163.com',
#   'name': 'Honghan',
#   'surname': 'Zhu',
#   'nationality': 'ShenZhen, China',
#   'followerNumber': 3,
#   'followingNumber': 5,
#   'isAdmin': False,
#   'registrationDate': '2017-06-08T06:23:06Z',
#   'commentIds': ['68543acf8e6211d047c01194']},
#  {'_id': 'valsinats42',
#   'password': '$2b$12$j5ECvioUqEk9afwgNXVxOuq4vPHsnyc1ZQa0Eh/clkg8LDg8duDEe',
#   'name': 'Stanislav',
#   'surname': 'Nikolov',
#   'nationality': 'Sofia, Bulgaria',
#   'followerNumber': 1,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2014-12-25T20:26:26Z',
#   'commentIds': ['68543ad48e6211d047c120e4']},
#  {'_id': 'jscruz',
#   'password': '$2b$12$NXzUXQKaeCzAGLsRSQvpaOmItv/h.7N0go.8QaNtP4TYBw463Y2S6',
#   'name': 'Jorge',
#   'surname': 'Cruz-Lambert',
#   'nationality': 'Poole, UK',
#   'followerNumber': 15,
#   'followingNumber': 4,
#   'commitIds': ['68543adf8e6211d047c39651',
#    '68543adf8e6211d047c39664',
#    '68543adf8e6211d047c39697',
#    '68543adf8e6211d047c39698',
#    '68543adf8e6211d047c396a4',
#    '68543adf8e6211d047c396b6',
#    '68543adf8e6211d047c396b9',
#    '68543adf8e6211d047c396e0',
#    '68543adf8e6211d047c396ed',
#    '68543adf8e6211d047c396fb',
#    '68543adf8e6211d047c396fe',
#    '68543adf8e6211d047c39725',
#    '68543adf8e6211d047c39740',
#    '68543adf8e6211d047c39761',
#    '68543adf8e6211d047c3976e',
#    '68543adf8e6211d047c3978b',
#    '68543adf8e6211d047c397b7',
#    '68543adf8e6211d047c397bd',
#    '68543adf8e6211d047c397c3'],
#   'isAdmin': False,
#   'registrationDate': '2012-03-07T19:42:12Z'},
#  {'_id': 'zhufui',
#   'password': '$2b$12$sZ.WCl8q6eH2I2bxhZZUbetOtL5MtecxKieNpMb67wmf4I1lD8MjO',
#   'followerNumber': 3,
#   'followingNumber': 15,
#   'isAdmin': False,
#   'registrationDate': '2013-07-12T02:36:03Z',
#   'commentIds': ['68543ade8e6211d047c36ae0']},
#  {'_id': 'DineshD',
#   'password': '$2b$12$7NPbK3lN3EQCrjarC7x9GOY7wxX620wHqce/ZlfY/2pKmR3G6QfAW',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2012-12-20T12:22:01Z',
#   'commentIds': ['68543ad08e6211d047c05918']},
#  {'_id': 'Zido7867',
#   'password': '$2b$12$h3yDu0vrKDoQx.Gi5Nv74OMHXv8XQ.hHXiF7duXVd/Bz/1txXGxJ.',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543add8e6211d047c332c8',
#    '68543add8e6211d047c332cc',
#    '68543add8e6211d047c332d3',
#    '68543add8e6211d047c332d9',
#    '68543add8e6211d047c332e7',
#    '68543add8e6211d047c33301',
#    '68543add8e6211d047c3332e',
#    '68543add8e6211d047c33348',
#    '68543add8e6211d047c33349',
#    '68543add8e6211d047c33350',
#    '68543add8e6211d047c3335a',
#    '68543add8e6211d047c33367',
#    '68543add8e6211d047c3337e',
#    '68543add8e6211d047c33384',
#    '68543add8e6211d047c33393',
#    '68543add8e6211d047c333a0',
#    '68543add8e6211d047c333ad',
#    '68543add8e6211d047c333b2'],
#   'isAdmin': False,
#   'registrationDate': '2016-10-05T06:41:12Z',
#   'commentIds': ['68543add8e6211d047c333c7']},
#  {'_id': 'ttanxu',
#   'password': '$2b$12$PwgDCv.fB9nlQ97PhCAUJuRGlP7TFdY3tQhcoj2y76DlI.oEZIsNC',
#   'email': 'xutan@google.com',
#   'name': 'Xu',
#   'surname': 'Tan',
#   'nationality': '美国',
#   'followerNumber': 3,
#   'followingNumber': 0,
#   'commitIds': ['68543acd8e6211d047bf9669',
#    '68543acd8e6211d047bf966c',
#    '68543acd8e6211d047bf966e',
#    '68543acd8e6211d047bf966f',
#    '68543acd8e6211d047bf9671',
#    '68543acd8e6211d047bf9674',
#    '68543acd8e6211d047bf9676',
#    '68543acd8e6211d047bf9678',
#    '68543acd8e6211d047bf967c'],
#   'isAdmin': False,
#   'registrationDate': '2013-02-12T04:04:16Z',
#   'commentIds': ['68543acd8e6211d047bf96bc',
#    '68543acd8e6211d047bf96c4',
#    '68543acd8e6211d047bf96c8',
#    '68543acd8e6211d047bf96c9',
#    '68543acd8e6211d047bf96ca',
#    '68543acd8e6211d047bf96cb',
#    '68543acd8e6211d047bf96cc',
#    '68543acd8e6211d047bf96cd',
#    '68543acd8e6211d047bf96d1',
#    '68543acd8e6211d047bf96d2',
#    '68543acd8e6211d047bf96d3',
#    '68543acd8e6211d047bf96d5',
#    '68543acd8e6211d047bf96d6',
#    '68543acd8e6211d047bf96d7',
#    '68543acd8e6211d047bf96da']},
#  {'_id': 'HanYanxi',
#   'password': '$2b$12$wHVKYhK2BqZDQXghhMSRv.7Vy2yRrAlSMMfz0bXu2jWDXiqup.SKK',
#   'followerNumber': 0,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2019-02-11T19:17:10Z',
#   'commentIds': ['68543acc8e6211d047bf38ea']},
#  {'_id': 'shamithc',
#   'password': '$2b$12$4iaRvI/m7lovBNUcMcmhUup/fQn7SFyES.8e9HJyg8BVa53uylqxK',
#   'email': 'shamithc@gmail.com',
#   'name': 'Shamith',
#   'surname': 'c',
#   'nationality': 'India',
#   'followerNumber': 28,
#   'followingNumber': 77,
#   'commitIds': ['68543ad08e6211d047c05683',
#    '68543ad08e6211d047c05685',
#    '68543ad08e6211d047c05686',
#    '68543ad08e6211d047c05687',
#    '68543ad08e6211d047c05688',
#    '68543ad08e6211d047c05689',
#    '68543ad08e6211d047c0568c',
#    '68543ad08e6211d047c0568d',
#    '68543ad08e6211d047c0568f',
#    '68543ad08e6211d047c05691',
#    '68543ad08e6211d047c05694',
#    '68543ad08e6211d047c05696',
#    '68543ad08e6211d047c05698',
#    '68543ad08e6211d047c05699',
#    '68543ad08e6211d047c0569c',
#    '68543ad08e6211d047c0569e'],
#   'isAdmin': False,
#   'registrationDate': '2010-09-17T09:01:23Z',
#   'commentIds': ['68543ad08e6211d047c056b0']},
#  {'_id': 'jxllh123456',
#   'password': '$2b$12$JoydnmY/pTy4NVDjdTZFfOXO8gYmN6CQUXer3BQ4knXTeoyJ23lfO',
#   'email': 'jxllh123456@gmail.com',
#   'name': 'lilinhai',
#   'nationality': '北京',
#   'followerNumber': 13,
#   'followingNumber': 48,
#   'isAdmin': False,
#   'registrationDate': '2015-02-05T02:52:14Z',
#   'commentIds': ['68543ada8e6211d047c27c9c']},
#  {'_id': 'RoKish',
#   'password': '$2b$12$t5tHYuKxSAF0xrfpunwr.uFAeBN869jDg0l/RqqM8tNNG42WI71Nu',
#   'email': 'rkishchenko@gmail.com',
#   'name': 'Roman',
#   'surname': 'Kishchenko',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543add8e6211d047c32104',
#    '68543add8e6211d047c32113',
#    '68543add8e6211d047c32147',
#    '68543add8e6211d047c3214b',
#    '68543add8e6211d047c32169',
#    '68543add8e6211d047c32187',
#    '68543add8e6211d047c32196',
#    '68543add8e6211d047c321c2',
#    '68543add8e6211d047c321ff',
#    '68543add8e6211d047c32205',
#    '68543add8e6211d047c3220c',
#    '68543add8e6211d047c32251',
#    '68543add8e6211d047c32253',
#    '68543add8e6211d047c32273',
#    '68543add8e6211d047c32281',
#    '68543add8e6211d047c322b3',
#    '68543add8e6211d047c322d9'],
#   'isAdmin': False,
#   'registrationDate': '2013-08-08T14:30:12Z'},
#  {'_id': 'hexgnu',
#   'password': '$2b$12$31NP3sKOcFmQWBxZFPs3euaVNEYpcdVr2y9ZlKQ5ZksqylfW7T0..',
#   'email': 'matt@matthewkirk.com',
#   'name': 'Matt',
#   'surname': 'Kirk',
#   'nationality': 'Seattle, WA',
#   'followerNumber': 128,
#   'followingNumber': 3,
#   'commitIds': ['68543add8e6211d047c316d0',
#    '68543add8e6211d047c316e0',
#    '68543add8e6211d047c31702',
#    '68543add8e6211d047c31712',
#    '68543add8e6211d047c3173f',
#    '68543add8e6211d047c3175b',
#    '68543add8e6211d047c31791',
#    '68543add8e6211d047c317ab',
#    '68543add8e6211d047c317ad',
#    '68543add8e6211d047c317c2',
#    '68543add8e6211d047c317f3',
#    '68543add8e6211d047c31809',
#    '68543add8e6211d047c31828',
#    '68543add8e6211d047c3182d',
#    '68543add8e6211d047c3187e'],
#   'isAdmin': False,
#   'registrationDate': '2009-10-12T05:34:17Z'},
#  {'_id': 'SHxKM',
#   'password': '$2b$12$I3H8DY0TjobGrhf17wBD2OOyK24mzireLHZcsyFVrFknhibZzTsJ2',
#   'followerNumber': 10,
#   'followingNumber': 7,
#   'isAdmin': False,
#   'registrationDate': '2014-02-03T10:12:34Z',
#   'commentIds': ['68543acb8e6211d047beee70', '68543acb8e6211d047beee71']},
#  {'_id': 'sgjesse',
#   'password': '$2b$12$vMr3y/6qkkPr6IjxQQAToOiJsiTJL3P3u4PedmLhWv/oZm.1chkly',
#   'email': 'soren@gjesse.dk',
#   'name': 'Søren',
#   'surname': 'Gjesse',
#   'nationality': 'Denmark',
#   'followerNumber': 33,
#   'followingNumber': 0,
#   'commitIds': ['68543ad18e6211d047c072b6',
#    '68543ad18e6211d047c072ba',
#    '68543ad18e6211d047c072d8',
#    '68543ad18e6211d047c072f1',
#    '68543ad18e6211d047c072ff',
#    '68543ad18e6211d047c07302',
#    '68543ad18e6211d047c0731c',
#    '68543ad18e6211d047c07341',
#    '68543ad18e6211d047c0737f',
#    '68543ad18e6211d047c07395',
#    '68543ad18e6211d047c073c4',
#    '68543ad18e6211d047c073d1',
#    '68543ad18e6211d047c073d5',
#    '68543ad18e6211d047c073e0',
#    '68543ad18e6211d047c073ea',
#    '68543ad18e6211d047c073ed',
#    '68543ad18e6211d047c07403',
#    '68543ad18e6211d047c07407'],
#   'isAdmin': False,
#   'registrationDate': '2012-01-18T09:28:35Z'},
#  {'_id': 'DManstrator',
#   'password': '$2b$12$BTX1aDCdzG/ySgBkYDFSRO.5Q3MFdIP36iUCXnnpGx6jnrJBD/iau',
#   'name': 'DMan',
#   'followerNumber': 5,
#   'followingNumber': 3,
#   'isAdmin': False,
#   'registrationDate': '2014-05-13T18:16:33Z',
#   'commentIds': ['68543ad08e6211d047c0171d']},
#  {'_id': 'aleksandra-majchrzak',
#   'password': '$2b$12$E.YedsdEXOfFenn.eaJYaOLy.48Fl88ZCq8XRxEnAqrlhtiNVQmQO',
#   'name': 'Aleksandra',
#   'surname': 'K.',
#   'followerNumber': 10,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2015-02-13T14:44:31Z',
#   'commentIds': ['68543ada8e6211d047c2b6f8']},
#  {'_id': 'jessespy2',
#   'password': '$2b$12$LznbZv8EJ73B2zK45HSWJO8qYmr4XOeciE6x/UhrkHYfCdw0qKhwm',
#   'followerNumber': 1,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2017-06-13T14:34:55Z',
#   'commentIds': ['68543ace8e6211d047bf997b']},
#  {'_id': 'andclt',
#   'password': '$2b$12$gGaIxA5ekHs0sV8wPQlkfuK/.JF9z5E3Y8EkWhUxkT/v6KroVYO06',
#   'name': 'Andrea',
#   'surname': 'Culot',
#   'followerNumber': 1,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2021-12-08T12:42:52Z',
#   'commentIds': ['68543ad18e6211d047c09d3c']},
#  {'_id': 'rafakob',
#   'password': '$2b$12$MHMF.OoJ9UuBEIyE/HmSS.nXhfRn46pUKwSnlMaunJ/04jIwp7T52',
#   'name': 'Rafał',
#   'surname': 'Kobyłko',
#   'nationality': 'Poland',
#   'followerNumber': 39,
#   'followingNumber': 3,
#   'isAdmin': False,
#   'registrationDate': '2014-03-12T00:27:30Z',
#   'commentIds': ['68543adb8e6211d047c2d94d']},
#  {'_id': 'JulianWu520',
#   'password': '$2b$12$vbefh5Ju3rabMWlQP1jvYONtF2IgDgfyYUxsyd2EM2Bl0HBDIhR2m',
#   'name': 'JulianWu',
#   'followerNumber': 54,
#   'followingNumber': 20,
#   'isAdmin': False,
#   'registrationDate': '2016-02-16T21:47:48Z',
#   'commentIds': ['68543ada8e6211d047c29c67']},
#  {'_id': 'MartyAlien',
#   'password': '$2b$12$rR/.XXLxxNj7i/gUIp0V.uiQYBfTC3f2ERpAbz3e0iB2mqoOd.FPa',
#   'followerNumber': 3,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2020-03-11T00:20:14Z',
#   'commentIds': ['68543ade8e6211d047c35c8c']},
#  {'_id': 'Pomelo1001',
#   'password': '$2b$12$sH0k3U8eXcDO5JzfvbWgHOzaDVtYg1iHCvEs0F4rmL8zu4Zc27.ke',
#   'followerNumber': 10,
#   'followingNumber': 138,
#   'isAdmin': False,
#   'registrationDate': '2016-03-18T06:27:25Z',
#   'commentIds': ['68543ad18e6211d047c0695e']},
#  {'_id': 'zhiguo-ren',
#   'password': '$2b$12$yqapB.P1j33U0XGTGwvT8urVNrpB62wS51mmuQvyPquWgCnp05qYi',
#   'name': 'Egbert',
#   'surname': 'Ren',
#   'nationality': 'China',
#   'followerNumber': 3,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2014-12-17T02:54:54Z',
#   'commentIds': ['68543ada8e6211d047c2a7ab']},
#  {'_id': 'pcallahan-r7',
#   'password': '$2b$12$lVFPx/SDSBo.U1W7YNlF2eQmUDcRN3KugW66ByUJKxoqx/xZ75ClC',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2019-07-19T18:24:45Z',
#   'commentIds': ['68543ace8e6211d047bfe8c8']},
#  {'_id': 'Varun-Sethu',
#   'password': '$2b$12$HDVVGbJbIT0JZn6.GPHJeu1uKbfkw632S/YbvG67J7wSZ5jm5vt46',
#   'email': 'varun.sethu@outlook.com',
#   'name': 'Varun',
#   'surname': 'Sethu',
#   'nationality': 'Sydney, Australia',
#   'followerNumber': 61,
#   'followingNumber': 53,
#   'isAdmin': False,
#   'registrationDate': '2016-08-19T00:25:18Z',
#   'commentIds': ['68543ad08e6211d047c049f4']},
#  {'_id': 'HuangDayu',
#   'password': '$2b$12$DLBLD00hwpwdpRxI6nx0s.oLLDd.Ji0RyZVDuA3QJ6dlJpPW7Xshy',
#   'name': '大鱼叔叔',
#   'nationality': '大秦帝国',
#   'followerNumber': 15,
#   'followingNumber': 45,
#   'isAdmin': False,
#   'registrationDate': '2016-11-12T17:24:33Z',
#   'commentIds': ['68543ad28e6211d047c0cdf8']},
#  {'_id': 'nikhilanayak',
#   'password': '$2b$12$bfV3ADk7l5I1HHDH/HT8Yu5kv3fMSLyb524LGvMOQo2SOC8uHm7RK',
#   'name': 'NikhilNayak',
#   'followerNumber': 12,
#   'followingNumber': 8,
#   'isAdmin': False,
#   'registrationDate': '2018-11-18T20:49:10Z',
#   'commentIds': ['68543acc8e6211d047bf1bfa']},
#  {'_id': 'amitsinha11',
#   'password': '$2b$12$sl8KXDiiPuqTZexHwg5lVe9zwvgZsuJeiKNNYrBdQ.r09RGT3/UB6',
#   'name': 'Amit',
#   'surname': 'Sinha',
#   'nationality': 'Noida',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'commitIds': ['68543ade8e6211d047c38418',
#    '68543ade8e6211d047c3841b',
#    '68543ade8e6211d047c38432',
#    '68543ade8e6211d047c38434',
#    '68543ade8e6211d047c38487',
#    '68543ade8e6211d047c38490',
#    '68543ade8e6211d047c38495',
#    '68543ade8e6211d047c3849e',
#    '68543ade8e6211d047c384ea',
#    '68543ade8e6211d047c384f0',
#    '68543ade8e6211d047c38508',
#    '68543ade8e6211d047c3851c',
#    '68543ade8e6211d047c3851e',
# ...
#   'password': '$2b$12$BHS6AYdUfvc0tPfxOfvcT.ng/VEjvBt31PIUCdufxh8tknvtSKfPq',
#   'name': 'RioAngele',
#   'followerNumber': 7,
#   'followingNumber': 4,
#   'isAdmin': False,
#   'registrationDate': '2021-01-15T03:44:03Z',
#   'commentIds': ['68543acc8e6211d047bef696']},
#  {'_id': 'shingwaichan',
#   'password': '$2b$12$C0mOqrdPRGcqXUrTFI3f5e/3wpzO1zlJ8HlXRAySol8wVYWmuyJba',
#   'name': 'Shing',
#   'surname': 'Wai Chan',
#   'nationality': 'Santa Clara, CA, USA',
#   'followerNumber': 21,
#   'followingNumber': 0,
#   'commitIds': ['68543acd8e6211d047bf3c40',
#    '68543acd8e6211d047bf3c46',
#    '68543acd8e6211d047bf3c50',
#    '68543acd8e6211d047bf3c57',
#    '68543acd8e6211d047bf3c5b',
#    '68543acd8e6211d047bf3c63',
#    '68543acd8e6211d047bf3c68',
#    '68543acd8e6211d047bf3c76',
#    '68543acd8e6211d047bf3c7a',
#    '68543acd8e6211d047bf3c89',
#    '68543acd8e6211d047bf3c8e',
#    '68543acd8e6211d047bf3c93',
#    '68543acd8e6211d047bf3c9a',
#    '68543acd8e6211d047bf3cc7',
#    '68543acd8e6211d047bf3cd0',
#    '68543acd8e6211d047bf3cfe',
#    '68543acd8e6211d047bf3d0e',
#    '68543acd8e6211d047bf3d17',
#    '68543acd8e6211d047bf3d1d',
#    '68543acd8e6211d047bf3d1f',
#    '68543acd8e6211d047bf3d2b',
#    '68543acd8e6211d047bf3d39',
#    '68543acd8e6211d047bf3d43',
#    '68543acd8e6211d047bf3d44',
#    '68543acd8e6211d047bf3d46',
#    '68543acd8e6211d047bf3d64',
#    '68543acd8e6211d047bf3d74',
#    '68543acd8e6211d047bf3d78',
#    '68543acd8e6211d047bf3da2',
#    '68543acd8e6211d047bf3da6',
#    '68543acd8e6211d047bf3daa',
#    '68543acd8e6211d047bf3dab',
#    '68543acd8e6211d047bf3dac',
#    '68543acd8e6211d047bf3db4',
#    '68543acd8e6211d047bf3db5',
#    '68543acd8e6211d047bf3db9',
#    '68543acd8e6211d047bf3dcf',
#    '68543acd8e6211d047bf3dd2',
#    '68543acd8e6211d047bf3dd4',
#    '68543acd8e6211d047bf3ddc',
#    '68543acd8e6211d047bf3de0',
#    '68543acd8e6211d047bf3de4',
#    '68543acd8e6211d047bf3de6',
#    '68543acd8e6211d047bf3dea',
#    '68543acd8e6211d047bf3def',
#    '68543acd8e6211d047bf3e0e',
#    '68543acd8e6211d047bf3e11'],
#   'isAdmin': False,
#   'registrationDate': '2016-12-13T18:58:57Z'},
#  {'_id': 'DroidDevRis',
#   'password': '$2b$12$miyu4hc1mWG.e90sY/5llenZ6GZMcbiVyqz8wl6WfvIS5eu6sNydm',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2016-11-10T07:58:50Z',
#   'commentIds': ['68543ad68e6211d047c1bdb9']},
#  {'_id': 'nicolasgarea',
#   'password': '$2b$12$mHbFShiZ6e.x7x2AU4b7pet2Qin8d758k5qGwxHL8.l/enn.ywCKm',
#   'email': 'nicogareacidre@gmail.com',
#   'name': 'Nicolas',
#   'surname': 'Garea',
#   'nationality': 'Galicia, Spain',
#   'followerNumber': 7,
#   'followingNumber': 9,
#   'isAdmin': False,
#   'registrationDate': '2024-08-04T12:25:48Z',
#   'commentIds': ['68543ade8e6211d047c3795c', '68543ade8e6211d047c3795d']},
#  {'_id': 'RR1335',
#   'password': '$2b$12$25Ml9fnxg1J366nrAkuu5unYz6rB8wWCUarJmFgxEebUXswI674mW',
#   'email': 'odyli@126.com',
#   'name': 'RR1335',
#   'nationality': 'BU',
#   'followerNumber': 2,
#   'followingNumber': 12,
#   'isAdmin': False,
#   'registrationDate': '2024-12-19T10:36:57Z',
#   'commentIds': ['68543adf8e6211d047c39e99']},
#  {'_id': 'fommil',
#   'password': '$2b$12$oe7JK27S0WB8RE575flU4.yvpblNfNqi5WIimKmqkA/yKMco7Xlyq',
#   'email': 'sam.halliday@gmail.com',
#   'name': '>>=',
#   'followerNumber': 468,
#   'followingNumber': 0,
#   'commitIds': ['68543ace8e6211d047bfb8bb',
#    '68543ace8e6211d047bfb8c2',
#    '68543ace8e6211d047bfb8d8',
#    '68543ace8e6211d047bfb8df',
#    '68543ace8e6211d047bfb8ee',
#    '68543ace8e6211d047bfb8ef',
#    '68543ace8e6211d047bfb901',
#    '68543ace8e6211d047bfb905',
#    '68543ace8e6211d047bfb90e',
#    '68543ace8e6211d047bfb927',
#    '68543ace8e6211d047bfb942',
#   'isAdmin': False,
#   'registrationDate': '2015-03-23T00:23:39Z'},
#  {'_id': 'lightzane',
#   'password': '$2b$12$fRmiQ5a72iMNEq.70OVN..wWJS1c9C9PCdrVDOmtDFa2AhI/Goj/S',
#   'name': 'Lightzane',
#   'followerNumber': 6,
#   'followingNumber': 2,
#   'isAdmin': False,
#   'registrationDate': '2014-08-14T07:05:51Z',
#   'commentIds': ['68543ad68e6211d047c1ae3c']},
#  {'_id': 'ivgg-me',
#   'password': '$2b$12$CdRJzx5e2jYVMyxunge.5e2V3kSHU/emPT.GqIO4Cc5xRvOKHncBS',
#   'name': 'Gergö',
#   'surname': 'Gabor Ilyes-Veisz',
#   'nationality': 'Hungary',
#   'followerNumber': 1,
#   'followingNumber': 1,
#   'isAdmin': False,
#   'registrationDate': '2016-01-27T05:50:07Z',
#   'commentIds': ['68543ad88e6211d047c2288e']},
#  {'_id': 'ouabing',
#   'password': '$2b$12$UZfP/sumQg/WRnCulIbBAeFoy/nymY41SIQ2FGcU9I77PGzYv5TQi',
#   'name': 'abing',
#   'nationality': 'Beijing, China',
#   'followerNumber': 118,
#   'followingNumber': 140,
#   'isAdmin': False,
#   'registrationDate': '2012-02-12T06:59:16Z',
#   'commentIds': ['68543ad58e6211d047c197b7']},
#  {'_id': 'netmikey',
#   'password': '$2b$12$yE7fiQC/y4u0AjYFQO9cjeGey9UrdJdGkkeXFf78NopjBqLEA9QHS',
#   'name': 'Mike',
#   'surname': 'Meessen',
#   'nationality': 'Aachen, Germany',
#   'followerNumber': 13,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2011-11-08T14:39:41Z',
#   'commentIds': ['68543ad98e6211d047c2535a', '68543ad98e6211d047c2535b']},
#  {'_id': 'kumarraviraushan71',
#   'password': '$2b$12$ycfG8O9hrqroAntCG/JEe.2vH5Cu5KrSTOb0ILJ/C6I990snLRhUm',
#   'followerNumber': 0,
#   'followingNumber': 0,
#   'isAdmin': False,
#   'registrationDate': '2023-10-18T03:15:54Z',
#   'commentIds': ['68543ad88e6211d047c21e49']},
#  {'_id': 'FFcjs',
#   'password': '$2b$12$XVYy.ZBwbmAtZp7FaSE4gOp2OJsi5Z3wCMfILgVsh0W4luqJ7qBmS',
#   'email': '675539857@qq.com',
#   'name': 'ffcjsf',
#   'followerNumber': 0,
#   'followingNumber': 3,
#   'isAdmin': False,
#   'registrationDate': '2017-04-04T01:19:42Z',
#   'commentIds': ['68543ad48e6211d047c160fc']},
#  {'_id': 'sue602',
#   'password': '$2b$12$EJhXYmZAbSyOVWQl8qJEhuGXjt1xjnbNgeqsbAKrVDxf3wWePZNhm',
#   'email': '181399700@qq.com',
#   'nationality': 'fuzhou',
#   'followerNumber': 45,
#   'followingNumber': 354,
#   'isAdmin': False,
#   'registrationDate': '2009-10-09T08:25:23Z',
#   'commentIds': ['68543ace8e6211d047bfa002']},
#  {'_id': 'mrwu77',
#   'password': '$2b$12$QL2AZfUW5X2c/pY23XQHzeDR5waUGsaJ2XmBdvyflNLcFgvQ4G7zy',
#    '68543adf8e6211d047c3a57c',
#    '68543adf8e6211d047c3a583',
#    '68543adf8e6211d047c3a5c4',
#    '68543adf8e6211d047c3a5c9',
#    '68543adf8e6211d047c3a5e7',
#    '68543adf8e6211d047c3a614',
#    '68543adf8e6211d047c3a620',
#    '68543adf8e6211d047c3a628',
#    '68543adf8e6211d047c3a63c',
#    '68543adf8e6211d047c3a647',
#    '68543adf8e6211d047c3a64a',
#    '68543adf8e6211d047c3a652',
#    '68543adf8e6211d047c3a694',
#    '68543adf8e6211d047c3a6a8'],
#   'isAdmin': False,
#   'registrationDate': '2021-06-21T20:17:49Z'},
#  {'_id': 'S3cuRiTy-Er1C',
#   'password': '$2b$12$ZWdi4lDWNYg5FgL3UzzDPujIaBWWQfZihRAzO5xJ5Idt1rE368k.O',
#   'followerNumber': 22,
#   'followingNumber': 8,
#   'isAdmin': False,
#   'registrationDate': '2016-07-15T08:39:39Z',
#   'commentIds': ['68543acf8e6211d047c00a16']},
#  {'_id': 'tflobbe',
#   'password': '$2b$12$gurN7VRWNKWrtrRXSXFWxOAba8Rp6HLsDNZB9OoBq0gAqSYZkdkSS',
#   'name': 'Tomas',
#   'surname': 'Eduardo Fernandez Lobbe',
#   'followerNumber': 28,
#   'followingNumber': 0,
#   'commitIds': ['68543ace8e6211d047bf9bb9',
#    '68543ace8e6211d047bf9bc1',
#    '68543ace8e6211d047bf9bc2',
#    '68543ace8e6211d047bf9be2',
#    '68543ace8e6211d047bf9bef',
#    '68543ace8e6211d047bf9c0f',
#    '68543ace8e6211d047bf9c36',
#    '68543ace8e6211d047bf9c3f',
#    '68543ace8e6211d047bf9c59',
#    '68543ace8e6211d047bf9c8f',
#    '68543ace8e6211d047bf9cbd',
#    '68543ace8e6211d047bf9cc5',
#    '68543ace8e6211d047bf9ccc',
#    '68543ace8e6211d047bf9d01',
#    '68543ace8e6211d047bf9d51',
#    '68543ace8e6211d047bf9d5e',
#    '68543ace8e6211d047bf9d6c',
#    '68543ace8e6211d047bf9d6d',
#    '68543ace8e6211d047bf9d77',
#    '68543ace8e6211d047bf9d84'],
#   'isAdmin': False,
#   'registrationDate': '2010-11-25T15:56:42Z'},
#  {'_id': 'thi747',
#   'password': '$2b$12$XrkxfshTxc7hrB1cWcz1xOt03TiMgJXw4LAAO2cpAS8O3jYLvuYTK',
#   'name': 'Thiago',
#   'surname': 'E. Santos',
#   'nationality': 'Brasília, Brazil',
#   'followerNumber': 4,
#   'followingNumber': 7,
#   'isAdmin': False,
#   'registrationDate': '2012-12-08T00:01:49Z',
#   'commentIds': ['68543ad58e6211d047c17467']},
#  {'_id': 'buwi',
#   'password': '$2b$12$jCSQb.lgo4IxLgvMZHSsiuDptR1kcuYWpXtX9LKsFSRFJqZe.Lw0G',
#   'name': 'NP',
#   'followerNumber': 1,
#   'followingNumber': 5,
#   'commitIds': ['68543ada8e6211d047c2bd6e',
#    '68543ada8e6211d047c2bd7e',
#    '68543ada8e6211d047c2bd7f',
#    '68543ada8e6211d047c2bd9c',
#    '68543ada8e6211d047c2bda7',
#    '68543acc8e6211d047befea5',
#    '68543acc8e6211d047befebd',
#    '68543acc8e6211d047befec0',
#    '68543acc8e6211d047befee7',
#    '68543acc8e6211d047befef4'],
#   'isAdmin': False,
#   'registrationDate': '2013-03-30T04:04:34Z'},
#  ...]

# %%
#TODO rinomicare comments, projects in commitIds, projectIds

for i in range(len(all_users)):
    if 'comments' in all_users[i]:
        all_users[i]['commentIds'] = all_users[i]['comments']
    if 'projects' in all_users[i]:
        all_users[i]['projectIds'] = all_users[i]['projects']
    if 'comments' in all_users[i]:
        del all_users[i]['comments']
    if 'projects' in all_users[i]:
        del all_users[i]['projects']

# %%
print(len(all_users))
print(len(users))

usernames_in_all_users = set(u['_id'] for u in all_users)
missing_users = users - usernames_in_all_users
print(f"Users in 'users' but not in 'all_users': {len(missing_users)}")
print(list(missing_users)[:10])  # print first 10 as example

# Fetch info for missing users and append to all_users
for i, username in enumerate(missing_users):
    print(f"Fetching missing user {i+1}/{len(missing_users)}: {username}")
    user_info = fetch_user_info(username)
    if user_info:
        all_users.append(user_info)
    time.sleep(0.8)  # Respect API rate limits

print(f"After adding missing users, total users: {len(all_users)}")
# Out:
# 25865
# 10057
# Users in 'users' but not in 'all_users': 0
# []
# After adding missing users, total users: 25865

# %%
# Save final users data
with open('mongo_users.json', 'w') as f:
    json.dump(all_users, f, indent=2)

# %%
import json

with open('mongo_users.json', 'r') as f:
    all_users = json.load(f)
print(f"Loaded {len(all_users)} users from mongo_users.json")

with open('mongo_projects.json', 'r') as f:
    all_projects = json.load(f)
print(f"Loaded {len(all_projects)} projects from mongo_projects.json")
# Out:
# Loaded 25476 users from mongo_users.json
# Loaded 1830 projects from mongo_projects.json

# %%
len(all_users)
# Out:
# 25476

# %%
# Add 'owner' to 'administrators' for each project
for project in all_projects:
    if 'administrators' in project:
        if project['owner'] not in project['administrators']:
            project['administrators'].append(project['owner'])
    else:
        project['administrators'] = [project['owner']]

# Collect all administrators into a set 'user'
users = set()
for project in all_projects:
    for admin in project['administrators']:
        users.add(admin)

# %%
25865-25476
# Out:
# 389

# %%
import json

for project in all_projects:
    owner = project.get('owner')
    admins = project.get('administrators', [])
    if not owner in admins:
        print(f"Owner '{owner}' is not in administrators for project '{project.get('name')}'")

with open('mongo_projects.json', 'w') as f:
    json.dump(all_projects, f, indent=2)

# %%
import json
with open('mongo_projects.json', 'r') as f:
    all_projects = json.load(f)
print(f"Loaded {len(all_projects)} projects from mongo_projects.json")

with open('mongo_files.json', 'r') as f:
    all_files = json.load(f)
print(f"Loaded {len(all_files)} files from mongo_files.json")

# Build a mapping from file ID to project IDs
file_to_projects = {}
for project in all_projects:
    for fid in project.get('fileIds', []):
        if fid in file_to_projects:
            print('Error')
            break
        file_to_projects[fid] = project['_id']

# Add 'projectIds' field to each file
for f in all_files:
    f['projectId'] = file_to_projects.get(f['_id'], [])
# Out:
# Loaded 1830 projects from mongo_projects.json
# Loaded 44964 files from mongo_files.json

# %%
all_files[0]

# save to neo4j
with open('neo4j_files.json', 'w') as f:
    json.dump(all_files, f, indent=2)
